# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from sklearn import metrics
import numpy as npw
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler


def split_data_with_window(x_in, y_in, split_window_size):
    # Initialize lists to store training and temporary sets
    x_out1_list, y_out1_list, x_out2_list, y_out2_list = [], [], [], []

    # Iterate through the data with the specified window size
    for i in range(0, len(x_in) - split_window_size, split_window_size + 1):
        x_out1_out2 = x_in.iloc[i:i+split_window_size+1]
        y_out1_out2 = y_in.iloc[i:i+split_window_size+1]

        # Separate the last row for the temporary set
        # [ :-1]: all elements except the last one
        # [-1:]:  selects only the last element
        # (:) is used to indicate slicing of a sequence
        # sequence[start : end : step]

        x_out1 = x_out1_out2.iloc[:-1]
        y_out1 = y_out1_out2.iloc[:-1]

        x_out2 = x_out1_out2.iloc[-1:]
        y_out2 = y_out1_out2.iloc[-1:]

        x_out1_list.append(x_out1)
        y_out1_list.append(y_out1)
        x_out2_list.append(x_out2)
        y_out2_list.append(y_out2)

    # Concatenate the lists into pandas DataFrames
    x_out1 = pd.concat(x_out1_list)
    y_out1 = pd.concat(y_out1_list)
    x_out2 = pd.concat(x_out2_list)
    y_out2 = pd.concat(y_out2_list)

    return x_out1, y_out1, x_out2, y_out2










# Read the CSV file
data = pd.read_csv("../data/data/aapl_raw_data.csv")

data = data.drop("date", axis=1)

data.isnull().sum()
data=data.fillna(0)  # Filling null values with zero
data.isnull().sum()

data = data.astype('float32')


# Keep data until 31.08.2023
data = data.iloc[:10731]

#print(data['open'].dtype)
#print(data.shape)

# Assuming 'data' is a pandas DataFrame
x_data = data[['open', 'high', 'low', 'volume', 'adjusted_close', 'change_percent', 'avg_vol_20d']]
y_data = data["close"]

# Now x_data and y_data are pandas DataFrames/Series, respectively

x_data.tail(1)



# Split Data to train and temp

# Define your split_window_size
split_window_size = 3

# Call the split_data_with_window function
x_train, y_train, x_temp, y_temp = split_data_with_window(x_data, y_data, split_window_size)


"""

# Print the last 5 rows of x_data
print("Last 5 rows of x_data:")
print(x_data.tail(5))

# Print the last 5 rows of x_train
print("\nLast 25 rows of x_train:")
print(x_train.tail(25))

print("\nLast 3 rows of y_train:")
print(y_temp.tail(3))

"""

# Split temp into val and test

# Define your split_window_size
split_window_size = 1

# Call the split_data_with_window function
x_val, y_val, x_test, y_test = split_data_with_window(x_temp, y_temp, split_window_size)




scaler = MinMaxScaler()

x_train_normalized = scaler.fit_transform(x_train)
x_val_normalized = scaler.transform(x_val)
x_test_normalized = scaler.transform(x_test)

# Convert the data to PyTorch tensors
x_train_tensor = torch.tensor(x_train_normalized, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).view(-1, 1)

x_val_tensor = torch.tensor(x_val_normalized, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val.values, dtype=torch.float32).view(-1, 1)

x_test_tensor = torch.tensor(x_test_normalized, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).view(-1, 1)


"""
# x_train_tensor inverse

x_test_original = scaler.inverse_transform(x_train_tensor.numpy())
print("\nFirst row of x_test_original:")
print(x_test_original[0])

print("\nFirst row of x_train:")
print(x_train.head(1))



print("\nLast row of x_test_original:")
print(x_test_original[-1])

print("\nLast row of x_train:")
print(x_train.tail(1))
"""









class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, learning_rate, window_size):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.window_size = window_size
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)
        self.learning_rate = learning_rate

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        out, _ = self.lstm(x, (h0, c0))

        out = self.fc(out[:, -1, :])
        return out

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [512]
num_layers_list = [3]

learning_rates = [0.00001]
window_sizes = [20]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=512, num_layers=3, learning_rate=1e-05, window_size=20
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 22433.411305155565, Validation Loss: 21776.1015625
# Epoch [2/800], Training Loss: 20236.986348461658, Validation Loss: 20051.8984375
# Epoch [3/800], Training Loss: 19283.891585590885, Validation Loss: 19211.447265625
# Epoch [4/800], Training Loss: 18798.44123118579, Validation Loss: 18757.388671875
# Epoch [5/800], Training Loss: 18525.202553947296, Validation Loss: 18491.935546875
# Epoch [6/800], Training Loss: 18360.16463226835, Validation Loss: 18327.3671875
# Epoch [7/800], Training Loss: 18255.478529769982, Validation Loss: 18219.99609375
# Epoch [8/800], Training Loss: 18184.64739675737, Validation Loss: 18147.892578125
# Epoch [9/800], Training Loss: 18137.776866277385, Validation Loss: 18098.587890625
# Epoch [10/800], Training Loss: 18104.79254481938, Validation Loss: 18063.95703125
# Epoch [11/800], Training Loss: 18080.119173676725, Validation Loss: 18038.015625
# Epoch [12/800], Training Loss: 18061.709580314757, Validation Loss: 18019.4375
# Epoch [13/800], Training Loss: 18048.61503049088, Validation Loss: 18005.8515625
# Epoch [14/800], Training Loss: 18038.009565487166, Validation Loss: 17995.53125
# Epoch [15/800], Training Loss: 18029.75730143059, Validation Loss: 17987.576171875
# Epoch [16/800], Training Loss: 18021.379961470662, Validation Loss: 17980.064453125
# Epoch [17/800], Training Loss: 18015.019489760296, Validation Loss: 17974.400390625
# Epoch [18/800], Training Loss: 18009.14379191177, Validation Loss: 17969.51953125
# Epoch [19/800], Training Loss: 18004.047859342423, Validation Loss: 17965.314453125
# Epoch [20/800], Training Loss: 17999.153328069377, Validation Loss: 17961.525390625
# Epoch [21/800], Training Loss: 17994.608151633223, Validation Loss: 17957.986328125
# Epoch [22/800], Training Loss: 17990.246898831778, Validation Loss: 17954.724609375
# Epoch [23/800], Training Loss: 17986.13148726772, Validation Loss: 17951.59375
# Epoch [24/800], Training Loss: 17982.29347583614, Validation Loss: 17948.671875
# Epoch [25/800], Training Loss: 17978.07032340376, Validation Loss: 17945.763671875
# Epoch [26/800], Training Loss: 17974.152780544235, Validation Loss: 17942.94140625
# Epoch [27/800], Training Loss: 17970.308606147206, Validation Loss: 17940.185546875
# Epoch [28/800], Training Loss: 17966.446920445236, Validation Loss: 17937.513671875
# Epoch [29/800], Training Loss: 17962.446193706277, Validation Loss: 17934.87890625
# Epoch [30/800], Training Loss: 17958.87183728025, Validation Loss: 17932.35546875
# Epoch [31/800], Training Loss: 17954.75070992027, Validation Loss: 17929.8046875
# Epoch [32/800], Training Loss: 17951.20494800511, Validation Loss: 17927.349609375
# Epoch [33/800], Training Loss: 17947.25500300164, Validation Loss: 17924.875
# Epoch [34/800], Training Loss: 17943.47117952146, Validation Loss: 17922.505859375
# Epoch [35/800], Training Loss: 17939.470694627085, Validation Loss: 17920.126953125
# Epoch [36/800], Training Loss: 17929.8367009104, Validation Loss: 17917.177734375

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [16]
num_layers_list = [3]

learning_rates = [0.00001]
window_sizes = [20]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=16, num_layers=3, learning_rate=1e-05, window_size=20
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 29420.71817247399, Validation Loss: 29757.4375
# Epoch [2/800], Training Loss: 29053.99323709551, Validation Loss: 29478.205078125
# Epoch [3/800], Training Loss: 28812.74459238927, Validation Loss: 29244.736328125
# Epoch [4/800], Training Loss: 28592.0647549455, Validation Loss: 29023.88671875
# Epoch [5/800], Training Loss: 28378.652727579378, Validation Loss: 28808.62890625
# Epoch [6/800], Training Loss: 28169.591602725588, Validation Loss: 28597.357421875
# Epoch [7/800], Training Loss: 27964.20851253604, Validation Loss: 28389.669921875
# Epoch [8/800], Training Loss: 27762.340829814337, Validation Loss: 28185.458984375
# Epoch [9/800], Training Loss: 27563.949065219393, Validation Loss: 27984.751953125
# Epoch [10/800], Training Loss: 27369.000917546447, Validation Loss: 27787.47265625
# Epoch [11/800], Training Loss: 27177.50082904425, Validation Loss: 27593.650390625
# Epoch [12/800], Training Loss: 26989.439703105825, Validation Loss: 27403.302734375
# Epoch [13/800], Training Loss: 26804.79991742584, Validation Loss: 27216.328125
# Epoch [14/800], Training Loss: 26623.572714691658, Validation Loss: 27032.79296875
# Epoch [15/800], Training Loss: 26445.74982043573, Validation Loss: 26852.65625
# Epoch [16/800], Training Loss: 26271.28703536325, Validation Loss: 26675.896484375
# Epoch [17/800], Training Loss: 26100.209967083985, Validation Loss: 26502.490234375
# Epoch [18/800], Training Loss: 25932.467994243314, Validation Loss: 26332.435546875
# Epoch [19/800], Training Loss: 25768.083923771628, Validation Loss: 26165.837890625
# Epoch [20/800], Training Loss: 25606.99810980634, Validation Loss: 26002.431640625
# Epoch [21/800], Training Loss: 25449.1857813166, Validation Loss: 25842.3359375
# Epoch [22/800], Training Loss: 25294.65699865058, Validation Loss: 25685.560546875
# Epoch [23/800], Training Loss: 25143.348130435174, Validation Loss: 25531.990234375
# Epoch [24/800], Training Loss: 24995.259009955094, Validation Loss: 25381.6796875
# Epoch [25/800], Training Loss: 24850.353822505847, Validation Loss: 25234.546875
# Epoch [26/800], Training Loss: 24708.59505551234, Validation Loss: 25090.552734375
# Epoch [27/800], Training Loss: 24569.968729705426, Validation Loss: 24949.71875
# Epoch [28/800], Training Loss: 24434.42419596691, Validation Loss: 24811.984375
# Epoch [29/800], Training Loss: 24301.901202842837, Validation Loss: 24677.28515625
# Epoch [30/800], Training Loss: 24172.39553600627, Validation Loss: 24545.59375
# Epoch [31/800], Training Loss: 24045.84351558451, Validation Loss: 24416.876953125
# Epoch [32/800], Training Loss: 23922.231688166, Validation Loss: 24291.158203125
# Epoch [33/800], Training Loss: 23801.50308925316, Validation Loss: 24168.29296875
# Epoch [34/800], Training Loss: 23683.580190435063, Validation Loss: 24048.259765625
# Epoch [35/800], Training Loss: 23568.456252415137, Validation Loss: 23931.03515625
# Epoch [36/800], Training Loss: 23456.078476146587, Validation Loss: 23816.5625
# Epoch [37/800], Training Loss: 23346.36714857816, Validation Loss: 23704.7734375
# Epoch [38/800], Training Loss: 23239.343308538133, Validation Loss: 23595.689453125
# Epoch [39/800], Training Loss: 23134.916388129543, Validation Loss: 23489.251953125
# Epoch [40/800], Training Loss: 23032.9480212596, Validation Loss: 23385.251953125
# Epoch [41/800], Training Loss: 22933.48261923717, Validation Loss: 23283.783203125
# Epoch [42/800], Training Loss: 22836.44279256155, Validation Loss: 23184.736328125
# Epoch [43/800], Training Loss: 22741.81117877816, Validation Loss: 23088.16015625
# Epoch [44/800], Training Loss: 22649.500289959153, Validation Loss: 22993.89453125
# Epoch [45/800], Training Loss: 22559.45119311362, Validation Loss: 22901.904296875
# Epoch [46/800], Training Loss: 22471.6115625264, Validation Loss: 22812.15234375
# Epoch [47/800], Training Loss: 22385.945135583122, Validation Loss: 22724.6015625
# Epoch [48/800], Training Loss: 22302.379754113455, Validation Loss: 22639.15625
# Epoch [49/800], Training Loss: 22220.91058989227, Validation Loss: 22555.861328125
# Epoch [50/800], Training Loss: 22141.43665110317, Validation Loss: 22474.513671875
# Epoch [51/800], Training Loss: 22063.900814073768, Validation Loss: 22395.1640625
# Epoch [52/800], Training Loss: 21988.267959517867, Validation Loss: 22317.71875
# Epoch [53/800], Training Loss: 21914.469735196704, Validation Loss: 22242.1328125
# Epoch [54/800], Training Loss: 21842.518573279107, Validation Loss: 22168.423828125
# Epoch [55/800], Training Loss: 21772.308743358615, Validation Loss: 22096.470703125
# Epoch [56/800], Training Loss: 21703.804645665856, Validation Loss: 22026.244140625
# Epoch [57/800], Training Loss: 21636.963991913155, Validation Loss: 21957.701171875
# Epoch [58/800], Training Loss: 21571.755834755884, Validation Loss: 21890.81640625
# Epoch [59/800], Training Loss: 21508.098410083712, Validation Loss: 21825.498046875
# Epoch [60/800], Training Loss: 21445.998106037136, Validation Loss: 21761.76953125
# Epoch [61/800], Training Loss: 21385.421526685062, Validation Loss: 21699.5546875
# Epoch [62/800], Training Loss: 21326.27622038203, Validation Loss: 21638.80078125
# Epoch [63/800], Training Loss: 21268.574397902037, Validation Loss: 21579.52734375
# Epoch [64/800], Training Loss: 21212.193454313176, Validation Loss: 21521.5703125
# Epoch [65/800], Training Loss: 21157.17681814361, Validation Loss: 21464.9921875
# Epoch [66/800], Training Loss: 21103.47065346662, Validation Loss: 21409.76953125
# Epoch [67/800], Training Loss: 21050.96661473006, Validation Loss: 21355.732421875
# Epoch [68/800], Training Loss: 20999.664767807815, Validation Loss: 21302.955078125
# Epoch [69/800], Training Loss: 20949.58861485756, Validation Loss: 21251.388671875
# Epoch [70/800], Training Loss: 20900.63640061367, Validation Loss: 21200.98046875
# Epoch [71/800], Training Loss: 20852.811270868984, Validation Loss: 21151.720703125
# Epoch [72/800], Training Loss: 20806.1174338757, Validation Loss: 21103.595703125
# Epoch [73/800], Training Loss: 20760.481185875004, Validation Loss: 21056.55859375
# Epoch [74/800], Training Loss: 20715.865473999216, Validation Loss: 21010.564453125
# Epoch [75/800], Training Loss: 20672.224825993035, Validation Loss: 20965.533203125
# Epoch [76/800], Training Loss: 20629.53865794294, Validation Loss: 20921.51171875
# Epoch [77/800], Training Loss: 20587.851616662112, Validation Loss: 20878.513671875
# Epoch [78/800], Training Loss: 20547.098623117352, Validation Loss: 20836.435546875
# Epoch [79/800], Training Loss: 20507.24873982827, Validation Loss: 20795.27734375
# Epoch [80/800], Training Loss: 20468.282965096652, Validation Loss: 20755.015625
# Epoch [81/800], Training Loss: 20430.174799066885, Validation Loss: 20715.693359375
# Epoch [82/800], Training Loss: 20392.90986642217, Validation Loss: 20677.1640625
# Epoch [83/800], Training Loss: 20356.425425082325, Validation Loss: 20639.4453125
# Epoch [84/800], Training Loss: 20320.705825083918, Validation Loss: 20602.515625
# Epoch [85/800], Training Loss: 20285.741733805386, Validation Loss: 20566.345703125
# Epoch [86/800], Training Loss: 20251.531228041444, Validation Loss: 20530.92578125
# Epoch [87/800], Training Loss: 20218.064386519527, Validation Loss: 20496.287109375
# Epoch [88/800], Training Loss: 20185.294393864846, Validation Loss: 20462.3515625
# Epoch [89/800], Training Loss: 20153.21579746569, Validation Loss: 20429.138671875
# Epoch [90/800], Training Loss: 20121.81038080966, Validation Loss: 20396.5859375
# Epoch [91/800], Training Loss: 20091.02807425359, Validation Loss: 20364.7265625
# Epoch [92/800], Training Loss: 20060.898195892947, Validation Loss: 20333.47265625
# Epoch [93/800], Training Loss: 20031.3820887054, Validation Loss: 20302.87109375
# Epoch [94/800], Training Loss: 20002.458781779198, Validation Loss: 20272.873046875
# Epoch [95/800], Training Loss: 19974.1115389457, Validation Loss: 20243.48046875
# Epoch [96/800], Training Loss: 19946.330764215985, Validation Loss: 20214.666015625
# Epoch [97/800], Training Loss: 19919.104426921822, Validation Loss: 20186.376953125
# Epoch [98/800], Training Loss: 19892.4492821448, Validation Loss: 20158.72265625
# Epoch [99/800], Training Loss: 19866.353814653015, Validation Loss: 20131.607421875
# Epoch [100/800], Training Loss: 19840.767211293914, Validation Loss: 20105.041015625
# Epoch [101/800], Training Loss: 19815.687009512534, Validation Loss: 20078.97265625
# Epoch [102/800], Training Loss: 19791.080335473525, Validation Loss: 20053.404296875
# Epoch [103/800], Training Loss: 19766.95306125245, Validation Loss: 20028.306640625
# Epoch [104/800], Training Loss: 19743.29230959145, Validation Loss: 20003.71875
# Epoch [105/800], Training Loss: 19720.079748119184, Validation Loss: 19979.57421875
# Epoch [106/800], Training Loss: 19697.331198157222, Validation Loss: 19955.8984375
# Epoch [107/800], Training Loss: 19675.01309204092, Validation Loss: 19932.697265625
# Epoch [108/800], Training Loss: 19653.102961464177, Validation Loss: 19909.873046875
# Epoch [109/800], Training Loss: 19631.62359788878, Validation Loss: 19887.517578125
# Epoch [110/800], Training Loss: 19610.5595987616, Validation Loss: 19865.568359375
# Epoch [111/800], Training Loss: 19589.88744413966, Validation Loss: 19844.044921875
# Epoch [112/800], Training Loss: 19569.604796673873, Validation Loss: 19822.900390625
# Epoch [113/800], Training Loss: 19549.73549153729, Validation Loss: 19802.1875
# Epoch [114/800], Training Loss: 19530.208551761272, Validation Loss: 19781.814453125
# Epoch [115/800], Training Loss: 19511.030201545498, Validation Loss: 19761.818359375
# Epoch [116/800], Training Loss: 19492.210357786196, Validation Loss: 19742.1875
# Epoch [117/800], Training Loss: 19473.72204637646, Validation Loss: 19722.900390625
# Epoch [118/800], Training Loss: 19455.562489880565, Validation Loss: 19703.9375
# Epoch [119/800], Training Loss: 19437.743320968704, Validation Loss: 19685.3515625
# Epoch [120/800], Training Loss: 19420.245467936114, Validation Loss: 19667.0703125
# Epoch [121/800], Training Loss: 19403.07505483263, Validation Loss: 19649.142578125
# Epoch [122/800], Training Loss: 19386.238029559034, Validation Loss: 19631.55859375
# Epoch [123/800], Training Loss: 19369.70509944395, Validation Loss: 19614.298828125
# Epoch [124/800], Training Loss: 19353.4796868777, Validation Loss: 19597.34765625
# Epoch [125/800], Training Loss: 19337.56447178134, Validation Loss: 19580.708984375
# Epoch [126/800], Training Loss: 19321.929442172164, Validation Loss: 19564.3515625
# Epoch [127/800], Training Loss: 19306.57967454783, Validation Loss: 19548.30859375
# Epoch [128/800], Training Loss: 19291.484439960328, Validation Loss: 19532.517578125
# Epoch [129/800], Training Loss: 19276.659306678448, Validation Loss: 19516.998046875
# Epoch [130/800], Training Loss: 19262.084014821987, Validation Loss: 19501.732421875
# Epoch [131/800], Training Loss: 19247.76947870488, Validation Loss: 19486.763671875
# Epoch [132/800], Training Loss: 19233.702412586787, Validation Loss: 19472.021484375
# Epoch [133/800], Training Loss: 19219.857445694855, Validation Loss: 19457.529296875
# Epoch [134/800], Training Loss: 19206.249468140242, Validation Loss: 19443.265625
# Epoch [135/800], Training Loss: 19192.859652779756, Validation Loss: 19429.244140625
# Epoch [136/800], Training Loss: 19179.66929595244, Validation Loss: 19415.439453125
# Epoch [137/800], Training Loss: 19166.685062135177, Validation Loss: 19401.814453125
# Epoch [138/800], Training Loss: 19153.919036632986, Validation Loss: 19388.4453125
# Epoch [139/800], Training Loss: 19141.354955174327, Validation Loss: 19375.271484375
# Epoch [140/800], Training Loss: 19129.000201954877, Validation Loss: 19362.302734375
# Epoch [141/800], Training Loss: 19116.873093706654, Validation Loss: 19349.58984375
# Epoch [142/800], Training Loss: 19104.941706043843, Validation Loss: 19337.0625
# Epoch [143/800], Training Loss: 19093.199941114457, Validation Loss: 19324.72265625
# Epoch [144/800], Training Loss: 19081.632583252805, Validation Loss: 19312.58203125
# Epoch [145/800], Training Loss: 19070.276525911497, Validation Loss: 19300.654296875
# Epoch [146/800], Training Loss: 19059.10133387147, Validation Loss: 19288.90625
# Epoch [147/800], Training Loss: 19048.107780089726, Validation Loss: 19277.34765625
# Epoch [148/800], Training Loss: 19037.29434166426, Validation Loss: 19266.009765625
# Epoch [149/800], Training Loss: 19026.637989088238, Validation Loss: 19254.796875
# Epoch [150/800], Training Loss: 19016.15707770866, Validation Loss: 19243.79296875
# Epoch [151/800], Training Loss: 19005.856618119706, Validation Loss: 19232.970703125
# Epoch [152/800], Training Loss: 18995.720442786114, Validation Loss: 19222.296875
# Epoch [153/800], Training Loss: 18985.758747551892, Validation Loss: 19211.8203125
# Epoch [154/800], Training Loss: 18975.974287194404, Validation Loss: 19201.513671875
# Epoch [155/800], Training Loss: 18966.325433364495, Validation Loss: 19191.375
# Epoch [156/800], Training Loss: 18956.82841326973, Validation Loss: 19181.369140625
# Epoch [157/800], Training Loss: 18947.467836178817, Validation Loss: 19171.529296875
# Epoch [158/800], Training Loss: 18938.250439337924, Validation Loss: 19161.826171875
# Epoch [159/800], Training Loss: 18929.18545100104, Validation Loss: 19152.275390625
# Epoch [160/800], Training Loss: 18920.25571842775, Validation Loss: 19142.861328125
# Epoch [161/800], Training Loss: 18911.46265426202, Validation Loss: 19133.60546875
# Epoch [162/800], Training Loss: 18902.82654172928, Validation Loss: 19124.51171875
# Epoch [163/800], Training Loss: 18894.31318723348, Validation Loss: 19115.533203125
# Epoch [164/800], Training Loss: 18885.934216138412, Validation Loss: 19106.701171875
# Epoch [165/800], Training Loss: 18877.68437389238, Validation Loss: 19098.0078125
# Epoch [166/800], Training Loss: 18869.562886240234, Validation Loss: 19089.455078125
# Epoch [167/800], Training Loss: 18861.563728566267, Validation Loss: 19081.01171875
# Epoch [168/800], Training Loss: 18853.693941916536, Validation Loss: 19072.69921875
# Epoch [169/800], Training Loss: 18845.953280523026, Validation Loss: 19064.5546875
# Epoch [170/800], Training Loss: 18838.362235396286, Validation Loss: 19056.525390625
# Epoch [171/800], Training Loss: 18830.865370374428, Validation Loss: 19048.609375
# Epoch [172/800], Training Loss: 18823.485867879823, Validation Loss: 19040.80859375
# Epoch [173/800], Training Loss: 18816.20139671257, Validation Loss: 19033.1171875
# Epoch [174/800], Training Loss: 18809.01558612911, Validation Loss: 19025.548828125
# Epoch [175/800], Training Loss: 18801.92980476523, Validation Loss: 19018.072265625
# Epoch [176/800], Training Loss: 18794.93880502649, Validation Loss: 19010.68359375
# Epoch [177/800], Training Loss: 18788.045369035215, Validation Loss: 19003.404296875
# Epoch [178/800], Training Loss: 18781.24986784859, Validation Loss: 18996.19921875
# Epoch [179/800], Training Loss: 18774.545072217443, Validation Loss: 18989.1328125
# Epoch [180/800], Training Loss: 18767.9398122392, Validation Loss: 18982.140625
# Epoch [181/800], Training Loss: 18761.421942789588, Validation Loss: 18975.248046875
# Epoch [182/800], Training Loss: 18755.001769734918, Validation Loss: 18968.4765625
# Epoch [183/800], Training Loss: 18748.67382303343, Validation Loss: 18961.787109375
# Epoch [184/800], Training Loss: 18742.424587545047, Validation Loss: 18955.16015625
# Epoch [185/800], Training Loss: 18736.265376642936, Validation Loss: 18948.673828125
# Epoch [186/800], Training Loss: 18730.192458077643, Validation Loss: 18942.248046875
# Epoch [187/800], Training Loss: 18724.212985059414, Validation Loss: 18935.923828125
# Epoch [188/800], Training Loss: 18718.306666737775, Validation Loss: 18929.662109375
# Epoch [189/800], Training Loss: 18712.48310237083, Validation Loss: 18923.517578125
# Epoch [190/800], Training Loss: 18706.726987241756, Validation Loss: 18917.4296875
# Epoch [191/800], Training Loss: 18701.059106458833, Validation Loss: 18911.416015625
# Epoch [192/800], Training Loss: 18695.460770366695, Validation Loss: 18905.48046875
# Epoch [193/800], Training Loss: 18689.959524292888, Validation Loss: 18899.67578125
# Epoch [194/800], Training Loss: 18684.51909421447, Validation Loss: 18893.9140625
# Epoch [195/800], Training Loss: 18679.155741655235, Validation Loss: 18888.2421875
# Epoch [196/800], Training Loss: 18673.859766623358, Validation Loss: 18882.638671875
# Epoch [197/800], Training Loss: 18668.655580338374, Validation Loss: 18877.11328125
# Epoch [198/800], Training Loss: 18663.521765678615, Validation Loss: 18871.681640625
# Epoch [199/800], Training Loss: 18658.464282993904, Validation Loss: 18866.3125
# Epoch [200/800], Training Loss: 18653.474693655207, Validation Loss: 18861.0234375
# Epoch [201/800], Training Loss: 18648.56218498759, Validation Loss: 18855.8125
# Epoch [202/800], Training Loss: 18643.720787296264, Validation Loss: 18850.689453125
# Epoch [203/800], Training Loss: 18638.947719311083, Validation Loss: 18845.62890625
# Epoch [204/800], Training Loss: 18634.237717217406, Validation Loss: 18840.642578125
# Epoch [205/800], Training Loss: 18629.617118758164, Validation Loss: 18835.7421875
# Epoch [206/800], Training Loss: 18625.063535660884, Validation Loss: 18830.8984375
# Epoch [207/800], Training Loss: 18620.559765166345, Validation Loss: 18826.12890625
# Epoch [208/800], Training Loss: 18616.117941021, Validation Loss: 18821.400390625
# Epoch [209/800], Training Loss: 18611.73563836589, Validation Loss: 18816.763671875
# Epoch [210/800], Training Loss: 18607.40703874785, Validation Loss: 18812.19140625
# Epoch [211/800], Training Loss: 18603.142717287727, Validation Loss: 18807.6484375
# Epoch [212/800], Training Loss: 18598.94179662638, Validation Loss: 18803.18359375
# Epoch [213/800], Training Loss: 18594.79002365948, Validation Loss: 18798.8125
# Epoch [214/800], Training Loss: 18590.701848278546, Validation Loss: 18794.439453125
# Epoch [215/800], Training Loss: 18586.67226989681, Validation Loss: 18790.181640625
# Epoch [216/800], Training Loss: 18582.704438999877, Validation Loss: 18785.94140625
# Epoch [217/800], Training Loss: 18578.7880214766, Validation Loss: 18781.806640625
# Epoch [218/800], Training Loss: 18574.924810791592, Validation Loss: 18777.689453125
# Epoch [219/800], Training Loss: 18571.107335158627, Validation Loss: 18773.642578125
# Epoch [220/800], Training Loss: 18567.345029942528, Validation Loss: 18769.658203125
# Epoch [221/800], Training Loss: 18563.62891480865, Validation Loss: 18765.701171875
# Epoch [222/800], Training Loss: 18559.961647486365, Validation Loss: 18761.814453125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[73], line 74
#      72 outputs = model(inputs)
#      73 loss = criterion(outputs, labels)
# ---> 74 loss.backward()
#      75 optimizer.step()
#      77 running_loss += loss.item()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\autograd\__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
l

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = []
num_layers_list = [3]

learning_rates = [0.001]
window_sizes = [20]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=4, num_layers=3, learning_rate=0.001, window_size=20
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 23947.149185140705, Validation Loss: 22941.515625
# Epoch [2/800], Training Loss: 20927.54693036099, Validation Loss: 20608.45703125
# Epoch [3/800], Training Loss: 19626.719027719966, Validation Loss: 19495.16796875
# Epoch [4/800], Training Loss: 18992.87244204482, Validation Loss: 18915.14453125
# Epoch [5/800], Training Loss: 18646.919626214603, Validation Loss: 18585.125
# Epoch [6/800], Training Loss: 18442.892194906235, Validation Loss: 18384.97265625
# Epoch [7/800], Training Loss: 18316.022752192937, Validation Loss: 18257.8828125
# Epoch [8/800], Training Loss: 18234.04012335372, Validation Loss: 18174.46484375
# Epoch [9/800], Training Loss: 18179.547604546657, Validation Loss: 18118.337890625
# Epoch [10/800], Training Loss: 18142.582277175377, Validation Loss: 18079.888671875
# Epoch [11/800], Training Loss: 18117.068153405726, Validation Loss: 18053.21484375
# Epoch [12/800], Training Loss: 18099.310080699444, Validation Loss: 18034.51171875
# Epoch [13/800], Training Loss: 18086.803725401664, Validation Loss: 18021.322265625
# Epoch [14/800], Training Loss: 18077.967117160806, Validation Loss: 18011.947265625
# Epoch [15/800], Training Loss: 18071.699868478932, Validation Loss: 18005.275390625
# Epoch [16/800], Training Loss: 18067.22539074618, Validation Loss: 18000.505859375
# Epoch [17/800], Training Loss: 18064.0274282385, Validation Loss: 17997.09765625
# Epoch [18/800], Training Loss: 18061.729477332326, Validation Loss: 17994.65234375
# Epoch [19/800], Training Loss: 18060.09208200181, Validation Loss: 17992.921875
# Epoch [20/800], Training Loss: 18058.91171401497, Validation Loss: 17991.650390625
# Epoch [21/800], Training Loss: 18058.060321069348, Validation Loss: 17990.744140625
# Epoch [22/800], Training Loss: 18057.439989153292, Validation Loss: 17990.123046875
# Epoch [23/800], Training Loss: 18056.99480620175, Validation Loss: 17989.642578125
# Epoch [24/800], Training Loss: 18056.69615604617, Validation Loss: 17989.30078125
# Epoch [25/800], Training Loss: 18056.460987796374, Validation Loss: 17989.068359375
# Epoch [26/800], Training Loss: 18056.303285969323, Validation Loss: 17988.865234375
# Epoch [27/800], Training Loss: 18056.193216288193, Validation Loss: 17988.7578125
# Epoch [28/800], Training Loss: 18056.108422354544, Validation Loss: 17988.673828125
# Epoch [29/800], Training Loss: 18056.0498729576, Validation Loss: 17988.61328125
# Epoch [30/800], Training Loss: 18056.010044879557, Validation Loss: 17988.55859375
# Epoch [31/800], Training Loss: 18055.98104175535, Validation Loss: 17988.51953125
# Epoch [32/800], Training Loss: 18055.95927539906, Validation Loss: 17988.51171875
# Epoch [33/800], Training Loss: 18055.945117544685, Validation Loss: 17988.494140625
# Epoch [34/800], Training Loss: 18055.93219726094, Validation Loss: 17988.462890625
# Epoch [35/800], Training Loss: 18055.924786455133, Validation Loss: 17988.451171875
# Epoch [36/800], Training Loss: 18055.919477973315, Validation Loss: 17988.4453125
# Epoch [37/800], Training Loss: 18055.915764406534, Validation Loss: 17988.44140625
# Epoch [38/800], Training Loss: 18055.912554098893, Validation Loss: 17988.435546875
# Epoch [39/800], Training Loss: 18055.909503700066, Validation Loss: 17988.435546875
# Epoch [40/800], Training Loss: 18055.907757211622, Validation Loss: 17988.4375
# Epoch [41/800], Training Loss: 18055.90566986575, Validation Loss: 17988.43359375
# Epoch [42/800], Training Loss: 18055.904529695115, Validation Loss: 17988.435546875
# Epoch [43/800], Training Loss: 18055.904106035574, Validation Loss: 17988.431640625
# Epoch [44/800], Training Loss: 18055.90468100027, Validation Loss: 17988.431640625
# Epoch [45/800], Training Loss: 18055.904011301103, Validation Loss: 17988.431640625
# Epoch [46/800], Training Loss: 18055.90365920525, Validation Loss: 17988.431640625
# Epoch [47/800], Training Loss: 18055.9043391908, Validation Loss: 17988.431640625
# Epoch [48/800], Training Loss: 18055.90429826096, Validation Loss: 17988.431640625
# Epoch [49/800], Training Loss: 18055.90382891691, Validation Loss: 17988.431640625
# Epoch [50/800], Training Loss: 18055.903667083236, Validation Loss: 17988.431640625
# Epoch [51/800], Training Loss: 18055.904391629847, Validation Loss: 17988.431640625
# Epoch [52/800], Training Loss: 18055.90448910261, Validation Loss: 17988.431640625
# Epoch [53/800], Training Loss: 18055.90393695579, Validation Loss: 17988.431640625
# Epoch [54/800], Training Loss: 18055.90469098227, Validation Loss: 17988.431640625
# Epoch [55/800], Training Loss: 18055.90467330949, Validation Loss: 17988.431640625
# Early stopping at epoch 55
# Final Test Loss: 17826.7109375

# %%
k
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 k
#
# NameError: name 'k' is not defined

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [8]
num_layers_list = [3]

learning_rates = [0.001]
window_sizes = [20]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=8, num_layers=3, learning_rate=0.001, window_size=20
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 20795.395852865076, Validation Loss: 19851.51953125
# Epoch [2/800], Training Loss: 18626.48581811203, Validation Loss: 18471.427734375
# Epoch [3/800], Training Loss: 18140.588277727995, Validation Loss: 18036.13671875
# Epoch [4/800], Training Loss: 17971.295685627872, Validation Loss: 17863.013671875
# Epoch [5/800], Training Loss: 17900.21907401281, Validation Loss: 17784.3046875
# Epoch [6/800], Training Loss: 17866.98962483465, Validation Loss: 17745.5078125
# Epoch [7/800], Training Loss: 17850.312841193354, Validation Loss: 17725.43359375
# Epoch [8/800], Training Loss: 17841.665603744044, Validation Loss: 17714.787109375
# Epoch [9/800], Training Loss: 17837.0411202345, Validation Loss: 17709.015625
# Epoch [10/800], Training Loss: 17834.55514303947, Validation Loss: 17705.87109375
# Epoch [11/800], Training Loss: 17833.198239528847, Validation Loss: 17704.154296875
# Epoch [12/800], Training Loss: 17832.452396473647, Validation Loss: 17703.2421875
# Epoch [13/800], Training Loss: 17832.04168083997, Validation Loss: 17702.6953125
# Epoch [14/800], Training Loss: 17831.80473403, Validation Loss: 17702.412109375
# Epoch [15/800], Training Loss: 17831.713691963945, Validation Loss: 17702.2421875
# Epoch [16/800], Training Loss: 17831.64349149595, Validation Loss: 17702.162109375
# Epoch [17/800], Training Loss: 17831.606976256975, Validation Loss: 17702.123046875
# Epoch [18/800], Training Loss: 17831.591413115264, Validation Loss: 17702.10546875
# Epoch [19/800], Training Loss: 17831.578004807692, Validation Loss: 17702.091796875
# Epoch [20/800], Training Loss: 17831.569371765523, Validation Loss: 17702.087890625
# Epoch [21/800], Training Loss: 17831.56465246081, Validation Loss: 17702.076171875
# Epoch [22/800], Training Loss: 17831.562215965725, Validation Loss: 17702.072265625
# Epoch [23/800], Training Loss: 17831.55940539191, Validation Loss: 17702.072265625
# Epoch [24/800], Training Loss: 17831.55831199632, Validation Loss: 17702.0703125
# Epoch [25/800], Training Loss: 17831.55778734893, Validation Loss: 17702.0703125
# Epoch [26/800], Training Loss: 17831.557124012357, Validation Loss: 17702.072265625
# Epoch [27/800], Training Loss: 17831.556363820866, Validation Loss: 17702.0703125
# Epoch [28/800], Training Loss: 17831.55650408894, Validation Loss: 17702.0703125
# Epoch [29/800], Training Loss: 17831.556966709064, Validation Loss: 17702.072265625
# Epoch [30/800], Training Loss: 17831.55671659626, Validation Loss: 17702.072265625
# Epoch [31/800], Training Loss: 17831.556498700193, Validation Loss: 17702.072265625
# Epoch [32/800], Training Loss: 17831.55713735128, Validation Loss: 17702.072265625
# Epoch [33/800], Training Loss: 17831.556513115273, Validation Loss: 17702.072265625
# Early stopping at epoch 33
# Final Test Loss: 17543.240234375

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [16]
num_layers_list = [4]

learning_rates = [0.001]
window_sizes = [20]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=16, num_layers=4, learning_rate=0.001, window_size=20
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 17446.092748820676, Validation Loss: 17703.365234375
# Epoch [2/800], Training Loss: 17151.0050168845, Validation Loss: 17478.1328125
# Epoch [3/800], Training Loss: 17233.28564545485, Validation Loss: 17458.12890625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 72
#      69 labels = y_train_tensor[window_end - 1]
#      71 optimizer.zero_grad()
# ---> 72 outputs = model(inputs)
#      73 loss = criterion(outputs, labels)
#      74 loss.backward()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[59], line 181, in LSTMModel.forward(self, x)
#     178 h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
#     179 c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
# --> 181 out, _ = self.lstm(x, (h0, c0))
#     183 out = self.fc(out[:, -1, :])
#     184 return out
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\rnn.py:878, in LSTM.forward(self, input, hx)
#     875         hx = self.permute_hidden(hx, sorted_indices)
#     877 if batch_sizes is None:
# --> 878     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     879                       self.dropout, self.training, self.bidirectional, self.batch_first)
#     880 else:
#     881     result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     882                       self.num_layers, self.dropout, self.training, self.bidirectional)
#
# KeyboardInterrupt:

# %%
,

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [16]
num_layers_list = [3]

learning_rates = [0.001]
window_sizes = [20]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=16, num_layers=3, learning_rate=0.001, window_size=20
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 17431.451943613607, Validation Loss: 17701.314453125
# Epoch [2/800], Training Loss: 17151.41680499465, Validation Loss: 17478.208984375
# Epoch [3/800], Training Loss: 17233.43021852241, Validation Loss: 17458.123046875
# Epoch [4/800], Training Loss: 17263.15762999285, Validation Loss: 17455.537109375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 75
#      73     loss = criterion(outputs, labels)
#      74     loss.backward()
# ---> 75     optimizer.step()
#      77     running_loss += loss.item()
#      79 model.eval()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:166, in Adam.step(self, closure)
#     155     beta1, beta2 = group['betas']
#     157     has_complex = self._init_group(
#     158         group,
#     159         params_with_grad,
#    (...)
#     163         max_exp_avg_sqs,
#     164         state_steps)
# --> 166     adam(
#     167         params_with_grad,
#     168         grads,
#     169         exp_avgs,
#     170         exp_avg_sqs,
#     171         max_exp_avg_sqs,
#     172         state_steps,
#     173         amsgrad=group['amsgrad'],
#     174         has_complex=has_complex,
#     175         beta1=beta1,
#     176         beta2=beta2,
#     177         lr=group['lr'],
#     178         weight_decay=group['weight_decay'],
#     179         eps=group['eps'],
#     180         maximize=group['maximize'],
#     181         foreach=group['foreach'],
#     182         capturable=group['capturable'],
#     183         differentiable=group['differentiable'],
#     184         fused=group['fused'],
#     185         grad_scale=getattr(self, "grad_scale", None),
#     186         found_inf=getattr(self, "found_inf", None),
#     187     )
#     189 return loss
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:316, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     313 else:
#     314     func = _single_tensor_adam
# --> 316 func(params,
#     317      grads,
#     318      exp_avgs,
#     319      exp_avg_sqs,
#     320      max_exp_avg_sqs,
#     321      state_steps,
#     322      amsgrad=amsgrad,
#     323      has_complex=has_complex,
#     324      beta1=beta1,
#     325      beta2=beta2,
#     326      lr=lr,
#     327      weight_decay=weight_decay,
#     328      eps=eps,
#     329      maximize=maximize,
#     330      capturable=capturable,
#     331      differentiable=differentiable,
#     332      grad_scale=grad_scale,
#     333      found_inf=found_inf)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:439, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     437         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     438     else:
# --> 439         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     441     param.addcdiv_(exp_avg, denom, value=-step_size)
#     443 # Lastly, switch back to complex view
#
# KeyboardInterrupt:

# %%
,

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [16]
num_layers_list = [3]

learning_rates = [0.00001]
window_sizes = [20]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=16, num_layers=3, learning_rate=1e-05, window_size=20
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 29420.71817247399, Validation Loss: 29757.4375
# Epoch [2/800], Training Loss: 29053.99323709551, Validation Loss: 29478.205078125
# Epoch [3/800], Training Loss: 28812.74459238927, Validation Loss: 29244.736328125
# Epoch [4/800], Training Loss: 28592.0647549455, Validation Loss: 29023.88671875
# Epoch [5/800], Training Loss: 28378.652727579378, Validation Loss: 28808.62890625
# Epoch [6/800], Training Loss: 28169.591602725588, Validation Loss: 28597.357421875
# Epoch [7/800], Training Loss: 27964.20851253604, Validation Loss: 28389.669921875
# Epoch [8/800], Training Loss: 27762.340829814337, Validation Loss: 28185.458984375
# Epoch [9/800], Training Loss: 27563.949065219393, Validation Loss: 27984.751953125
# Epoch [10/800], Training Loss: 27369.000917546447, Validation Loss: 27787.47265625
# Epoch [11/800], Training Loss: 27177.50082904425, Validation Loss: 27593.650390625
# Epoch [12/800], Training Loss: 26989.439703105825, Validation Loss: 27403.302734375
# Epoch [13/800], Training Loss: 26804.79991742584, Validation Loss: 27216.328125
# Epoch [14/800], Training Loss: 26623.572714691658, Validation Loss: 27032.79296875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 75
#      73     loss = criterion(outputs, labels)
#      74     loss.backward()
# ---> 75     optimizer.step()
#      77     running_loss += loss.item()
#      79 model.eval()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:166, in Adam.step(self, closure)
#     155     beta1, beta2 = group['betas']
#     157     has_complex = self._init_group(
#     158         group,
#     159         params_with_grad,
#    (...)
#     163         max_exp_avg_sqs,
#     164         state_steps)
# --> 166     adam(
#     167         params_with_grad,
#     168         grads,
#     169         exp_avgs,
#     170         exp_avg_sqs,
#     171         max_exp_avg_sqs,
#     172         state_steps,
#     173         amsgrad=group['amsgrad'],
#     174         has_complex=has_complex,
#     175         beta1=beta1,
#     176         beta2=beta2,
#     177         lr=group['lr'],
#     178         weight_decay=group['weight_decay'],
#     179         eps=group['eps'],
#     180         maximize=group['maximize'],
#     181         foreach=group['foreach'],
#     182         capturable=group['capturable'],
#     183         differentiable=group['differentiable'],
#     184         fused=group['fused'],
#     185         grad_scale=getattr(self, "grad_scale", None),
#     186         found_inf=getattr(self, "found_inf", None),
#     187     )
#     189 return loss
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:316, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     313 else:
#     314     func = _single_tensor_adam
# --> 316 func(params,
#     317      grads,
#     318      exp_avgs,
#     319      exp_avg_sqs,
#     320      max_exp_avg_sqs,
#     321      state_steps,
#     322      amsgrad=amsgrad,
#     323      has_complex=has_complex,
#     324      beta1=beta1,
#     325      beta2=beta2,
#     326      lr=lr,
#     327      weight_decay=weight_decay,
#     328      eps=eps,
#     329      maximize=maximize,
#     330      capturable=capturable,
#     331      differentiable=differentiable,
#     332      grad_scale=grad_scale,
#     333      found_inf=found_inf)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:391, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     388     param = torch.view_as_real(param)
#     390 # Decay the first and second moment running average coefficient
# --> 391 exp_avg.lerp_(grad, 1 - beta1)
#     392 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     394 if capturable or differentiable:
#
# KeyboardInterrupt:

# %%
m

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [16]
num_layers_list = [3]

learning_rates = [0.00005]
window_sizes = [20]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=16, num_layers=3, learning_rate=5e-05, window_size=20
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 28282.712377878674, Validation Loss: 28371.990234375
# Epoch [2/800], Training Loss: 27228.59239858491, Validation Loss: 27379.50390625
# Epoch [3/800], Training Loss: 26306.619314942454, Validation Loss: 26472.197265625
# Epoch [4/800], Training Loss: 25469.56535021456, Validation Loss: 25648.0625
# Epoch [5/800], Training Loss: 24715.08216176997, Validation Loss: 24904.703125
# Epoch [6/800], Training Loss: 24039.775655850342, Validation Loss: 24238.544921875
# Epoch [7/800], Training Loss: 23439.041192796903, Validation Loss: 23644.916015625
# Epoch [8/800], Training Loss: 22907.21652250411, Validation Loss: 23118.28125
# Epoch [9/800], Training Loss: 22437.86666594825, Validation Loss: 22652.33203125
# Epoch [10/800], Training Loss: 22024.262949199867, Validation Loss: 22240.556640625
# Epoch [11/800], Training Loss: 21659.762306203986, Validation Loss: 21876.61328125
# Epoch [12/800], Training Loss: 21338.16261775608, Validation Loss: 21554.53515625
# Epoch [13/800], Training Loss: 21053.80039052322, Validation Loss: 21268.974609375
# Epoch [14/800], Training Loss: 20801.72529320354, Validation Loss: 21015.103515625
# Epoch [15/800], Training Loss: 20577.63613288354, Validation Loss: 20788.837890625
# Epoch [16/800], Training Loss: 20377.81144701607, Validation Loss: 20586.541015625
# Epoch [17/800], Training Loss: 20199.11895693853, Validation Loss: 20405.2421875
# Epoch [18/800], Training Loss: 20038.81188889234, Validation Loss: 20242.1875
# Epoch [19/800], Training Loss: 19894.596308573626, Validation Loss: 20095.197265625
# Epoch [20/800], Training Loss: 19764.500741023374, Validation Loss: 19962.328125
# Epoch [21/800], Training Loss: 19646.853644970157, Validation Loss: 19841.90625
# Epoch [22/800], Training Loss: 19540.19027013695, Validation Loss: 19732.533203125
# Epoch [23/800], Training Loss: 19443.266269321113, Validation Loss: 19632.96875
# Epoch [24/800], Training Loss: 19355.010950167987, Validation Loss: 19542.15625
# Epoch [25/800], Training Loss: 19274.444240239325, Validation Loss: 19459.1015625
# Epoch [26/800], Training Loss: 19200.81724931804, Validation Loss: 19383.09375
# Epoch [27/800], Training Loss: 19133.381098127928, Validation Loss: 19313.31640625
# Epoch [28/800], Training Loss: 19071.476101199965, Validation Loss: 19249.216796875
# Epoch [29/800], Training Loss: 19014.620291555875, Validation Loss: 19190.244140625
# Epoch [30/800], Training Loss: 18962.270809609487, Validation Loss: 19135.875
# Epoch [31/800], Training Loss: 18913.96473786793, Validation Loss: 19085.65625
# Epoch [32/800], Training Loss: 18869.467474859368, Validation Loss: 19039.3125
# Epoch [33/800], Training Loss: 18828.332143142863, Validation Loss: 18996.40234375
# Epoch [34/800], Training Loss: 18790.225037082026, Validation Loss: 18956.630859375
# Epoch [35/800], Training Loss: 18754.940978169998, Validation Loss: 18919.763671875
# Epoch [36/800], Training Loss: 18722.192953195674, Validation Loss: 18885.505859375
# Epoch [37/800], Training Loss: 18691.810315051294, Validation Loss: 18853.72265625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 75
#      73     loss = criterion(outputs, labels)
#      74     loss.backward()
# ---> 75     optimizer.step()
#      77     running_loss += loss.item()
#      79 model.eval()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:166, in Adam.step(self, closure)
#     155     beta1, beta2 = group['betas']
#     157     has_complex = self._init_group(
#     158         group,
#     159         params_with_grad,
#    (...)
#     163         max_exp_avg_sqs,
#     164         state_steps)
# --> 166     adam(
#     167         params_with_grad,
#     168         grads,
#     169         exp_avgs,
#     170         exp_avg_sqs,
#     171         max_exp_avg_sqs,
#     172         state_steps,
#     173         amsgrad=group['amsgrad'],
#     174         has_complex=has_complex,
#     175         beta1=beta1,
#     176         beta2=beta2,
#     177         lr=group['lr'],
#     178         weight_decay=group['weight_decay'],
#     179         eps=group['eps'],
#     180         maximize=group['maximize'],
#     181         foreach=group['foreach'],
#     182         capturable=group['capturable'],
#     183         differentiable=group['differentiable'],
#     184         fused=group['fused'],
#     185         grad_scale=getattr(self, "grad_scale", None),
#     186         found_inf=getattr(self, "found_inf", None),
#     187     )
#     189 return loss
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:316, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     313 else:
#     314     func = _single_tensor_adam
# --> 316 func(params,
#     317      grads,
#     318      exp_avgs,
#     319      exp_avg_sqs,
#     320      max_exp_avg_sqs,
#     321      state_steps,
#     322      amsgrad=amsgrad,
#     323      has_complex=has_complex,
#     324      beta1=beta1,
#     325      beta2=beta2,
#     326      lr=lr,
#     327      weight_decay=weight_decay,
#     328      eps=eps,
#     329      maximize=maximize,
#     330      capturable=capturable,
#     331      differentiable=differentiable,
#     332      grad_scale=grad_scale,
#     333      found_inf=found_inf)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:382, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     379 if weight_decay != 0:
#     380     grad = grad.add(param, alpha=weight_decay)
# --> 382 if torch.is_complex(param):
#     383     grad = torch.view_as_real(grad)
#     384     exp_avg = torch.view_as_real(exp_avg)
#
# KeyboardInterrupt:

# %%
o

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [16]
num_layers_list = [3]

learning_rates = [0.0001]
window_sizes = [20]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=16, num_layers=3, learning_rate=0.0001, window_size=20
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 27185.03288132309, Validation Loss: 26943.6953125
# Epoch [2/800], Training Loss: 25355.56001287789, Validation Loss: 25266.04296875
# Epoch [3/800], Training Loss: 23919.057554871473, Validation Loss: 23903.529296875
# Epoch [4/800], Training Loss: 22783.71044427202, Validation Loss: 22823.181640625
# Epoch [5/800], Training Loss: 21902.191045357642, Validation Loss: 21978.533203125
# Epoch [6/800], Training Loss: 21220.65698116605, Validation Loss: 21319.564453125
# Epoch [7/800], Training Loss: 20690.558289637833, Validation Loss: 20802.248046875
# Epoch [8/800], Training Loss: 20273.60657285583, Validation Loss: 20391.828125
# Epoch [9/800], Training Loss: 19941.477110582393, Validation Loss: 20062.48828125
# Epoch [10/800], Training Loss: 19673.688284859414, Validation Loss: 19795.142578125
# Epoch [11/800], Training Loss: 19455.37531588487, Validation Loss: 19575.921875
# Epoch [12/800], Training Loss: 19275.62472923316, Validation Loss: 19394.462890625
# Epoch [13/800], Training Loss: 19126.289857358333, Validation Loss: 19243.025390625
# Epoch [14/800], Training Loss: 19001.313408790855, Validation Loss: 19115.716796875
# Epoch [15/800], Training Loss: 18895.975868472044, Validation Loss: 19007.978515625
# Epoch [16/800], Training Loss: 18806.614837001307, Validation Loss: 18916.287109375
# Epoch [17/800], Training Loss: 18730.449362296553, Validation Loss: 18837.88671875
# Epoch [18/800], Training Loss: 18665.199169412637, Validation Loss: 18770.51171875
# Epoch [19/800], Training Loss: 18609.054375164313, Validation Loss: 18712.376953125
# Epoch [20/800], Training Loss: 18560.494149663424, Validation Loss: 18662.00390625
# Epoch [21/800], Training Loss: 18518.437503023466, Validation Loss: 18618.251953125
# Epoch [22/800], Training Loss: 18481.90920628846, Validation Loss: 18580.13671875
# Epoch [23/800], Training Loss: 18449.994582211246, Validation Loss: 18546.84765625
# Epoch [24/800], Training Loss: 18422.11989858645, Validation Loss: 18517.68359375
# Epoch [25/800], Training Loss: 18397.680803932326, Validation Loss: 18492.09765625
# Epoch [26/800], Training Loss: 18376.22982710378, Validation Loss: 18469.60546875
# Epoch [27/800], Training Loss: 18357.322650401195, Validation Loss: 18449.76953125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 88
#      85         inputs = x_val_tensor[i:window_end].unsqueeze(0)
#      86         labels = y_val_tensor[window_end - 1]
# ---> 88         outputs = model(inputs)
#      89         val_loss += criterion(outputs, labels)
#      92 # Early stopping based on validation loss
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[51], line 181, in LSTMModel.forward(self, x)
#     178 h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
#     179 c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
# --> 181 out, _ = self.lstm(x, (h0, c0))
#     183 out = self.fc(out[:, -1, :])
#     184 return out
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\rnn.py:878, in LSTM.forward(self, input, hx)
#     875         hx = self.permute_hidden(hx, sorted_indices)
#     877 if batch_sizes is None:
# --> 878     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     879                       self.dropout, self.training, self.bidirectional, self.batch_first)
#     880 else:
#     881     result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     882                       self.num_layers, self.dropout, self.training, self.bidirectional)
#
# KeyboardInterrupt:

# %%
m

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [16]
num_layers_list = [3]

learning_rates = [0.001]
window_sizes = [20]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=16, num_layers=3, learning_rate=0.001, window_size=20
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 17431.451943613607, Validation Loss: 17701.314453125
# Epoch [2/800], Training Loss: 17151.41680499465, Validation Loss: 17478.208984375
# Epoch [3/800], Training Loss: 17233.43021852241, Validation Loss: 17458.123046875
# Epoch [4/800], Training Loss: 17263.15762999285, Validation Loss: 17455.537109375
# Epoch [5/800], Training Loss: 17272.678859125182, Validation Loss: 17455.05078125
# Epoch [6/800], Training Loss: 17275.642455180347, Validation Loss: 17454.8671875
# Epoch [7/800], Training Loss: 17276.56844007667, Validation Loss: 17454.830078125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 68
#      66 for i in range(len(x_train_tensor)):
#      67     window_end = min(i + window_size, len(x_train_tensor))
# ---> 68     inputs = x_train_tensor[i:window_end].unsqueeze(0)
#      69     labels = y_train_tensor[window_end - 1]
#      71     optimizer.zero_grad()
#
# KeyboardInterrupt:

# %%
l

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [32]
num_layers_list = [3]

learning_rates = [0.001]
window_sizes = [20]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=32, num_layers=3, learning_rate=0.001, window_size=20
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 13503.23087822501, Validation Loss: 17893.7890625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 75
#      73     loss = criterion(outputs, labels)
#      74     loss.backward()
# ---> 75     optimizer.step()
#      77     running_loss += loss.item()
#      79 model.eval()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:166, in Adam.step(self, closure)
#     155     beta1, beta2 = group['betas']
#     157     has_complex = self._init_group(
#     158         group,
#     159         params_with_grad,
#    (...)
#     163         max_exp_avg_sqs,
#     164         state_steps)
# --> 166     adam(
#     167         params_with_grad,
#     168         grads,
#     169         exp_avgs,
#     170         exp_avg_sqs,
#     171         max_exp_avg_sqs,
#     172         state_steps,
#     173         amsgrad=group['amsgrad'],
#     174         has_complex=has_complex,
#     175         beta1=beta1,
#     176         beta2=beta2,
#     177         lr=group['lr'],
#     178         weight_decay=group['weight_decay'],
#     179         eps=group['eps'],
#     180         maximize=group['maximize'],
#     181         foreach=group['foreach'],
#     182         capturable=group['capturable'],
#     183         differentiable=group['differentiable'],
#     184         fused=group['fused'],
#     185         grad_scale=getattr(self, "grad_scale", None),
#     186         found_inf=getattr(self, "found_inf", None),
#     187     )
#     189 return loss
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:316, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     313 else:
#     314     func = _single_tensor_adam
# --> 316 func(params,
#     317      grads,
#     318      exp_avgs,
#     319      exp_avg_sqs,
#     320      max_exp_avg_sqs,
#     321      state_steps,
#     322      amsgrad=amsgrad,
#     323      has_complex=has_complex,
#     324      beta1=beta1,
#     325      beta2=beta2,
#     326      lr=lr,
#     327      weight_decay=weight_decay,
#     328      eps=eps,
#     329      maximize=maximize,
#     330      capturable=capturable,
#     331      differentiable=differentiable,
#     332      grad_scale=grad_scale,
#     333      found_inf=found_inf)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:439, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     437         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     438     else:
# --> 439         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     441     param.addcdiv_(exp_avg, denom, value=-step_size)
#     443 # Lastly, switch back to complex view
#
# KeyboardInterrupt:

# %%
l

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [256]
num_layers_list = [3]

learning_rates = [0.001]
window_sizes = [20]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=256, num_layers=3, learning_rate=0.001, window_size=20
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 4112.87679528407, Validation Loss: 19275.603515625
# Epoch [2/800], Training Loss: 4697.796374721523, Validation Loss: 21023.45703125
# Epoch [3/800], Training Loss: 2006.3851127083446, Validation Loss: 20951.22265625
# Epoch [4/800], Training Loss: 1259.1857546761803, Validation Loss: 22004.703125
# Epoch [5/800], Training Loss: 1339.6613811855852, Validation Loss: 23533.001953125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 75
#      73     loss = criterion(outputs, labels)
#      74     loss.backward()
# ---> 75     optimizer.step()
#      77     running_loss += loss.item()
#      79 model.eval()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:166, in Adam.step(self, closure)
#     155     beta1, beta2 = group['betas']
#     157     has_complex = self._init_group(
#     158         group,
#     159         params_with_grad,
#    (...)
#     163         max_exp_avg_sqs,
#     164         state_steps)
# --> 166     adam(
#     167         params_with_grad,
#     168         grads,
#     169         exp_avgs,
#     170         exp_avg_sqs,
#     171         max_exp_avg_sqs,
#     172         state_steps,
#     173         amsgrad=group['amsgrad'],
#     174         has_complex=has_complex,
#     175         beta1=beta1,
#     176         beta2=beta2,
#     177         lr=group['lr'],
#     178         weight_decay=group['weight_decay'],
#     179         eps=group['eps'],
#     180         maximize=group['maximize'],
#     181         foreach=group['foreach'],
#     182         capturable=group['capturable'],
#     183         differentiable=group['differentiable'],
#     184         fused=group['fused'],
#     185         grad_scale=getattr(self, "grad_scale", None),
#     186         found_inf=getattr(self, "found_inf", None),
#     187     )
#     189 return loss
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:316, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     313 else:
#     314     func = _single_tensor_adam
# --> 316 func(params,
#     317      grads,
#     318      exp_avgs,
#     319      exp_avg_sqs,
#     320      max_exp_avg_sqs,
#     321      state_steps,
#     322      amsgrad=amsgrad,
#     323      has_complex=has_complex,
#     324      beta1=beta1,
#     325      beta2=beta2,
#     326      lr=lr,
#     327      weight_decay=weight_decay,
#     328      eps=eps,
#     329      maximize=maximize,
#     330      capturable=capturable,
#     331      differentiable=differentiable,
#     332      grad_scale=grad_scale,
#     333      found_inf=found_inf)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:439, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     437         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     438     else:
# --> 439         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     441     param.addcdiv_(exp_avg, denom, value=-step_size)
#     443 # Lastly, switch back to complex view
#
# KeyboardInterrupt:

# %%
p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 p
#
# NameError: name 'p' is not defined

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [128]
num_layers_list = [3]

learning_rates = [0.00001]
window_sizes = [10]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=128, num_layers=3, learning_rate=1e-05, window_size=10
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 27017.25567229805, Validation Loss: 26769.623046875
# Epoch [2/800], Training Loss: 25623.97183518767, Validation Loss: 25492.396484375
# Epoch [3/800], Training Loss: 24470.0112164961, Validation Loss: 24392.611328125
# Epoch [4/800], Training Loss: 23500.893896414593, Validation Loss: 23467.3203125
# Epoch [5/800], Training Loss: 22695.131246181176, Validation Loss: 22695.970703125
# Epoch [6/800], Training Loss: 22030.30283635899, Validation Loss: 22057.005859375
# Epoch [7/800], Training Loss: 21482.78625422362, Validation Loss: 21528.318359375
# Epoch [8/800], Training Loss: 21030.653159191817, Validation Loss: 21089.578125
# Epoch [9/800], Training Loss: 20655.227444088938, Validation Loss: 20723.548828125
# Epoch [10/800], Training Loss: 20341.358995878545, Validation Loss: 20416.234375
# Epoch [11/800], Training Loss: 20077.102803588743, Validation Loss: 20156.45703125
# Epoch [12/800], Training Loss: 19853.03843180935, Validation Loss: 19935.4296875
# Epoch [13/800], Training Loss: 19661.80035748031, Validation Loss: 19746.154296875
# Epoch [14/800], Training Loss: 19497.60519638704, Validation Loss: 19583.154296875
# Epoch [15/800], Training Loss: 19355.82188736574, Validation Loss: 19442.037109375
# Epoch [16/800], Training Loss: 19232.80369551542, Validation Loss: 19319.271484375
# Epoch [17/800], Training Loss: 19125.5189453551, Validation Loss: 19211.98046875
# Epoch [18/800], Training Loss: 19031.635762962484, Validation Loss: 19117.845703125
# Epoch [19/800], Training Loss: 18949.076031545796, Validation Loss: 19034.916015625
# Epoch [20/800], Training Loss: 18876.29604108975, Validation Loss: 18961.64453125
# Epoch [21/800], Training Loss: 18811.85643077932, Validation Loss: 18896.68359375
# Epoch [22/800], Training Loss: 18754.724019443944, Validation Loss: 18838.943359375
# Epoch [23/800], Training Loss: 18703.80807805975, Validation Loss: 18787.431640625
# Epoch [24/800], Training Loss: 18658.40840746845, Validation Loss: 18741.390625
# Epoch [25/800], Training Loss: 18617.80906667855, Validation Loss: 18700.16796875
# Epoch [26/800], Training Loss: 18581.456569582417, Validation Loss: 18663.1953125
# Epoch [27/800], Training Loss: 18548.79944751717, Validation Loss: 18629.955078125
# Epoch [28/800], Training Loss: 18519.419321995923, Validation Loss: 18599.986328125
# Epoch [29/800], Training Loss: 18492.93855410642, Validation Loss: 18572.94140625
# Epoch [30/800], Training Loss: 18469.058715606523, Validation Loss: 18548.490234375
# Epoch [31/800], Training Loss: 18447.5269558386, Validation Loss: 18526.396484375
# Epoch [32/800], Training Loss: 18427.97354452795, Validation Loss: 18506.349609375
# Epoch [33/800], Training Loss: 18410.2930386153, Validation Loss: 18488.1640625
# Epoch [34/800], Training Loss: 18394.224822260057, Validation Loss: 18471.591796875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 75
#      73     loss = criterion(outputs, labels)
#      74     loss.backward()
# ---> 75     optimizer.step()
#      77     running_loss += loss.item()
#      79 model.eval()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:166, in Adam.step(self, closure)
#     155     beta1, beta2 = group['betas']
#     157     has_complex = self._init_group(
#     158         group,
#     159         params_with_grad,
#    (...)
#     163         max_exp_avg_sqs,
#     164         state_steps)
# --> 166     adam(
#     167         params_with_grad,
#     168         grads,
#     169         exp_avgs,
#     170         exp_avg_sqs,
#     171         max_exp_avg_sqs,
#     172         state_steps,
#     173         amsgrad=group['amsgrad'],
#     174         has_complex=has_complex,
#     175         beta1=beta1,
#     176         beta2=beta2,
#     177         lr=group['lr'],
#     178         weight_decay=group['weight_decay'],
#     179         eps=group['eps'],
#     180         maximize=group['maximize'],
#     181         foreach=group['foreach'],
#     182         capturable=group['capturable'],
#     183         differentiable=group['differentiable'],
#     184         fused=group['fused'],
#     185         grad_scale=getattr(self, "grad_scale", None),
#     186         found_inf=getattr(self, "found_inf", None),
#     187     )
#     189 return loss
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:316, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     313 else:
#     314     func = _single_tensor_adam
# --> 316 func(params,
#     317      grads,
#     318      exp_avgs,
#     319      exp_avg_sqs,
#     320      max_exp_avg_sqs,
#     321      state_steps,
#     322      amsgrad=amsgrad,
#     323      has_complex=has_complex,
#     324      beta1=beta1,
#     325      beta2=beta2,
#     326      lr=lr,
#     327      weight_decay=weight_decay,
#     328      eps=eps,
#     329      maximize=maximize,
#     330      capturable=capturable,
#     331      differentiable=differentiable,
#     332      grad_scale=grad_scale,
#     333      found_inf=found_inf)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:391, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     388     param = torch.view_as_real(param)
#     390 # Decay the first and second moment running average coefficient
# --> 391 exp_avg.lerp_(grad, 1 - beta1)
#     392 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     394 if capturable or differentiable:
#
# KeyboardInterrupt:

# %%
p

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [128]
num_layers_list = [6]

learning_rates = [0.000001]
window_sizes = [10]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=128, num_layers=6, learning_rate=1e-06, window_size=10
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 29230.330948792907, Validation Loss: 29254.22265625
# Epoch [2/800], Training Loss: 28711.68674648635, Validation Loss: 28920.205078125
# Epoch [3/800], Training Loss: 28464.39403007933, Validation Loss: 28702.87890625
# Epoch [4/800], Training Loss: 28278.923694671757, Validation Loss: 28526.8125
# Epoch [5/800], Training Loss: 28113.620593405707, Validation Loss: 28363.91015625
# Epoch [6/800], Training Loss: 27955.76568382586, Validation Loss: 28206.4453125
# Epoch [7/800], Training Loss: 27801.594746057737, Validation Loss: 28052.044921875
# Epoch [8/800], Training Loss: 27649.939721691735, Validation Loss: 27900.005859375
# Epoch [9/800], Training Loss: 27500.43447677432, Validation Loss: 27750.01953125
# Epoch [10/800], Training Loss: 27352.961108749292, Validation Loss: 27602.0859375
# Epoch [11/800], Training Loss: 27207.49308828789, Validation Loss: 27456.125
# Epoch [12/800], Training Loss: 27064.00785705787, Validation Loss: 27312.154296875
# Epoch [13/800], Training Loss: 26922.492358441556, Validation Loss: 27170.1484375
# Epoch [14/800], Training Loss: 26782.95054234724, Validation Loss: 27030.09375
# Epoch [15/800], Training Loss: 26645.372274974477, Validation Loss: 26892.021484375
# Epoch [16/800], Training Loss: 26509.7400735838, Validation Loss: 26755.888671875
# Epoch [17/800], Training Loss: 26376.06809739488, Validation Loss: 26621.701171875
# Epoch [18/800], Training Loss: 26244.350725792297, Validation Loss: 26489.4609375
# Epoch [19/800], Training Loss: 26114.56584786521, Validation Loss: 26359.15625
# Epoch [20/800], Training Loss: 25986.70265819315, Validation Loss: 26230.779296875
# Epoch [21/800], Training Loss: 25860.75349640592, Validation Loss: 26104.30078125
# Epoch [22/800], Training Loss: 25736.73155183976, Validation Loss: 25979.740234375
# Epoch [23/800], Training Loss: 25614.59924888807, Validation Loss: 25857.07421875
# Epoch [24/800], Training Loss: 25494.355612406325, Validation Loss: 25736.3125
# Epoch [25/800], Training Loss: 25376.02933235462, Validation Loss: 25617.44921875
# Epoch [26/800], Training Loss: 25259.583320502097, Validation Loss: 25500.4453125
# Epoch [27/800], Training Loss: 25144.977198293283, Validation Loss: 25385.30078125
# Epoch [28/800], Training Loss: 25032.21857737318, Validation Loss: 25272.0
# Epoch [29/800], Training Loss: 24921.30458102312, Validation Loss: 25160.525390625
# Epoch [30/800], Training Loss: 24812.205048245996, Validation Loss: 25050.869140625
# Epoch [31/800], Training Loss: 24704.906721058305, Validation Loss: 24942.994140625
# Epoch [32/800], Training Loss: 24599.414088870035, Validation Loss: 24836.9453125
# Epoch [33/800], Training Loss: 24495.692530587534, Validation Loss: 24732.666015625
# Epoch [34/800], Training Loss: 24393.74823169822, Validation Loss: 24630.15625
# Epoch [35/800], Training Loss: 24293.531095358558, Validation Loss: 24529.36328125
# Epoch [36/800], Training Loss: 24195.05223707423, Validation Loss: 24430.294921875
# Epoch [37/800], Training Loss: 24098.278991006602, Validation Loss: 24332.962890625
# Epoch [38/800], Training Loss: 24003.20490699222, Validation Loss: 24237.28515625
# Epoch [39/800], Training Loss: 23909.79387824508, Validation Loss: 24143.306640625
# Epoch [40/800], Training Loss: 23818.041023151814, Validation Loss: 24050.962890625
# Epoch [41/800], Training Loss: 23727.93250504457, Validation Loss: 23960.275390625
# Epoch [42/800], Training Loss: 23639.454846178676, Validation Loss: 23871.21875
# Epoch [43/800], Training Loss: 23552.559456656076, Validation Loss: 23783.73046875
# Epoch [44/800], Training Loss: 23467.23755731109, Validation Loss: 23697.826171875
# Epoch [45/800], Training Loss: 23383.48161218717, Validation Loss: 23613.498046875
# Epoch [46/800], Training Loss: 23301.24233529954, Validation Loss: 23530.640625
# Epoch [47/800], Training Loss: 23220.523907395152, Validation Loss: 23449.33984375
# Epoch [48/800], Training Loss: 23141.27498542446, Validation Loss: 23369.5
# Epoch [49/800], Training Loss: 23063.50424498589, Validation Loss: 23291.125
# Epoch [50/800], Training Loss: 22987.184837114946, Validation Loss: 23214.212890625
# Epoch [51/800], Training Loss: 22912.308208017905, Validation Loss: 23138.74609375
# Epoch [52/800], Training Loss: 22838.83960216317, Validation Loss: 23064.681640625
# Epoch [53/800], Training Loss: 22766.694801869853, Validation Loss: 22991.94140625
# Epoch [54/800], Training Loss: 22695.86743783353, Validation Loss: 22920.5078125
# Epoch [55/800], Training Loss: 22626.372016977017, Validation Loss: 22850.4140625
# Epoch [56/800], Training Loss: 22558.23092264823, Validation Loss: 22781.66796875
# Epoch [57/800], Training Loss: 22491.330413172294, Validation Loss: 22714.193359375
# Epoch [58/800], Training Loss: 22425.71395623599, Validation Loss: 22647.96484375
# Epoch [59/800], Training Loss: 22361.273485531874, Validation Loss: 22582.93359375
# Epoch [60/800], Training Loss: 22298.05579652614, Validation Loss: 22519.126953125
# Epoch [61/800], Training Loss: 22236.057835272226, Validation Loss: 22456.517578125
# Epoch [62/800], Training Loss: 22175.235864885803, Validation Loss: 22395.115234375
# Epoch [63/800], Training Loss: 22115.538140261448, Validation Loss: 22334.810546875
# Epoch [64/800], Training Loss: 22056.91614705372, Validation Loss: 22275.6171875
# Epoch [65/800], Training Loss: 21999.41302533424, Validation Loss: 22217.548828125
# Epoch [66/800], Training Loss: 21943.001481996227, Validation Loss: 22160.55078125
# Epoch [67/800], Training Loss: 21887.6179432072, Validation Loss: 22104.583984375
# Epoch [68/800], Training Loss: 21833.27882766228, Validation Loss: 22049.66796875
# Epoch [69/800], Training Loss: 21779.989206903585, Validation Loss: 21995.8046875
# Epoch [70/800], Training Loss: 21727.665388174344, Validation Loss: 21942.904296875
# Epoch [71/800], Training Loss: 21676.336368928907, Validation Loss: 21891.0
# Epoch [72/800], Training Loss: 21625.95729076929, Validation Loss: 21840.0234375
# Epoch [73/800], Training Loss: 21576.46824419345, Validation Loss: 21789.98046875
# Epoch [74/800], Training Loss: 21527.883653368757, Validation Loss: 21740.81640625
# Epoch [75/800], Training Loss: 21480.196203224114, Validation Loss: 21692.591796875
# Epoch [76/800], Training Loss: 21433.40634462785, Validation Loss: 21645.234375
# Epoch [77/800], Training Loss: 21387.506922345798, Validation Loss: 21598.759765625
# Epoch [78/800], Training Loss: 21342.43080548823, Validation Loss: 21553.13671875
# Epoch [79/800], Training Loss: 21298.160394237057, Validation Loss: 21508.296875
# Epoch [80/800], Training Loss: 21254.695822784306, Validation Loss: 21464.29296875
# Epoch [81/800], Training Loss: 21212.001171089807, Validation Loss: 21421.044921875
# Epoch [82/800], Training Loss: 21170.068647805536, Validation Loss: 21378.583984375
# Epoch [83/800], Training Loss: 21128.86047601213, Validation Loss: 21336.8359375
# Epoch [84/800], Training Loss: 21088.432140813413, Validation Loss: 21295.857421875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 75
#      73     loss = criterion(outputs, labels)
#      74     loss.backward()
# ---> 75     optimizer.step()
#      77     running_loss += loss.item()
#      79 model.eval()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:166, in Adam.step(self, closure)
#     155     beta1, beta2 = group['betas']
#     157     has_complex = self._init_group(
#     158         group,
#     159         params_with_grad,
#    (...)
#     163         max_exp_avg_sqs,
#     164         state_steps)
# --> 166     adam(
#     167         params_with_grad,
#     168         grads,
#     169         exp_avgs,
#     170         exp_avg_sqs,
#     171         max_exp_avg_sqs,
#     172         state_steps,
#     173         amsgrad=group['amsgrad'],
#     174         has_complex=has_complex,
#     175         beta1=beta1,
#     176         beta2=beta2,
#     177         lr=group['lr'],
#     178         weight_decay=group['weight_decay'],
#     179         eps=group['eps'],
#     180         maximize=group['maximize'],
#     181         foreach=group['foreach'],
#     182         capturable=group['capturable'],
#     183         differentiable=group['differentiable'],
#     184         fused=group['fused'],
#     185         grad_scale=getattr(self, "grad_scale", None),
#     186         found_inf=getattr(self, "found_inf", None),
#     187     )
#     189 return loss
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:316, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     313 else:
#     314     func = _single_tensor_adam
# --> 316 func(params,
#     317      grads,
#     318      exp_avgs,
#     319      exp_avg_sqs,
#     320      max_exp_avg_sqs,
#     321      state_steps,
#     322      amsgrad=amsgrad,
#     323      has_complex=has_complex,
#     324      beta1=beta1,
#     325      beta2=beta2,
#     326      lr=lr,
#     327      weight_decay=weight_decay,
#     328      eps=eps,
#     329      maximize=maximize,
#     330      capturable=capturable,
#     331      differentiable=differentiable,
#     332      grad_scale=grad_scale,
#     333      found_inf=found_inf)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:392, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     390 # Decay the first and second moment running average coefficient
#     391 exp_avg.lerp_(grad, 1 - beta1)
# --> 392 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     394 if capturable or differentiable:
#     395     step = step_t
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [84]
num_layers_list = [6]

learning_rates = [0.0002]
window_sizes = [10]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=84, num_layers=6, learning_rate=0.0002, window_size=10
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 17937.245566597063, Validation Loss: 17861.65625
# Epoch [2/800], Training Loss: 17127.01271234097, Validation Loss: 17501.865234375
# Epoch [3/800], Training Loss: 14243.380475697888, Validation Loss: 18006.7578125
# Epoch [4/800], Training Loss: 12154.438124210932, Validation Loss: 20105.673828125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 72
#      69 labels = y_train_tensor[window_end - 1]
#      71 optimizer.zero_grad()
# ---> 72 outputs = model(inputs)
#      73 loss = criterion(outputs, labels)
#      74 loss.backward()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[20], line 181, in LSTMModel.forward(self, x)
#     178 h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
#     179 c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
# --> 181 out, _ = self.lstm(x, (h0, c0))
#     183 out = self.fc(out[:, -1, :])
#     184 return out
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\rnn.py:878, in LSTM.forward(self, input, hx)
#     875         hx = self.permute_hidden(hx, sorted_indices)
#     877 if batch_sizes is None:
# --> 878     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     879                       self.dropout, self.training, self.bidirectional, self.batch_first)
#     880 else:
#     881     result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     882                       self.num_layers, self.dropout, self.training, self.bidirectional)
#
# KeyboardInterrupt:

# %%
l

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [88]
num_layers_list = [6]

learning_rates = [0.0002]
window_sizes = [10]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=88, num_layers=6, learning_rate=0.0002, window_size=10
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 17755.78321221817, Validation Loss: 17786.36328125
# Epoch [2/800], Training Loss: 17091.422829971787, Validation Loss: 17488.04296875
# Epoch [3/800], Training Loss: 12189.674027569705, Validation Loss: 19044.51171875
# Epoch [4/800], Training Loss: 10874.31613742711, Validation Loss: 20797.826171875
# Epoch [5/800], Training Loss: 8944.046858378042, Validation Loss: 21537.625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 74
#      72 outputs = model(inputs)
#      73 loss = criterion(outputs, labels)
# ---> 74 loss.backward()
#      75 optimizer.step()
#      77 running_loss += loss.item()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\autograd\__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
8

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [80]
num_layers_list = [6]

learning_rates = [0.0002]
window_sizes = [10]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=80, num_layers=6, learning_rate=0.0002, window_size=10
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 17653.51585414323, Validation Loss: 17764.439453125
# Epoch [2/800], Training Loss: 17210.242130848594, Validation Loss: 17500.11328125
# Epoch [3/800], Training Loss: 17249.847098479124, Validation Loss: 17473.291015625
# Epoch [4/800], Training Loss: 17257.064272498108, Validation Loss: 17469.70703125
# Epoch [5/800], Training Loss: 17251.476612383263, Validation Loss: 17469.14453125
# Epoch [6/800], Training Loss: 17240.740367786253, Validation Loss: 17469.07421875
# Epoch [7/800], Training Loss: 17225.12057148665, Validation Loss: 17469.1171875
# Epoch [8/800], Training Loss: 17212.8721919672, Validation Loss: 17469.26171875
# Epoch [9/800], Training Loss: 17197.77203511055, Validation Loss: 17469.490234375
# Epoch [10/800], Training Loss: 17187.50474248677, Validation Loss: 17469.796875
# Epoch [11/800], Training Loss: 17169.953111049464, Validation Loss: 17470.205078125
# Epoch [12/800], Training Loss: 17158.303669574492, Validation Loss: 17470.666015625
# Epoch [13/800], Training Loss: 17144.334075692634, Validation Loss: 17471.140625
# Epoch [14/800], Training Loss: 17134.090473741267, Validation Loss: 17471.734375
# Epoch [15/800], Training Loss: 17116.176802534144, Validation Loss: 17472.412109375
# Early stopping at epoch 15
# Final Test Loss: 17928.98828125

# %%
k
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 k
#
# NameError: name 'k' is not defined

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [64]
num_layers_list = [6]

learning_rates = [0.0002]
window_sizes = [10]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=64, num_layers=6, learning_rate=0.0002, window_size=10
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 18731.84697124812, Validation Loss: 18299.77734375
# Epoch [2/800], Training Loss: 17669.35537669297, Validation Loss: 17700.193359375
# Epoch [3/800], Training Loss: 17582.354965616334, Validation Loss: 17575.92578125
# Epoch [4/800], Training Loss: 17569.85932850295, Validation Loss: 17539.98046875
# Epoch [5/800], Training Loss: 17567.982095454987, Validation Loss: 17527.44921875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 75
#      73     loss = criterion(outputs, labels)
#      74     loss.backward()
# ---> 75     optimizer.step()
#      77     running_loss += loss.item()
#      79 model.eval()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:166, in Adam.step(self, closure)
#     155     beta1, beta2 = group['betas']
#     157     has_complex = self._init_group(
#     158         group,
#     159         params_with_grad,
#    (...)
#     163         max_exp_avg_sqs,
#     164         state_steps)
# --> 166     adam(
#     167         params_with_grad,
#     168         grads,
#     169         exp_avgs,
#     170         exp_avg_sqs,
#     171         max_exp_avg_sqs,
#     172         state_steps,
#     173         amsgrad=group['amsgrad'],
#     174         has_complex=has_complex,
#     175         beta1=beta1,
#     176         beta2=beta2,
#     177         lr=group['lr'],
#     178         weight_decay=group['weight_decay'],
#     179         eps=group['eps'],
#     180         maximize=group['maximize'],
#     181         foreach=group['foreach'],
#     182         capturable=group['capturable'],
#     183         differentiable=group['differentiable'],
#     184         fused=group['fused'],
#     185         grad_scale=getattr(self, "grad_scale", None),
#     186         found_inf=getattr(self, "found_inf", None),
#     187     )
#     189 return loss
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:316, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     313 else:
#     314     func = _single_tensor_adam
# --> 316 func(params,
#     317      grads,
#     318      exp_avgs,
#     319      exp_avg_sqs,
#     320      max_exp_avg_sqs,
#     321      state_steps,
#     322      amsgrad=amsgrad,
#     323      has_complex=has_complex,
#     324      beta1=beta1,
#     325      beta2=beta2,
#     326      lr=lr,
#     327      weight_decay=weight_decay,
#     328      eps=eps,
#     329      maximize=maximize,
#     330      capturable=capturable,
#     331      differentiable=differentiable,
#     332      grad_scale=grad_scale,
#     333      found_inf=found_inf)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:441, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     438     else:
#     439         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
# --> 441     param.addcdiv_(exp_avg, denom, value=-step_size)
#     443 # Lastly, switch back to complex view
#     444 if amsgrad and torch.is_complex(params[i]):
#
# KeyboardInterrupt:

# %%
p

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [96]
num_layers_list = [6]

learning_rates = [0.0002]
window_sizes = [10]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=96, num_layers=6, learning_rate=0.0002, window_size=10
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 17765.405537494105, Validation Loss: 17773.65234375
# Epoch [2/800], Training Loss: 16889.086277863058, Validation Loss: 17473.806640625
# Epoch [3/800], Training Loss: 13833.165145919651, Validation Loss: 18283.6640625
# Epoch [4/800], Training Loss: 10238.514398461872, Validation Loss: 21929.490234375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 75
#      73     loss = criterion(outputs, labels)
#      74     loss.backward()
# ---> 75     optimizer.step()
#      77     running_loss += loss.item()
#      79 model.eval()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:166, in Adam.step(self, closure)
#     155     beta1, beta2 = group['betas']
#     157     has_complex = self._init_group(
#     158         group,
#     159         params_with_grad,
#    (...)
#     163         max_exp_avg_sqs,
#     164         state_steps)
# --> 166     adam(
#     167         params_with_grad,
#     168         grads,
#     169         exp_avgs,
#     170         exp_avg_sqs,
#     171         max_exp_avg_sqs,
#     172         state_steps,
#     173         amsgrad=group['amsgrad'],
#     174         has_complex=has_complex,
#     175         beta1=beta1,
#     176         beta2=beta2,
#     177         lr=group['lr'],
#     178         weight_decay=group['weight_decay'],
#     179         eps=group['eps'],
#     180         maximize=group['maximize'],
#     181         foreach=group['foreach'],
#     182         capturable=group['capturable'],
#     183         differentiable=group['differentiable'],
#     184         fused=group['fused'],
#     185         grad_scale=getattr(self, "grad_scale", None),
#     186         found_inf=getattr(self, "found_inf", None),
#     187     )
#     189 return loss
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:316, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     313 else:
#     314     func = _single_tensor_adam
# --> 316 func(params,
#     317      grads,
#     318      exp_avgs,
#     319      exp_avg_sqs,
#     320      max_exp_avg_sqs,
#     321      state_steps,
#     322      amsgrad=amsgrad,
#     323      has_complex=has_complex,
#     324      beta1=beta1,
#     325      beta2=beta2,
#     326      lr=lr,
#     327      weight_decay=weight_decay,
#     328      eps=eps,
#     329      maximize=maximize,
#     330      capturable=capturable,
#     331      differentiable=differentiable,
#     332      grad_scale=grad_scale,
#     333      found_inf=found_inf)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:392, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     390 # Decay the first and second moment running average coefficient
#     391 exp_avg.lerp_(grad, 1 - beta1)
# --> 392 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     394 if capturable or differentiable:
#     395     step = step_t
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [128]
num_layers_list = [8]

learning_rates = [0.0002]
window_sizes = [10]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=128, num_layers=8, learning_rate=0.0002, window_size=10
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 16249.662224031175, Validation Loss: 17471.640625
# Epoch [2/800], Training Loss: 13705.373359125577, Validation Loss: 18670.40625
# Epoch [3/800], Training Loss: 10974.888909632375, Validation Loss: 22450.193359375
# Epoch [4/800], Training Loss: 9599.521636446587, Validation Loss: 21339.1796875
# Epoch [5/800], Training Loss: 7772.001113345393, Validation Loss: 22927.056640625
# Epoch [6/800], Training Loss: 5004.73448390274, Validation Loss: 24037.69140625
# Epoch [7/800], Training Loss: 3740.102204744537, Validation Loss: 23069.0703125
# Epoch [8/800], Training Loss: 2747.0681891787917, Validation Loss: 24952.087890625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 75
#      73     loss = criterion(outputs, labels)
#      74     loss.backward()
# ---> 75     optimizer.step()
#      77     running_loss += loss.item()
#      79 model.eval()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:166, in Adam.step(self, closure)
#     155     beta1, beta2 = group['betas']
#     157     has_complex = self._init_group(
#     158         group,
#     159         params_with_grad,
#    (...)
#     163         max_exp_avg_sqs,
#     164         state_steps)
# --> 166     adam(
#     167         params_with_grad,
#     168         grads,
#     169         exp_avgs,
#     170         exp_avg_sqs,
#     171         max_exp_avg_sqs,
#     172         state_steps,
#     173         amsgrad=group['amsgrad'],
#     174         has_complex=has_complex,
#     175         beta1=beta1,
#     176         beta2=beta2,
#     177         lr=group['lr'],
#     178         weight_decay=group['weight_decay'],
#     179         eps=group['eps'],
#     180         maximize=group['maximize'],
#     181         foreach=group['foreach'],
#     182         capturable=group['capturable'],
#     183         differentiable=group['differentiable'],
#     184         fused=group['fused'],
#     185         grad_scale=getattr(self, "grad_scale", None),
#     186         found_inf=getattr(self, "found_inf", None),
#     187     )
#     189 return loss
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:316, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     313 else:
#     314     func = _single_tensor_adam
# --> 316 func(params,
#     317      grads,
#     318      exp_avgs,
#     319      exp_avg_sqs,
#     320      max_exp_avg_sqs,
#     321      state_steps,
#     322      amsgrad=amsgrad,
#     323      has_complex=has_complex,
#     324      beta1=beta1,
#     325      beta2=beta2,
#     326      lr=lr,
#     327      weight_decay=weight_decay,
#     328      eps=eps,
#     329      maximize=maximize,
#     330      capturable=capturable,
#     331      differentiable=differentiable,
#     332      grad_scale=grad_scale,
#     333      found_inf=found_inf)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:391, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     388     param = torch.view_as_real(param)
#     390 # Decay the first and second moment running average coefficient
# --> 391 exp_avg.lerp_(grad, 1 - beta1)
#     392 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     394 if capturable or differentiable:
#
# KeyboardInterrupt:

# %%
l

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [32]
num_layers_list = [6]

learning_rates = [0.0002]
window_sizes = [10]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=32, num_layers=6, learning_rate=0.0002, window_size=10
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 22145.58349563289, Validation Loss: 21079.986328125
# Epoch [2/800], Training Loss: 19600.599216972838, Validation Loss: 19294.447265625
# Epoch [3/800], Training Loss: 18756.66787731154, Validation Loss: 18585.037109375
# Epoch [4/800], Training Loss: 18393.43850461453, Validation Loss: 18254.125
# Epoch [5/800], Training Loss: 18212.911728320883, Validation Loss: 18082.0703125
# Epoch [6/800], Training Loss: 18115.088115198178, Validation Loss: 17985.97265625
# Epoch [7/800], Training Loss: 18058.909772687446, Validation Loss: 17929.580078125
# Epoch [8/800], Training Loss: 18025.425424307337, Validation Loss: 17895.462890625
# Epoch [9/800], Training Loss: 18004.876177851995, Validation Loss: 17874.3125
# Epoch [10/800], Training Loss: 17992.065356179453, Validation Loss: 17861.025390625
# Epoch [11/800], Training Loss: 17983.958329134755, Validation Loss: 17852.611328125
# Epoch [12/800], Training Loss: 17978.826369861392, Validation Loss: 17847.208984375
# Epoch [13/800], Training Loss: 17975.48761868938, Validation Loss: 17843.75390625
# Epoch [14/800], Training Loss: 17973.39175533613, Validation Loss: 17841.533203125
# Epoch [15/800], Training Loss: 17972.03196666, Validation Loss: 17840.09765625
# Epoch [16/800], Training Loss: 17971.15320271253, Validation Loss: 17839.158203125
# Epoch [17/800], Training Loss: 17970.591652051462, Validation Loss: 17838.58203125
# Epoch [18/800], Training Loss: 17970.229249580683, Validation Loss: 17838.173828125
# Epoch [19/800], Training Loss: 17970.011094804613, Validation Loss: 17837.923828125
# Epoch [20/800], Training Loss: 17969.86507993086, Validation Loss: 17837.775390625
# Epoch [21/800], Training Loss: 17969.760936342114, Validation Loss: 17837.666015625
# Epoch [22/800], Training Loss: 17969.687637391868, Validation Loss: 17837.5859375
# Epoch [23/800], Training Loss: 17969.64222230334, Validation Loss: 17837.537109375
# Epoch [24/800], Training Loss: 17969.612415172734, Validation Loss: 17837.51171875
# Epoch [25/800], Training Loss: 17969.597762573743, Validation Loss: 17837.505859375
# Epoch [26/800], Training Loss: 17969.587997911276, Validation Loss: 17837.490234375
# Epoch [27/800], Training Loss: 17969.583007715457, Validation Loss: 17837.48828125
# Epoch [28/800], Training Loss: 17969.575466857572, Validation Loss: 17837.4765625
# Epoch [29/800], Training Loss: 17969.574033252324, Validation Loss: 17837.47265625
# Epoch [30/800], Training Loss: 17969.57249756919, Validation Loss: 17837.46875
# Epoch [31/800], Training Loss: 17969.570032706182, Validation Loss: 17837.466796875
# Epoch [32/800], Training Loss: 17969.56721112666, Validation Loss: 17837.466796875
# Epoch [33/800], Training Loss: 17969.567140433304, Validation Loss: 17837.466796875
# Epoch [34/800], Training Loss: 17969.567965297818, Validation Loss: 17837.466796875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 75
#      73     loss = criterion(outputs, labels)
#      74     loss.backward()
# ---> 75     optimizer.step()
#      77     running_loss += loss.item()
#      79 model.eval()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:166, in Adam.step(self, closure)
#     155     beta1, beta2 = group['betas']
#     157     has_complex = self._init_group(
#     158         group,
#     159         params_with_grad,
#    (...)
#     163         max_exp_avg_sqs,
#     164         state_steps)
# --> 166     adam(
#     167         params_with_grad,
#     168         grads,
#     169         exp_avgs,
#     170         exp_avg_sqs,
#     171         max_exp_avg_sqs,
#     172         state_steps,
#     173         amsgrad=group['amsgrad'],
#     174         has_complex=has_complex,
#     175         beta1=beta1,
#     176         beta2=beta2,
#     177         lr=group['lr'],
#     178         weight_decay=group['weight_decay'],
#     179         eps=group['eps'],
#     180         maximize=group['maximize'],
#     181         foreach=group['foreach'],
#     182         capturable=group['capturable'],
#     183         differentiable=group['differentiable'],
#     184         fused=group['fused'],
#     185         grad_scale=getattr(self, "grad_scale", None),
#     186         found_inf=getattr(self, "found_inf", None),
#     187     )
#     189 return loss
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:316, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     313 else:
#     314     func = _single_tensor_adam
# --> 316 func(params,
#     317      grads,
#     318      exp_avgs,
#     319      exp_avg_sqs,
#     320      max_exp_avg_sqs,
#     321      state_steps,
#     322      amsgrad=amsgrad,
#     323      has_complex=has_complex,
#     324      beta1=beta1,
#     325      beta2=beta2,
#     326      lr=lr,
#     327      weight_decay=weight_decay,
#     328      eps=eps,
#     329      maximize=maximize,
#     330      capturable=capturable,
#     331      differentiable=differentiable,
#     332      grad_scale=grad_scale,
#     333      found_inf=found_inf)
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\optim\adam.py:392, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     390 # Decay the first and second moment running average coefficient
#     391 exp_avg.lerp_(grad, 1 - beta1)
# --> 392 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     394 if capturable or differentiable:
#     395     step = step_t
#
# KeyboardInterrupt:

# %%
l

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]

hidden_sizes = [16]
num_layers_list = [4]

learning_rates = [0.0002]
window_sizes = [10]

num_epochs = 800
patience = 10 # Number of epochs to wait for improvement




# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=16, num_layers=4, learning_rate=0.0002, window_size=10
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/800], Training Loss: 25325.237653064905, Validation Loss: 24444.546875
# Epoch [2/800], Training Loss: 22585.686684986653, Validation Loss: 22165.3984375
# Epoch [3/800], Training Loss: 20999.440971688775, Validation Loss: 20780.595703125
# Epoch [4/800], Training Loss: 20063.048936499083, Validation Loss: 19937.408203125
# Epoch [5/800], Training Loss: 19483.991641731467, Validation Loss: 19401.466796875
# Epoch [6/800], Training Loss: 19106.66399924554, Validation Loss: 19045.357421875
# Epoch [7/800], Training Loss: 18850.25730772591, Validation Loss: 18799.9296875
# Epoch [8/800], Training Loss: 18670.388401161028, Validation Loss: 18625.80859375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 74
#      72 outputs = model(inputs)
#      73 loss = criterion(outputs, labels)
# ---> 74 loss.backward()
#      75 optimizer.step()
#      77 running_loss += loss.item()
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\autograd\__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:
