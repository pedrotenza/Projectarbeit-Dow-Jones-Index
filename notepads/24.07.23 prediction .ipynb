# %% [markdown]
# Steps for Predicting Future Close Values
#
# https://chatgpt.com/c/55d32d42-d50a-4a87-8cf7-da0cf6ff3971

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from sklearn import metrics
import numpy as npw
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler


def split_data_with_window(x_in, y_in, split_window_size):
    # Initialize lists to store training and temporary sets
    x_out1_list, y_out1_list, x_out2_list, y_out2_list = [], [], [], []

    # Iterate through the data with the specified window size
    for i in range(0, len(x_in) - split_window_size, split_window_size + 1):
        x_out1_out2 = x_in.iloc[i:i+split_window_size+1]
        y_out1_out2 = y_in.iloc[i:i+split_window_size+1]

        # Separate the last row for the temporary set
        # [ :-1]: all elements except the last one
        # [-1:]:  selects only the last element
        # (:) is used to indicate slicing of a sequence
        # sequence[start : end : step]

        x_out1 = x_out1_out2.iloc[:-1]
        y_out1 = y_out1_out2.iloc[:-1]

        x_out2 = x_out1_out2.iloc[-1:]
        y_out2 = y_out1_out2.iloc[-1:]

        x_out1_list.append(x_out1)
        y_out1_list.append(y_out1)
        x_out2_list.append(x_out2)
        y_out2_list.append(y_out2)

    # Concatenate the lists into pandas DataFrames
    x_out1 = pd.concat(x_out1_list)
    y_out1 = pd.concat(y_out1_list)
    x_out2 = pd.concat(x_out2_list)
    y_out2 = pd.concat(y_out2_list)

    return x_out1, y_out1, x_out2, y_out2










# Read the CSV file
data = pd.read_csv("../data/data/aapl_raw_data.csv")

data = data.drop("date", axis=1)

data.isnull().sum()
data=data.fillna(0)  # Filling null values with zero
data.isnull().sum()

data = data.astype('float32')


# Keep data until 31.07.2023
data = data.iloc[:10747]

print(data.tail(5))

#print(data['open'].dtype)
#print(data.shape)

# Assuming 'data' is a pandas DataFrame
x_data = data[['open', 'high', 'low', 'volume', 'adjusted_close', 'change_percent', 'avg_vol_20d']]
y_data = data["close"]

# Now x_data and y_data are pandas DataFrames/Series, respectively

x_data.tail(1)



# Split Data to train and temp

# Define your split_window_size
split_window_size = 3

# Call the split_data_with_window function
x_train, y_train, x_temp, y_temp = split_data_with_window(x_data, y_data, split_window_size)


"""

# Print the last 5 rows of x_data
print("Last 5 rows of x_data:")
print(x_data.tail(5))

# Print the last 5 rows of x_train
print("\nLast 25 rows of x_train:")
print(x_train.tail(25))

print("\nLast 3 rows of y_train:")
print(y_temp.tail(3))

"""

# Split temp into val and test

# Define your split_window_size
split_window_size = 1

# Call the split_data_with_window function
x_val, y_val, x_test, y_test = split_data_with_window(x_temp, y_temp, split_window_size)




scaler = MinMaxScaler()

x_train_normalized = scaler.fit_transform(x_train)
x_val_normalized = scaler.transform(x_val)
x_test_normalized = scaler.transform(x_test)

# Convert the data to PyTorch tensors
x_train_tensor = torch.tensor(x_train_normalized, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).view(-1, 1)

x_val_tensor = torch.tensor(x_val_normalized, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val.values, dtype=torch.float32).view(-1, 1)

x_test_tensor = torch.tensor(x_test_normalized, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).view(-1, 1)


"""
# x_train_tensor inverse

x_test_original = scaler.inverse_transform(x_train_tensor.numpy())
print("\nFirst row of x_test_original:")
print(x_test_original[0])

print("\nFirst row of x_train:")
print(x_train.head(1))



print("\nLast row of x_test_original:")
print(x_test_original[-1])

print("\nLast row of x_train:")
print(x_train.tail(1))
"""









class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, learning_rate, window_size):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.window_size = window_size
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)
        self.learning_rate = learning_rate

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        out, _ = self.lstm(x, (h0, c0))

        out = self.fc(out[:, -1, :])
        return out

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]
hidden_sizes = [4]
num_layers_list = [1]
learning_rates = [0.0003]
window_sizes = [5]

num_epochs = 1500
patience = 10  # Number of epochs to wait for improvement



# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=4, num_layers=1, learning_rate=0.0003, window_size=5
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/1500], Training Loss: 27793.018322544376, Validation Loss: 27326.3203125
# Epoch [2/1500], Training Loss: 26061.825515796434, Validation Loss: 25747.73828125
# Epoch [3/1500], Training Loss: 24654.274446725227, Validation Loss: 24422.88671875
# Epoch [4/1500], Training Loss: 23496.82109503624, Validation Loss: 23333.95703125
# Epoch [5/1500], Training Loss: 22537.20042588913, Validation Loss: 22394.634765625
# Epoch [6/1500], Training Loss: 21540.526555390843, Validation Loss: 21426.326171875
# Epoch [7/1500], Training Loss: 20609.623494876847, Validation Loss: 20503.376953125
# Epoch [8/1500], Training Loss: 19740.36465098926, Validation Loss: 19648.171875
# Epoch [9/1500], Training Loss: 18936.523915505662, Validation Loss: 18854.091796875
# Epoch [10/1500], Training Loss: 18185.33938852773, Validation Loss: 18113.08984375
# Epoch [11/1500], Training Loss: 17481.399780101172, Validation Loss: 17419.451171875
# Epoch [12/1500], Training Loss: 16819.11745512535, Validation Loss: 16769.7578125
# Epoch [13/1500], Training Loss: 16195.863564343877, Validation Loss: 16159.2939453125
# Epoch [14/1500], Training Loss: 15610.324911822876, Validation Loss: 15578.8564453125
# Epoch [15/1500], Training Loss: 15059.542398571128, Validation Loss: 15025.4384765625
# Epoch [16/1500], Training Loss: 14540.035158678156, Validation Loss: 14507.505859375
# Epoch [17/1500], Training Loss: 14049.448710585051, Validation Loss: 14040.15234375
# Epoch [18/1500], Training Loss: 13583.43011184559, Validation Loss: 13598.87890625
# Epoch [19/1500], Training Loss: 13141.196400026909, Validation Loss: 13159.994140625
# Epoch [20/1500], Training Loss: 12721.673358346403, Validation Loss: 12740.064453125
# Epoch [21/1500], Training Loss: 12323.84046163378, Validation Loss: 12341.2587890625
# Epoch [22/1500], Training Loss: 11946.310941535865, Validation Loss: 11964.2646484375
# Epoch [23/1500], Training Loss: 11587.673201255126, Validation Loss: 11608.3828125
# Epoch [24/1500], Training Loss: 11246.710770090876, Validation Loss: 11272.6708984375
# Epoch [25/1500], Training Loss: 10922.505560436008, Validation Loss: 10956.048828125
# Epoch [26/1500], Training Loss: 10614.478379795823, Validation Loss: 10657.3779296875
# Epoch [27/1500], Training Loss: 10322.16578019837, Validation Loss: 10376.2607421875
# Epoch [28/1500], Training Loss: 10045.115347912288, Validation Loss: 10113.51953125
# Epoch [29/1500], Training Loss: 9782.794509699965, Validation Loss: 9871.6796875
# Epoch [30/1500], Training Loss: 9534.523465412673, Validation Loss: 9669.380859375
# Epoch [31/1500], Training Loss: 9291.036466566524, Validation Loss: 9814.16796875
# Epoch [32/1500], Training Loss: 9060.722557813795, Validation Loss: 9435.8447265625
# Epoch [33/1500], Training Loss: 8823.103979116153, Validation Loss: 9155.509765625
# Epoch [34/1500], Training Loss: 8566.458286120815, Validation Loss: 9026.744140625
# Epoch [35/1500], Training Loss: 8326.391246182411, Validation Loss: 8814.068359375
# Epoch [36/1500], Training Loss: 8095.960921648662, Validation Loss: 8504.1396484375
# Epoch [37/1500], Training Loss: 7874.863487499432, Validation Loss: 8206.86328125
# Epoch [38/1500], Training Loss: 7664.942733514592, Validation Loss: 7935.13330078125
# Epoch [39/1500], Training Loss: 7465.646801085869, Validation Loss: 7686.11376953125
# Epoch [40/1500], Training Loss: 7274.009500030941, Validation Loss: 7456.6494140625
# Epoch [41/1500], Training Loss: 7088.1026710946435, Validation Loss: 7245.63671875
# Epoch [42/1500], Training Loss: 6907.091997160856, Validation Loss: 7049.55615234375
# Epoch [43/1500], Training Loss: 6730.825731716657, Validation Loss: 6866.6552734375
# Epoch [44/1500], Training Loss: 6559.27583884024, Validation Loss: 6695.11328125
# Epoch [45/1500], Training Loss: 6392.233686870868, Validation Loss: 6532.7490234375
# Epoch [46/1500], Training Loss: 6229.2722783439185, Validation Loss: 6373.71484375
# Epoch [47/1500], Training Loss: 6070.072270049774, Validation Loss: 6207.64013671875
# Epoch [48/1500], Training Loss: 5915.286827740858, Validation Loss: 6040.89013671875
# Epoch [49/1500], Training Loss: 5765.1367958823885, Validation Loss: 5887.32421875
# Epoch [50/1500], Training Loss: 5619.370714418439, Validation Loss: 5742.6220703125
# Epoch [51/1500], Training Loss: 5477.915138632363, Validation Loss: 5602.9609375
# Epoch [52/1500], Training Loss: 5340.7514770914995, Validation Loss: 5467.52734375
# Epoch [53/1500], Training Loss: 5207.870058806594, Validation Loss: 5336.21240234375
# Epoch [54/1500], Training Loss: 5079.185014447116, Validation Loss: 5208.77001953125
# Epoch [55/1500], Training Loss: 4954.473598835869, Validation Loss: 5084.52294921875
# Epoch [56/1500], Training Loss: 4833.309287707636, Validation Loss: 4962.47314453125
# Epoch [57/1500], Training Loss: 4715.184895093103, Validation Loss: 4841.939453125
# Epoch [58/1500], Training Loss: 4599.650285226448, Validation Loss: 4723.1435546875
# Epoch [59/1500], Training Loss: 4486.428764859834, Validation Loss: 4606.4814453125
# Epoch [60/1500], Training Loss: 4375.369788145308, Validation Loss: 4492.248046875
# Epoch [61/1500], Training Loss: 4266.380029190662, Validation Loss: 4380.7412109375
# Epoch [62/1500], Training Loss: 4159.433122169601, Validation Loss: 4272.1357421875
# Epoch [63/1500], Training Loss: 4054.557874368872, Validation Loss: 4166.45361328125
# Epoch [64/1500], Training Loss: 3951.835600125707, Validation Loss: 4063.69482421875
# Epoch [65/1500], Training Loss: 3851.361475868187, Validation Loss: 3963.83740234375
# Epoch [66/1500], Training Loss: 3753.2236044760048, Validation Loss: 3866.931884765625
# Epoch [67/1500], Training Loss: 3657.4906701934638, Validation Loss: 3772.990234375
# Epoch [68/1500], Training Loss: 3564.2053015587135, Validation Loss: 3681.958251953125
# Epoch [69/1500], Training Loss: 3473.3830251089103, Validation Loss: 3593.748291015625
# Epoch [70/1500], Training Loss: 3385.0266592888543, Validation Loss: 3508.240234375
# Epoch [71/1500], Training Loss: 3299.1138458843225, Validation Loss: 3425.326416015625
# Epoch [72/1500], Training Loss: 3215.6425496388333, Validation Loss: 3344.9404296875
# Epoch [73/1500], Training Loss: 3134.623313786894, Validation Loss: 3267.02490234375
# Epoch [74/1500], Training Loss: 3056.0294085283376, Validation Loss: 3191.53564453125
# Epoch [75/1500], Training Loss: 2979.8452843812493, Validation Loss: 3118.416015625
# Epoch [76/1500], Training Loss: 2906.0010570034424, Validation Loss: 3047.53759765625
# Epoch [77/1500], Training Loss: 2834.3351765731213, Validation Loss: 2978.76611328125
# Epoch [78/1500], Training Loss: 2764.6758430510317, Validation Loss: 2911.962158203125
# Epoch [79/1500], Training Loss: 2696.870898660353, Validation Loss: 2847.036376953125
# Epoch [80/1500], Training Loss: 2630.8836784223986, Validation Loss: 2784.001708984375
# Epoch [81/1500], Training Loss: 2566.8215072663966, Validation Loss: 2722.9189453125
# Epoch [82/1500], Training Loss: 2504.8114787000013, Validation Loss: 2663.891845703125
# Epoch [83/1500], Training Loss: 2444.9543364874444, Validation Loss: 2606.976318359375
# Epoch [84/1500], Training Loss: 2387.2597599937008, Validation Loss: 2552.162841796875
# Epoch [85/1500], Training Loss: 2331.631746500996, Validation Loss: 2499.353271484375
# Epoch [86/1500], Training Loss: 2277.8497523950023, Validation Loss: 2448.31787109375
# Epoch [87/1500], Training Loss: 2225.687852313029, Validation Loss: 2398.81591796875
# Epoch [88/1500], Training Loss: 2174.957743648687, Validation Loss: 2350.65869140625
# Epoch [89/1500], Training Loss: 2125.541914631707, Validation Loss: 2303.697021484375
# Epoch [90/1500], Training Loss: 2077.3629379106205, Validation Loss: 2257.81396484375
# Epoch [91/1500], Training Loss: 2030.341571168627, Validation Loss: 2212.90283203125
# Epoch [92/1500], Training Loss: 1984.4349429591075, Validation Loss: 2168.881591796875
# Epoch [93/1500], Training Loss: 1939.5984089526933, Validation Loss: 2125.68408203125
# Epoch [94/1500], Training Loss: 1895.8155785441595, Validation Loss: 2083.24951171875
# Epoch [95/1500], Training Loss: 1853.0638024015811, Validation Loss: 2041.548828125
# Epoch [96/1500], Training Loss: 1811.368055087839, Validation Loss: 2000.579833984375
# Epoch [97/1500], Training Loss: 1770.7724756221808, Validation Loss: 1960.322998046875
# Epoch [98/1500], Training Loss: 1731.287575356168, Validation Loss: 1920.744384765625
# Epoch [99/1500], Training Loss: 1692.9195789613168, Validation Loss: 1881.7822265625
# Epoch [100/1500], Training Loss: 1655.6471492492255, Validation Loss: 1843.3447265625
# Epoch [101/1500], Training Loss: 1619.4454259708807, Validation Loss: 1805.3341064453125
# Epoch [102/1500], Training Loss: 1584.282851837871, Validation Loss: 1767.6146240234375
# Epoch [103/1500], Training Loss: 1550.1297803763412, Validation Loss: 1730.0938720703125
# Epoch [104/1500], Training Loss: 1516.9482004461654, Validation Loss: 1692.6961669921875
# Epoch [105/1500], Training Loss: 1484.7046293090148, Validation Loss: 1655.50537109375
# Epoch [106/1500], Training Loss: 1453.3601975574552, Validation Loss: 1618.688232421875
# Epoch [107/1500], Training Loss: 1422.8749643583064, Validation Loss: 1582.565185546875
# Epoch [108/1500], Training Loss: 1393.1941901332075, Validation Loss: 1547.3363037109375
# Epoch [109/1500], Training Loss: 1364.241397535408, Validation Loss: 1512.8023681640625
# Epoch [110/1500], Training Loss: 1335.9470856029257, Validation Loss: 1478.6873779296875
# Epoch [111/1500], Training Loss: 1308.2188426793275, Validation Loss: 1444.876220703125
# Epoch [112/1500], Training Loss: 1281.003330840574, Validation Loss: 1411.0780029296875
# Epoch [113/1500], Training Loss: 1254.2558756284238, Validation Loss: 1376.7532958984375
# Epoch [114/1500], Training Loss: 1227.9542353346944, Validation Loss: 1341.74853515625
# Epoch [115/1500], Training Loss: 1202.0816894109214, Validation Loss: 1306.53662109375
# Epoch [116/1500], Training Loss: 1176.668075588011, Validation Loss: 1271.90185546875
# Epoch [117/1500], Training Loss: 1151.7592608367386, Validation Loss: 1238.162841796875
# Epoch [118/1500], Training Loss: 1127.3911871273851, Validation Loss: 1205.906982421875
# Epoch [119/1500], Training Loss: 1103.6190616865044, Validation Loss: 1175.5350341796875
# Epoch [120/1500], Training Loss: 1080.4760082054127, Validation Loss: 1147.2103271484375
# Epoch [121/1500], Training Loss: 1057.9750214477808, Validation Loss: 1120.883056640625
# Epoch [122/1500], Training Loss: 1036.1109855188745, Validation Loss: 1096.370361328125
# Epoch [123/1500], Training Loss: 1014.8467909569501, Validation Loss: 1073.4764404296875
# Epoch [124/1500], Training Loss: 994.1599592287424, Validation Loss: 1051.921142578125
# Epoch [125/1500], Training Loss: 973.9978972914837, Validation Loss: 1031.437744140625
# Epoch [126/1500], Training Loss: 954.3282269401589, Validation Loss: 1011.7940063476562
# Epoch [127/1500], Training Loss: 935.1088299826265, Validation Loss: 992.8098754882812
# Epoch [128/1500], Training Loss: 916.324466459583, Validation Loss: 974.3643188476562
# Epoch [129/1500], Training Loss: 897.9447045680924, Validation Loss: 956.3790283203125
# Epoch [130/1500], Training Loss: 879.9539926937861, Validation Loss: 938.7992553710938
# Epoch [131/1500], Training Loss: 862.3339035993012, Validation Loss: 921.6068725585938
# Epoch [132/1500], Training Loss: 845.075141999257, Validation Loss: 904.7693481445312
# Epoch [133/1500], Training Loss: 828.1566183053088, Validation Loss: 888.2734375
# Epoch [134/1500], Training Loss: 811.5704373802753, Validation Loss: 872.1127319335938
# Epoch [135/1500], Training Loss: 795.309347129565, Validation Loss: 856.2807006835938
# Epoch [136/1500], Training Loss: 779.3668486127738, Validation Loss: 840.7756958007812
# Epoch [137/1500], Training Loss: 763.7319708618181, Validation Loss: 825.59765625
# Epoch [138/1500], Training Loss: 748.3975915292106, Validation Loss: 810.7238159179688
# Epoch [139/1500], Training Loss: 733.3567745371982, Validation Loss: 796.169677734375
# Epoch [140/1500], Training Loss: 718.6098001026618, Validation Loss: 781.919677734375
# Epoch [141/1500], Training Loss: 704.1482820494199, Validation Loss: 767.9655151367188
# Epoch [142/1500], Training Loss: 689.9660054376552, Validation Loss: 754.2998046875
# Epoch [143/1500], Training Loss: 676.0532007901912, Validation Loss: 740.9110717773438
# Epoch [144/1500], Training Loss: 662.4074223176738, Validation Loss: 727.7988891601562
# Epoch [145/1500], Training Loss: 649.0227045117645, Validation Loss: 714.948974609375
# Epoch [146/1500], Training Loss: 635.8919182798078, Validation Loss: 702.3543090820312
# Epoch [147/1500], Training Loss: 623.0072793230678, Validation Loss: 690.0100708007812
# Epoch [148/1500], Training Loss: 610.3662502955538, Validation Loss: 677.9071655273438
# Epoch [149/1500], Training Loss: 597.9590047184001, Validation Loss: 666.0328979492188
# Epoch [150/1500], Training Loss: 585.7809413056445, Validation Loss: 654.3902587890625
# Epoch [151/1500], Training Loss: 573.831240636967, Validation Loss: 642.9743041992188
# Epoch [152/1500], Training Loss: 562.1026557868115, Validation Loss: 631.7785034179688
# Epoch [153/1500], Training Loss: 550.5908841210644, Validation Loss: 620.806396484375
# Epoch [154/1500], Training Loss: 539.296890180344, Validation Loss: 610.0638427734375
# Epoch [155/1500], Training Loss: 528.2170969429066, Validation Loss: 599.5421752929688
# Epoch [156/1500], Training Loss: 517.3453556519905, Validation Loss: 589.2451782226562
# Epoch [157/1500], Training Loss: 506.683079129041, Validation Loss: 579.1683959960938
# Epoch [158/1500], Training Loss: 496.22310499091543, Validation Loss: 569.3062744140625
# Epoch [159/1500], Training Loss: 485.9662036405963, Validation Loss: 559.6572875976562
# Epoch [160/1500], Training Loss: 475.90865483741163, Validation Loss: 550.2229614257812
# Epoch [161/1500], Training Loss: 466.0501195314126, Validation Loss: 540.9895629882812
# Epoch [162/1500], Training Loss: 456.3796794124156, Validation Loss: 531.9581298828125
# Epoch [163/1500], Training Loss: 446.9028975061334, Validation Loss: 523.1262817382812
# Epoch [164/1500], Training Loss: 437.61319883557434, Validation Loss: 514.4921875
# Epoch [165/1500], Training Loss: 428.5105376479045, Validation Loss: 506.05078125
# Epoch [166/1500], Training Loss: 419.59283443165623, Validation Loss: 497.8026428222656
# Epoch [167/1500], Training Loss: 410.8577686096714, Validation Loss: 489.7426452636719
# Epoch [168/1500], Training Loss: 402.3024123065778, Validation Loss: 481.868896484375
# Epoch [169/1500], Training Loss: 393.924146338355, Validation Loss: 474.1745300292969
# Epoch [170/1500], Training Loss: 385.7214419216524, Validation Loss: 466.6632080078125
# Epoch [171/1500], Training Loss: 377.6932593078169, Validation Loss: 459.32568359375
# Epoch [172/1500], Training Loss: 369.8352838480139, Validation Loss: 452.1622619628906
# Epoch [173/1500], Training Loss: 362.1463398800322, Validation Loss: 445.1708068847656
# Epoch [174/1500], Training Loss: 354.6265322983239, Validation Loss: 438.3458557128906
# Epoch [175/1500], Training Loss: 347.2701444432305, Validation Loss: 431.684326171875
# Epoch [176/1500], Training Loss: 340.0733821216571, Validation Loss: 425.18304443359375
# Epoch [177/1500], Training Loss: 333.0360388069918, Validation Loss: 418.8368835449219
# Epoch [178/1500], Training Loss: 326.1515162095405, Validation Loss: 412.6451416015625
# Epoch [179/1500], Training Loss: 319.4192615699915, Validation Loss: 406.59930419921875
# Epoch [180/1500], Training Loss: 312.8352515553262, Validation Loss: 400.7001647949219
# Epoch [181/1500], Training Loss: 306.39880480410875, Validation Loss: 394.94573974609375
# Epoch [182/1500], Training Loss: 300.1080847192973, Validation Loss: 389.33270263671875
# Epoch [183/1500], Training Loss: 293.9598226602001, Validation Loss: 383.85491943359375
# Epoch [184/1500], Training Loss: 287.9497691058516, Validation Loss: 378.5096435546875
# Epoch [185/1500], Training Loss: 282.0739095657914, Validation Loss: 373.2966003417969
# Epoch [186/1500], Training Loss: 276.33295071120324, Validation Loss: 368.20977783203125
# Epoch [187/1500], Training Loss: 270.7245761775786, Validation Loss: 363.2470703125
# Epoch [188/1500], Training Loss: 265.24403825556, Validation Loss: 358.40618896484375
# Epoch [189/1500], Training Loss: 259.89106201796926, Validation Loss: 353.6847229003906
# Epoch [190/1500], Training Loss: 254.66279697822307, Validation Loss: 349.078369140625
# Epoch [191/1500], Training Loss: 249.55544054988357, Validation Loss: 344.58599853515625
# Epoch [192/1500], Training Loss: 244.5696261332955, Validation Loss: 340.2060546875
# Epoch [193/1500], Training Loss: 239.7027597313517, Validation Loss: 335.9354553222656
# Epoch [194/1500], Training Loss: 234.94996821982642, Validation Loss: 331.7709655761719
# Epoch [195/1500], Training Loss: 230.31032951466653, Validation Loss: 327.71087646484375
# Epoch [196/1500], Training Loss: 225.78133078412958, Validation Loss: 323.75372314453125
# Epoch [197/1500], Training Loss: 221.3622056958966, Validation Loss: 319.8970947265625
# Epoch [198/1500], Training Loss: 217.04921124870262, Validation Loss: 316.1396484375
# Epoch [199/1500], Training Loss: 212.84132567280827, Validation Loss: 312.479248046875
# Epoch [200/1500], Training Loss: 208.73648930960545, Validation Loss: 308.91326904296875
# Epoch [201/1500], Training Loss: 204.73132261846865, Validation Loss: 305.4385986328125
# Epoch [202/1500], Training Loss: 200.82355279388966, Validation Loss: 302.05511474609375
# Epoch [203/1500], Training Loss: 197.01162174204694, Validation Loss: 298.7582702636719
# Epoch [204/1500], Training Loss: 193.29140357148478, Validation Loss: 295.5483703613281
# Epoch [205/1500], Training Loss: 189.66188954709042, Validation Loss: 292.42303466796875
# Epoch [206/1500], Training Loss: 186.11938326102427, Validation Loss: 289.380615234375
# Epoch [207/1500], Training Loss: 182.6601863068628, Validation Loss: 286.420654296875
# Epoch [208/1500], Training Loss: 179.283117644186, Validation Loss: 283.5436706542969
# Epoch [209/1500], Training Loss: 175.9852248791167, Validation Loss: 280.7525329589844
# Epoch [210/1500], Training Loss: 172.7652319731297, Validation Loss: 278.0462646484375
# Epoch [211/1500], Training Loss: 169.61997082700796, Validation Loss: 275.42559814453125
# Epoch [212/1500], Training Loss: 166.5467404063368, Validation Loss: 272.8858947753906
# Epoch [213/1500], Training Loss: 163.5427208576148, Validation Loss: 270.4249267578125
# Epoch [214/1500], Training Loss: 160.60651446342501, Validation Loss: 268.03826904296875
# Epoch [215/1500], Training Loss: 157.73737334519407, Validation Loss: 265.7234191894531
# Epoch [216/1500], Training Loss: 154.9307104088633, Validation Loss: 263.47491455078125
# Epoch [217/1500], Training Loss: 152.18695403851746, Validation Loss: 261.29052734375
# Epoch [218/1500], Training Loss: 149.50204499135833, Validation Loss: 259.1664733886719
# Epoch [219/1500], Training Loss: 146.8768022961592, Validation Loss: 257.1015319824219
# Epoch [220/1500], Training Loss: 144.30894824837264, Validation Loss: 255.0928955078125
# Epoch [221/1500], Training Loss: 141.79699664997446, Validation Loss: 253.13746643066406
# Epoch [222/1500], Training Loss: 139.33934576560063, Validation Loss: 251.23416137695312
# Epoch [223/1500], Training Loss: 136.93425371626697, Validation Loss: 249.3798828125
# Epoch [224/1500], Training Loss: 134.5802633794791, Validation Loss: 247.5729522705078
# Epoch [225/1500], Training Loss: 132.2773389492607, Validation Loss: 245.8119659423828
# Epoch [226/1500], Training Loss: 130.02288412070365, Validation Loss: 244.0962677001953
# Epoch [227/1500], Training Loss: 127.8167908997843, Validation Loss: 242.42172241210938
# Epoch [228/1500], Training Loss: 125.65718686475037, Validation Loss: 240.78797912597656
# Epoch [229/1500], Training Loss: 123.54372402839499, Validation Loss: 239.1935272216797
# Epoch [230/1500], Training Loss: 121.4742239591314, Validation Loss: 237.63607788085938
# Epoch [231/1500], Training Loss: 119.44969820276057, Validation Loss: 236.1146240234375
# Epoch [232/1500], Training Loss: 117.4683356724528, Validation Loss: 234.62673950195312
# Epoch [233/1500], Training Loss: 115.52876200219754, Validation Loss: 233.17115783691406
# Epoch [234/1500], Training Loss: 113.62991803718153, Validation Loss: 231.74453735351562
# Epoch [235/1500], Training Loss: 111.77038593706767, Validation Loss: 230.34600830078125
# Epoch [236/1500], Training Loss: 109.95003877330923, Validation Loss: 228.97372436523438
# Epoch [237/1500], Training Loss: 108.16852867840355, Validation Loss: 227.62660217285156
# Epoch [238/1500], Training Loss: 106.42492418953468, Validation Loss: 226.3031005859375
# Epoch [239/1500], Training Loss: 104.71752696409844, Validation Loss: 225.00022888183594
# Epoch [240/1500], Training Loss: 103.04692569533258, Validation Loss: 223.7178192138672
# Epoch [241/1500], Training Loss: 101.4112920182263, Validation Loss: 222.4544219970703
# Epoch [242/1500], Training Loss: 99.81083062826208, Validation Loss: 221.20851135253906
# Epoch [243/1500], Training Loss: 98.24487127161656, Validation Loss: 219.98036193847656
# Epoch [244/1500], Training Loss: 96.71424045996069, Validation Loss: 218.76812744140625
# Epoch [245/1500], Training Loss: 95.21700314132583, Validation Loss: 217.57220458984375
# Epoch [246/1500], Training Loss: 93.75306102299857, Validation Loss: 216.39320373535156
# Epoch [247/1500], Training Loss: 92.32188653829894, Validation Loss: 215.23048400878906
# Epoch [248/1500], Training Loss: 90.92295870786204, Validation Loss: 214.0847930908203
# Epoch [249/1500], Training Loss: 89.55676925954286, Validation Loss: 212.95816040039062
# Epoch [250/1500], Training Loss: 88.22272298931279, Validation Loss: 211.8486328125
# Epoch [251/1500], Training Loss: 86.91927324529671, Validation Loss: 210.7569122314453
# Epoch [252/1500], Training Loss: 85.6460722076412, Validation Loss: 209.6807098388672
# Epoch [253/1500], Training Loss: 84.40199313591788, Validation Loss: 208.619384765625
# Epoch [254/1500], Training Loss: 83.1865077516487, Validation Loss: 207.56887817382812
# Epoch [255/1500], Training Loss: 81.998504212559, Validation Loss: 206.52780151367188
# Epoch [256/1500], Training Loss: 80.8373951684129, Validation Loss: 205.49273681640625
# Epoch [257/1500], Training Loss: 79.70164511914354, Validation Loss: 204.46058654785156
# Epoch [258/1500], Training Loss: 78.5899751744082, Validation Loss: 203.427490234375
# Epoch [259/1500], Training Loss: 77.50186531495552, Validation Loss: 202.3902130126953
# Epoch [260/1500], Training Loss: 76.43576386458224, Validation Loss: 201.34666442871094
# Epoch [261/1500], Training Loss: 75.39152450185165, Validation Loss: 200.29161071777344
# Epoch [262/1500], Training Loss: 74.36706755987878, Validation Loss: 199.22279357910156
# Epoch [263/1500], Training Loss: 73.36185862607684, Validation Loss: 198.13595581054688
# Epoch [264/1500], Training Loss: 72.37408154961817, Validation Loss: 197.0278778076172
# Epoch [265/1500], Training Loss: 71.4027413643593, Validation Loss: 195.8944091796875
# Epoch [266/1500], Training Loss: 70.44618091963497, Validation Loss: 194.73141479492188
# Epoch [267/1500], Training Loss: 69.5028946061147, Validation Loss: 193.53456115722656
# Epoch [268/1500], Training Loss: 68.57221443958032, Validation Loss: 192.30032348632812
# Epoch [269/1500], Training Loss: 67.65220693281682, Validation Loss: 191.02268981933594
# Epoch [270/1500], Training Loss: 66.74196030682367, Validation Loss: 189.7001190185547
# Epoch [271/1500], Training Loss: 65.840512063978, Validation Loss: 188.32676696777344
# Epoch [272/1500], Training Loss: 64.94657036159367, Validation Loss: 186.8992462158203
# Epoch [273/1500], Training Loss: 64.05893161283643, Validation Loss: 185.41432189941406
# Epoch [274/1500], Training Loss: 63.176816537175114, Validation Loss: 183.87149047851562
# Epoch [275/1500], Training Loss: 62.29937901817305, Validation Loss: 182.2694091796875
# Epoch [276/1500], Training Loss: 61.426968812086216, Validation Loss: 180.6112060546875
# Epoch [277/1500], Training Loss: 60.56008890530078, Validation Loss: 178.90016174316406
# Epoch [278/1500], Training Loss: 59.69942849578125, Validation Loss: 177.14402770996094
# Epoch [279/1500], Training Loss: 58.84663507013179, Validation Loss: 175.35092163085938
# Epoch [280/1500], Training Loss: 58.00269788372103, Validation Loss: 173.52993774414062
# Epoch [281/1500], Training Loss: 57.16900648553503, Validation Loss: 171.69497680664062
# Epoch [282/1500], Training Loss: 56.34785196060432, Validation Loss: 169.85716247558594
# Epoch [283/1500], Training Loss: 55.54074859671251, Validation Loss: 168.02757263183594
# Epoch [284/1500], Training Loss: 54.74891565808038, Validation Loss: 166.2181396484375
# Epoch [285/1500], Training Loss: 53.973676830073224, Validation Loss: 164.4366912841797
# Epoch [286/1500], Training Loss: 53.21449368137781, Validation Loss: 162.6878662109375
# Epoch [287/1500], Training Loss: 52.47172870376537, Validation Loss: 160.97616577148438
# Epoch [288/1500], Training Loss: 51.74503308472222, Validation Loss: 159.3007049560547
# Epoch [289/1500], Training Loss: 51.03394193104087, Validation Loss: 157.66067504882812
# Epoch [290/1500], Training Loss: 50.33815365523277, Validation Loss: 156.05360412597656
# Epoch [291/1500], Training Loss: 49.657437562222555, Validation Loss: 154.4761962890625
# Epoch [292/1500], Training Loss: 48.9906190228322, Validation Loss: 152.9249267578125
# Epoch [293/1500], Training Loss: 48.33729267106911, Validation Loss: 151.3967742919922
# Epoch [294/1500], Training Loss: 47.69644938046543, Validation Loss: 149.88790893554688
# Epoch [295/1500], Training Loss: 47.0680695359925, Validation Loss: 148.39666748046875
# Epoch [296/1500], Training Loss: 46.4517791865133, Validation Loss: 146.92111206054688
# Epoch [297/1500], Training Loss: 45.847071236487515, Validation Loss: 145.4596405029297
# Epoch [298/1500], Training Loss: 45.25327979424688, Validation Loss: 144.00958251953125
# Epoch [299/1500], Training Loss: 44.669969100698445, Validation Loss: 142.5721893310547
# Epoch [300/1500], Training Loss: 44.09731382089929, Validation Loss: 141.14675903320312
# Epoch [301/1500], Training Loss: 43.534878954827896, Validation Loss: 139.7332305908203
# Epoch [302/1500], Training Loss: 42.982464104384384, Validation Loss: 138.33106994628906
# Epoch [303/1500], Training Loss: 42.43979468828803, Validation Loss: 136.9409942626953
# Epoch [304/1500], Training Loss: 41.90653284400499, Validation Loss: 135.56295776367188
# Epoch [305/1500], Training Loss: 41.382534905672756, Validation Loss: 134.1974639892578
# Epoch [306/1500], Training Loss: 40.867816516680946, Validation Loss: 132.84469604492188
# Epoch [307/1500], Training Loss: 40.36170037925655, Validation Loss: 131.50482177734375
# Epoch [308/1500], Training Loss: 39.86421698906521, Validation Loss: 130.17811584472656
# Epoch [309/1500], Training Loss: 39.37525736378327, Validation Loss: 128.86422729492188
# Epoch [310/1500], Training Loss: 38.89451898920114, Validation Loss: 127.56243896484375
# Epoch [311/1500], Training Loss: 38.421845063477434, Validation Loss: 126.27359771728516
# Epoch [312/1500], Training Loss: 37.95691393769274, Validation Loss: 124.99578857421875
# Epoch [313/1500], Training Loss: 37.49944456364522, Validation Loss: 123.72772979736328
# Epoch [314/1500], Training Loss: 37.048902652672695, Validation Loss: 122.46807861328125
# Epoch [315/1500], Training Loss: 36.60516523341166, Validation Loss: 121.21489715576172
# Epoch [316/1500], Training Loss: 36.16732054529774, Validation Loss: 119.9670181274414
# Epoch [317/1500], Training Loss: 35.73487069792603, Validation Loss: 118.72167205810547
# Epoch [318/1500], Training Loss: 35.30780580149491, Validation Loss: 117.47743225097656
# Epoch [319/1500], Training Loss: 34.88538508695798, Validation Loss: 116.23382568359375
# Epoch [320/1500], Training Loss: 34.468044806169225, Validation Loss: 114.9925765991211
# Epoch [321/1500], Training Loss: 34.056100051854756, Validation Loss: 113.75727081298828
# Epoch [322/1500], Training Loss: 33.65094954149345, Validation Loss: 112.53504180908203
# Epoch [323/1500], Training Loss: 33.25366395993502, Validation Loss: 111.33516693115234
# Epoch [324/1500], Training Loss: 32.86586608761793, Validation Loss: 110.1686782836914
# Epoch [325/1500], Training Loss: 32.48855163272548, Validation Loss: 109.04346466064453
# Epoch [326/1500], Training Loss: 32.122418832044374, Validation Loss: 107.96515655517578
# Epoch [327/1500], Training Loss: 31.766879688368675, Validation Loss: 106.93499755859375
# Epoch [328/1500], Training Loss: 31.420942129873016, Validation Loss: 105.9494400024414
# Epoch [329/1500], Training Loss: 31.083864726427123, Validation Loss: 105.00374603271484
# Epoch [330/1500], Training Loss: 30.754282218479158, Validation Loss: 104.09162902832031
# Epoch [331/1500], Training Loss: 30.43117313805967, Validation Loss: 103.2077407836914
# Epoch [332/1500], Training Loss: 30.11391399420008, Validation Loss: 102.3466796875
# Epoch [333/1500], Training Loss: 29.801837709090098, Validation Loss: 101.50328063964844
# Epoch [334/1500], Training Loss: 29.49429967671852, Validation Loss: 100.67378234863281
# Epoch [335/1500], Training Loss: 29.191325604802014, Validation Loss: 99.85485076904297
# Epoch [336/1500], Training Loss: 28.892354743243928, Validation Loss: 99.04385375976562
# Epoch [337/1500], Training Loss: 28.597615284322703, Validation Loss: 98.2389907836914
# Epoch [338/1500], Training Loss: 28.307029051628668, Validation Loss: 97.43932342529297
# Epoch [339/1500], Training Loss: 28.020866577295248, Validation Loss: 96.64382934570312
# Epoch [340/1500], Training Loss: 27.73906826774898, Validation Loss: 95.85331726074219
# Epoch [341/1500], Training Loss: 27.461533498498095, Validation Loss: 95.06777954101562
# Epoch [342/1500], Training Loss: 27.188344920086788, Validation Loss: 94.28861999511719
# Epoch [343/1500], Training Loss: 26.919684627477285, Validation Loss: 93.51631927490234
# Epoch [344/1500], Training Loss: 26.65554542869611, Validation Loss: 92.75253295898438
# Epoch [345/1500], Training Loss: 26.39551859527918, Validation Loss: 91.9976577758789
# Epoch [346/1500], Training Loss: 26.139871307122128, Validation Loss: 91.25221252441406
# Epoch [347/1500], Training Loss: 25.888264080642216, Validation Loss: 90.51612854003906
# Epoch [348/1500], Training Loss: 25.640558521567918, Validation Loss: 89.78944396972656
# Epoch [349/1500], Training Loss: 25.396535950056187, Validation Loss: 89.07205963134766
# Epoch [350/1500], Training Loss: 25.1559897883136, Validation Loss: 88.3636474609375
# Epoch [351/1500], Training Loss: 24.91883599649118, Validation Loss: 87.66300964355469
# Epoch [352/1500], Training Loss: 24.684510204382594, Validation Loss: 86.96956634521484
# Epoch [353/1500], Training Loss: 24.452777132193418, Validation Loss: 86.28193664550781
# Epoch [354/1500], Training Loss: 24.223688731723215, Validation Loss: 85.59993743896484
# Epoch [355/1500], Training Loss: 23.99705438508208, Validation Loss: 84.92285919189453
# Epoch [356/1500], Training Loss: 23.77235966015133, Validation Loss: 84.25023651123047
# Epoch [357/1500], Training Loss: 23.549574495459126, Validation Loss: 83.58174133300781
# Epoch [358/1500], Training Loss: 23.328664081595782, Validation Loss: 82.91768646240234
# Epoch [359/1500], Training Loss: 23.109882974763963, Validation Loss: 82.25914764404297
# Epoch [360/1500], Training Loss: 22.89319985649575, Validation Loss: 81.6070327758789
# Epoch [361/1500], Training Loss: 22.678386956205014, Validation Loss: 80.9635238647461
# Epoch [362/1500], Training Loss: 22.465741349597742, Validation Loss: 80.3308334350586
# Epoch [363/1500], Training Loss: 22.254858630700163, Validation Loss: 79.71002197265625
# Epoch [364/1500], Training Loss: 22.046041017464052, Validation Loss: 79.10060119628906
# Epoch [365/1500], Training Loss: 21.839257821579615, Validation Loss: 78.4971923828125
# Epoch [366/1500], Training Loss: 21.63439387153282, Validation Loss: 77.89070892333984
# Epoch [367/1500], Training Loss: 21.43128459251582, Validation Loss: 77.27171325683594
# Epoch [368/1500], Training Loss: 21.2295851663404, Validation Loss: 76.6341323852539
# Epoch [369/1500], Training Loss: 21.028645113595953, Validation Loss: 75.97654724121094
# Epoch [370/1500], Training Loss: 20.828402472579832, Validation Loss: 75.30213165283203
# Epoch [371/1500], Training Loss: 20.628517606294615, Validation Loss: 74.6142349243164
# Epoch [372/1500], Training Loss: 20.428551508300675, Validation Loss: 73.91561126708984
# Epoch [373/1500], Training Loss: 20.22851491184514, Validation Loss: 73.20838928222656
# Epoch [374/1500], Training Loss: 20.02799128902794, Validation Loss: 72.49212646484375
# Epoch [375/1500], Training Loss: 19.826953305467068, Validation Loss: 71.76614379882812
# Epoch [376/1500], Training Loss: 19.62516453528998, Validation Loss: 71.02910614013672
# Epoch [377/1500], Training Loss: 19.422509210200136, Validation Loss: 70.27918243408203
# Epoch [378/1500], Training Loss: 19.218968220528353, Validation Loss: 69.51516723632812
# Epoch [379/1500], Training Loss: 19.014258571784577, Validation Loss: 68.73607635498047
# Epoch [380/1500], Training Loss: 18.80850266600687, Validation Loss: 67.94087219238281
# Epoch [381/1500], Training Loss: 18.601566124160126, Validation Loss: 67.12972259521484
# Epoch [382/1500], Training Loss: 18.393423207650557, Validation Loss: 66.3025894165039
# Epoch [383/1500], Training Loss: 18.18400841182675, Validation Loss: 65.45938873291016
# Epoch [384/1500], Training Loss: 17.973461426299266, Validation Loss: 64.60128021240234
# Epoch [385/1500], Training Loss: 17.761776383211416, Validation Loss: 63.72926330566406
# Epoch [386/1500], Training Loss: 17.549098334316483, Validation Loss: 62.844810485839844
# Epoch [387/1500], Training Loss: 17.335695188136445, Validation Loss: 61.94914627075195
# Epoch [388/1500], Training Loss: 17.121606507097237, Validation Loss: 61.046077728271484
# Epoch [389/1500], Training Loss: 16.907046118956686, Validation Loss: 60.13808822631836
# Epoch [390/1500], Training Loss: 16.692074508332606, Validation Loss: 59.229408264160156
# Epoch [391/1500], Training Loss: 16.477378658225536, Validation Loss: 58.32398986816406
# Epoch [392/1500], Training Loss: 16.262776789439336, Validation Loss: 57.42655944824219
# Epoch [393/1500], Training Loss: 16.04866094280348, Validation Loss: 56.541015625
# Epoch [394/1500], Training Loss: 15.835289805737883, Validation Loss: 55.66975021362305
# Epoch [395/1500], Training Loss: 15.622896183527656, Validation Loss: 54.81662368774414
# Epoch [396/1500], Training Loss: 15.41192394722778, Validation Loss: 53.98577117919922
# Epoch [397/1500], Training Loss: 15.202856359134351, Validation Loss: 53.178035736083984
# Epoch [398/1500], Training Loss: 14.99593524836987, Validation Loss: 52.39015197753906
# Epoch [399/1500], Training Loss: 14.790381694705209, Validation Loss: 51.599266052246094
# Epoch [400/1500], Training Loss: 14.58327576032248, Validation Loss: 50.74379348754883
# Epoch [401/1500], Training Loss: 14.371487986597776, Validation Loss: 49.762046813964844
# Epoch [402/1500], Training Loss: 14.155752054994982, Validation Loss: 48.68629455566406
# Epoch [403/1500], Training Loss: 13.939116073054324, Validation Loss: 47.6009635925293
# Epoch [404/1500], Training Loss: 13.723674009243258, Validation Loss: 46.554222106933594
# Epoch [405/1500], Training Loss: 13.511161987107927, Validation Loss: 45.55834197998047
# Epoch [406/1500], Training Loss: 13.30225161528443, Validation Loss: 44.610408782958984
# Epoch [407/1500], Training Loss: 13.09744215436978, Validation Loss: 43.70395278930664
# Epoch [408/1500], Training Loss: 12.896848730973549, Validation Loss: 42.834716796875
# Epoch [409/1500], Training Loss: 12.700730726864679, Validation Loss: 41.998294830322266
# Epoch [410/1500], Training Loss: 12.508887647218538, Validation Loss: 41.1920280456543
# Epoch [411/1500], Training Loss: 12.321245374932474, Validation Loss: 40.41301727294922
# Epoch [412/1500], Training Loss: 12.137764663012199, Validation Loss: 39.66020202636719
# Epoch [413/1500], Training Loss: 11.958272892056895, Validation Loss: 38.9322395324707
# Epoch [414/1500], Training Loss: 11.782619241173927, Validation Loss: 38.227867126464844
# Epoch [415/1500], Training Loss: 11.610600337523358, Validation Loss: 37.547096252441406
# Epoch [416/1500], Training Loss: 11.442032926171876, Validation Loss: 36.88905334472656
# Epoch [417/1500], Training Loss: 11.277035931709845, Validation Loss: 36.253753662109375
# Epoch [418/1500], Training Loss: 11.11522626079577, Validation Loss: 35.64017868041992
# Epoch [419/1500], Training Loss: 10.956406184180347, Validation Loss: 35.04795837402344
# Epoch [420/1500], Training Loss: 10.800535724501628, Validation Loss: 34.477291107177734
# Epoch [421/1500], Training Loss: 10.647559944639521, Validation Loss: 33.9268913269043
# Epoch [422/1500], Training Loss: 10.497344846586742, Validation Loss: 33.3963508605957
# Epoch [423/1500], Training Loss: 10.34982943794383, Validation Loss: 32.88426971435547
# Epoch [424/1500], Training Loss: 10.205018557031313, Validation Loss: 32.39006805419922
# Epoch [425/1500], Training Loss: 10.063087484734018, Validation Loss: 31.911928176879883
# Epoch [426/1500], Training Loss: 9.924162165807703, Validation Loss: 31.448177337646484
# Epoch [427/1500], Training Loss: 9.788182228851863, Validation Loss: 30.998252868652344
# Epoch [428/1500], Training Loss: 9.655556787454524, Validation Loss: 30.560510635375977
# Epoch [429/1500], Training Loss: 9.526435559824082, Validation Loss: 30.13334846496582
# Epoch [430/1500], Training Loss: 9.400749805004937, Validation Loss: 29.71654510498047
# Epoch [431/1500], Training Loss: 9.27877612105098, Validation Loss: 29.309246063232422
# Epoch [432/1500], Training Loss: 9.160476729803797, Validation Loss: 28.91030502319336
# Epoch [433/1500], Training Loss: 9.045765866947882, Validation Loss: 28.519987106323242
# Epoch [434/1500], Training Loss: 8.934686936223763, Validation Loss: 28.138214111328125
# Epoch [435/1500], Training Loss: 8.82699427011225, Validation Loss: 27.764543533325195
# Epoch [436/1500], Training Loss: 8.72258464174334, Validation Loss: 27.398765563964844
# Epoch [437/1500], Training Loss: 8.621297114301488, Validation Loss: 27.040939331054688
# Epoch [438/1500], Training Loss: 8.522823605892407, Validation Loss: 26.69144058227539
# Epoch [439/1500], Training Loss: 8.427124780368972, Validation Loss: 26.349750518798828
# Epoch [440/1500], Training Loss: 8.334107074116304, Validation Loss: 26.01613998413086
# Epoch [441/1500], Training Loss: 8.243414973634547, Validation Loss: 25.689998626708984
# Epoch [442/1500], Training Loss: 8.155069394948704, Validation Loss: 25.3717098236084
# Epoch [443/1500], Training Loss: 8.068886792138475, Validation Loss: 25.061141967773438
# Epoch [444/1500], Training Loss: 7.984714332746387, Validation Loss: 24.758079528808594
# Epoch [445/1500], Training Loss: 7.902404159854685, Validation Loss: 24.462594985961914
# Epoch [446/1500], Training Loss: 7.822002534494265, Validation Loss: 24.174448013305664
# Epoch [447/1500], Training Loss: 7.743358268187333, Validation Loss: 23.893272399902344
# Epoch [448/1500], Training Loss: 7.666382227458497, Validation Loss: 23.61882972717285
# Epoch [449/1500], Training Loss: 7.591091167850972, Validation Loss: 23.350648880004883
# Epoch [450/1500], Training Loss: 7.517341144614605, Validation Loss: 23.088401794433594
# Epoch [451/1500], Training Loss: 7.445180665440742, Validation Loss: 22.8316593170166
# Epoch [452/1500], Training Loss: 7.3745969752322855, Validation Loss: 22.580007553100586
# Epoch [453/1500], Training Loss: 7.305437321320931, Validation Loss: 22.33325958251953
# Epoch [454/1500], Training Loss: 7.237634977902389, Validation Loss: 22.091083526611328
# Epoch [455/1500], Training Loss: 7.171268025493186, Validation Loss: 21.853260040283203
# Epoch [456/1500], Training Loss: 7.106156344352108, Validation Loss: 21.619903564453125
# Epoch [457/1500], Training Loss: 7.042294994879257, Validation Loss: 21.39081573486328
# Epoch [458/1500], Training Loss: 6.979609898785998, Validation Loss: 21.165817260742188
# Epoch [459/1500], Training Loss: 6.91820089779792, Validation Loss: 20.94493293762207
# Epoch [460/1500], Training Loss: 6.857836733839241, Validation Loss: 20.728214263916016
# Epoch [461/1500], Training Loss: 6.798544007092812, Validation Loss: 20.515531539916992
# Epoch [462/1500], Training Loss: 6.740378088379343, Validation Loss: 20.30699920654297
# Epoch [463/1500], Training Loss: 6.683257024471988, Validation Loss: 20.1026611328125
# Epoch [464/1500], Training Loss: 6.627182865655427, Validation Loss: 19.902334213256836
# Epoch [465/1500], Training Loss: 6.572125782995281, Validation Loss: 19.70612335205078
# Epoch [466/1500], Training Loss: 6.517954196572765, Validation Loss: 19.51386070251465
# Epoch [467/1500], Training Loss: 6.464661384483097, Validation Loss: 19.32554054260254
# Epoch [468/1500], Training Loss: 6.4122776541798325, Validation Loss: 19.14116096496582
# Epoch [469/1500], Training Loss: 6.3606777217818555, Validation Loss: 18.960737228393555
# Epoch [470/1500], Training Loss: 6.309892400234139, Validation Loss: 18.78424644470215
# Epoch [471/1500], Training Loss: 6.259927275548177, Validation Loss: 18.611360549926758
# Epoch [472/1500], Training Loss: 6.210789437805854, Validation Loss: 18.442113876342773
# Epoch [473/1500], Training Loss: 6.162426214069948, Validation Loss: 18.276399612426758
# Epoch [474/1500], Training Loss: 6.114753402034885, Validation Loss: 18.11425018310547
# Epoch [475/1500], Training Loss: 6.0678875491897175, Validation Loss: 17.955318450927734
# Epoch [476/1500], Training Loss: 6.02173133077956, Validation Loss: 17.79962730407715
# Epoch [477/1500], Training Loss: 5.976270119210662, Validation Loss: 17.647092819213867
# Epoch [478/1500], Training Loss: 5.931467371578212, Validation Loss: 17.497703552246094
# Epoch [479/1500], Training Loss: 5.8872858463380435, Validation Loss: 17.35116195678711
# Epoch [480/1500], Training Loss: 5.843644554789227, Validation Loss: 17.207313537597656
# Epoch [481/1500], Training Loss: 5.800623702330192, Validation Loss: 17.06612777709961
# Epoch [482/1500], Training Loss: 5.758133980126341, Validation Loss: 16.92770004272461
# Epoch [483/1500], Training Loss: 5.7161765827956925, Validation Loss: 16.79171371459961
# Epoch [484/1500], Training Loss: 5.674706678206252, Validation Loss: 16.65822410583496
# Epoch [485/1500], Training Loss: 5.6338025053308005, Validation Loss: 16.527225494384766
# Epoch [486/1500], Training Loss: 5.593325908836059, Validation Loss: 16.398691177368164
# Epoch [487/1500], Training Loss: 5.553355824065533, Validation Loss: 16.27254867553711
# Epoch [488/1500], Training Loss: 5.513874170397441, Validation Loss: 16.148710250854492
# Epoch [489/1500], Training Loss: 5.474843619379323, Validation Loss: 16.027254104614258
# Epoch [490/1500], Training Loss: 5.436302383254426, Validation Loss: 15.908158302307129
# Epoch [491/1500], Training Loss: 5.398157605948887, Validation Loss: 15.791271209716797
# Epoch [492/1500], Training Loss: 5.360431161788821, Validation Loss: 15.676977157592773
# Epoch [493/1500], Training Loss: 5.3231006719803675, Validation Loss: 15.564984321594238
# Epoch [494/1500], Training Loss: 5.286200904367692, Validation Loss: 15.455341339111328
# Epoch [495/1500], Training Loss: 5.249738991956453, Validation Loss: 15.34821605682373
# Epoch [496/1500], Training Loss: 5.213674352069847, Validation Loss: 15.24350643157959
# Epoch [497/1500], Training Loss: 5.178023347460122, Validation Loss: 15.141298294067383
# Epoch [498/1500], Training Loss: 5.142730840867085, Validation Loss: 15.041600227355957
# Epoch [499/1500], Training Loss: 5.107831203718257, Validation Loss: 14.94417953491211
# Epoch [500/1500], Training Loss: 5.0733668748707395, Validation Loss: 14.849032402038574
# Epoch [501/1500], Training Loss: 5.0392602494851975, Validation Loss: 14.756133079528809
# Epoch [502/1500], Training Loss: 5.00553810774933, Validation Loss: 14.665367126464844
# Epoch [503/1500], Training Loss: 4.972265449473948, Validation Loss: 14.576676368713379
# Epoch [504/1500], Training Loss: 4.939435261403591, Validation Loss: 14.48961353302002
# Epoch [505/1500], Training Loss: 4.906988336140727, Validation Loss: 14.404479026794434
# Epoch [506/1500], Training Loss: 4.874955706018985, Validation Loss: 14.320785522460938
# Epoch [507/1500], Training Loss: 4.843359032282512, Validation Loss: 14.238428115844727
# Epoch [508/1500], Training Loss: 4.8121860704376305, Validation Loss: 14.156929016113281
# Epoch [509/1500], Training Loss: 4.781359491964491, Validation Loss: 14.076504707336426
# Epoch [510/1500], Training Loss: 4.750891466315497, Validation Loss: 13.996728897094727
# Epoch [511/1500], Training Loss: 4.720866484940655, Validation Loss: 13.917403221130371
# Epoch [512/1500], Training Loss: 4.691121727069268, Validation Loss: 13.83787727355957
# Epoch [513/1500], Training Loss: 4.661712012727056, Validation Loss: 13.758291244506836
# Epoch [514/1500], Training Loss: 4.632597653190118, Validation Loss: 13.678149223327637
# Epoch [515/1500], Training Loss: 4.603779232242034, Validation Loss: 13.597379684448242
# Epoch [516/1500], Training Loss: 4.57520476954846, Validation Loss: 13.515543937683105
# Epoch [517/1500], Training Loss: 4.546752442621508, Validation Loss: 13.432133674621582
# Epoch [518/1500], Training Loss: 4.51840373734506, Validation Loss: 13.346733093261719
# Epoch [519/1500], Training Loss: 4.490171522262516, Validation Loss: 13.25861930847168
# Epoch [520/1500], Training Loss: 4.461858578018791, Validation Loss: 13.167128562927246
# Epoch [521/1500], Training Loss: 4.433545648280917, Validation Loss: 13.070830345153809
# Epoch [522/1500], Training Loss: 4.405095306354264, Validation Loss: 12.969932556152344
# Epoch [523/1500], Training Loss: 4.3764585686154405, Validation Loss: 12.864547729492188
# Epoch [524/1500], Training Loss: 4.347764830565538, Validation Loss: 12.75528335571289
# Epoch [525/1500], Training Loss: 4.318932381763716, Validation Loss: 12.642179489135742
# Epoch [526/1500], Training Loss: 4.290009708491281, Validation Loss: 12.52613639831543
# Epoch [527/1500], Training Loss: 4.261039317984935, Validation Loss: 12.406937599182129
# Epoch [528/1500], Training Loss: 4.231950473007101, Validation Loss: 12.284992218017578
# Epoch [529/1500], Training Loss: 4.202854851583029, Validation Loss: 12.160696983337402
# Epoch [530/1500], Training Loss: 4.173681297931293, Validation Loss: 12.03369426727295
# Epoch [531/1500], Training Loss: 4.144485578442272, Validation Loss: 11.90475082397461
# Epoch [532/1500], Training Loss: 4.11521664260883, Validation Loss: 11.773529052734375
# Epoch [533/1500], Training Loss: 4.085941818350797, Validation Loss: 11.64036750793457
# Epoch [534/1500], Training Loss: 4.056643070020985, Validation Loss: 11.505382537841797
# Epoch [535/1500], Training Loss: 4.027354132182727, Validation Loss: 11.369142532348633
# Epoch [536/1500], Training Loss: 3.9981436847636407, Validation Loss: 11.23098373413086
# Epoch [537/1500], Training Loss: 3.968932484387193, Validation Loss: 11.091498374938965
# Epoch [538/1500], Training Loss: 3.939755418925059, Validation Loss: 10.950662612915039
# Epoch [539/1500], Training Loss: 3.9105996681142323, Validation Loss: 10.808687210083008
# Epoch [540/1500], Training Loss: 3.881440119473516, Validation Loss: 10.66540813446045
# Epoch [541/1500], Training Loss: 3.852270948757919, Validation Loss: 10.521403312683105
# Epoch [542/1500], Training Loss: 3.8231035857538185, Validation Loss: 10.376044273376465
# Epoch [543/1500], Training Loss: 3.7939498712521478, Validation Loss: 10.229940414428711
# Epoch [544/1500], Training Loss: 3.7647971679894776, Validation Loss: 10.083098411560059
# Epoch [545/1500], Training Loss: 3.7356470885249227, Validation Loss: 9.93632698059082
# Epoch [546/1500], Training Loss: 3.7065169026916114, Validation Loss: 9.7903413772583
# Epoch [547/1500], Training Loss: 3.677437648997027, Validation Loss: 9.6463623046875
# Epoch [548/1500], Training Loss: 3.6485501936996916, Validation Loss: 9.50552749633789
# Epoch [549/1500], Training Loss: 3.6199880406244733, Validation Loss: 9.370373725891113
# Epoch [550/1500], Training Loss: 3.591762267454882, Validation Loss: 9.24141788482666
# Epoch [551/1500], Training Loss: 3.5638103015746805, Validation Loss: 9.1176118850708
# Epoch [552/1500], Training Loss: 3.5360903775998764, Validation Loss: 8.996586799621582
# Epoch [553/1500], Training Loss: 3.5086547229365674, Validation Loss: 8.878424644470215
# Epoch [554/1500], Training Loss: 3.481553484905953, Validation Loss: 8.762760162353516
# Epoch [555/1500], Training Loss: 3.4548134689274588, Validation Loss: 8.649985313415527
# Epoch [556/1500], Training Loss: 3.4284579063248324, Validation Loss: 8.539851188659668
# Epoch [557/1500], Training Loss: 3.4025627292945932, Validation Loss: 8.432613372802734
# Epoch [558/1500], Training Loss: 3.3771135405933594, Validation Loss: 8.32856559753418
# Epoch [559/1500], Training Loss: 3.3521371229576635, Validation Loss: 8.228066444396973
# Epoch [560/1500], Training Loss: 3.3276228108462726, Validation Loss: 8.131139755249023
# Epoch [561/1500], Training Loss: 3.3036013005257447, Validation Loss: 8.03823471069336
# Epoch [562/1500], Training Loss: 3.2800400928992737, Validation Loss: 7.949420928955078
# Epoch [563/1500], Training Loss: 3.25696628607307, Validation Loss: 7.8656487464904785
# Epoch [564/1500], Training Loss: 3.2343637719865113, Validation Loss: 7.787109375
# Epoch [565/1500], Training Loss: 3.2122489110151307, Validation Loss: 7.714339733123779
# Epoch [566/1500], Training Loss: 3.19060298562645, Validation Loss: 7.6475605964660645
# Epoch [567/1500], Training Loss: 3.1693543931532813, Validation Loss: 7.587519645690918
# Epoch [568/1500], Training Loss: 3.148506274106141, Validation Loss: 7.533976078033447
# Epoch [569/1500], Training Loss: 3.1280775997589267, Validation Loss: 7.487339019775391
# Epoch [570/1500], Training Loss: 3.108014025413924, Validation Loss: 7.447278022766113
# Epoch [571/1500], Training Loss: 3.0883291722362434, Validation Loss: 7.413814544677734
# Epoch [572/1500], Training Loss: 3.068948966933109, Validation Loss: 7.386017799377441
# Epoch [573/1500], Training Loss: 3.049927347134273, Validation Loss: 7.363580703735352
# Epoch [574/1500], Training Loss: 3.031252395787576, Validation Loss: 7.344685077667236
# Epoch [575/1500], Training Loss: 3.0129236242880495, Validation Loss: 7.327849388122559
# Epoch [576/1500], Training Loss: 2.994912379667257, Validation Loss: 7.310379505157471
# Epoch [577/1500], Training Loss: 2.977276739231776, Validation Loss: 7.290486812591553
# Epoch [578/1500], Training Loss: 2.9600515657309376, Validation Loss: 7.2663493156433105
# Epoch [579/1500], Training Loss: 2.943283153276781, Validation Loss: 7.235772609710693
# Epoch [580/1500], Training Loss: 2.926989708756768, Validation Loss: 7.199095726013184
# Epoch [581/1500], Training Loss: 2.911217561446538, Validation Loss: 7.156094551086426
# Epoch [582/1500], Training Loss: 2.895978528580875, Validation Loss: 7.108216762542725
# Epoch [583/1500], Training Loss: 2.881237954104552, Validation Loss: 7.055438041687012
# Epoch [584/1500], Training Loss: 2.866946980341235, Validation Loss: 6.9998087882995605
# Epoch [585/1500], Training Loss: 2.853040161812967, Validation Loss: 6.94036340713501
# Epoch [586/1500], Training Loss: 2.8395206064505016, Validation Loss: 6.8777008056640625
# Epoch [587/1500], Training Loss: 2.8263386498707352, Validation Loss: 6.812519550323486
# Epoch [588/1500], Training Loss: 2.8135016693510067, Validation Loss: 6.7458600997924805
# Epoch [589/1500], Training Loss: 2.8009883953127717, Validation Loss: 6.6775007247924805
# Epoch [590/1500], Training Loss: 2.7887426525020844, Validation Loss: 6.6079888343811035
# Epoch [591/1500], Training Loss: 2.7767800248527186, Validation Loss: 6.538323879241943
# Epoch [592/1500], Training Loss: 2.7650648344682693, Validation Loss: 6.469100475311279
# Epoch [593/1500], Training Loss: 2.7536450464604467, Validation Loss: 6.400177001953125
# Epoch [594/1500], Training Loss: 2.7424348163028016, Validation Loss: 6.3325395584106445
# Epoch [595/1500], Training Loss: 2.7314361336472848, Validation Loss: 6.266059875488281
# Epoch [596/1500], Training Loss: 2.7206516479627787, Validation Loss: 6.201547622680664
# Epoch [597/1500], Training Loss: 2.710042014428097, Validation Loss: 6.138277530670166
# Epoch [598/1500], Training Loss: 2.6996684564696802, Validation Loss: 6.07685661315918
# Epoch [599/1500], Training Loss: 2.689445218377905, Validation Loss: 6.017796039581299
# Epoch [600/1500], Training Loss: 2.679385699781631, Validation Loss: 5.960848808288574
# Epoch [601/1500], Training Loss: 2.669534349204305, Validation Loss: 5.906064987182617
# Epoch [602/1500], Training Loss: 2.6598379424284873, Validation Loss: 5.8532633781433105
# Epoch [603/1500], Training Loss: 2.6502854423651154, Validation Loss: 5.802666187286377
# Epoch [604/1500], Training Loss: 2.640881859950291, Validation Loss: 5.754230976104736
# Epoch [605/1500], Training Loss: 2.6316146591459058, Validation Loss: 5.707956314086914
# Epoch [606/1500], Training Loss: 2.6224801744490076, Validation Loss: 5.663461685180664
# Epoch [607/1500], Training Loss: 2.6134822685121035, Validation Loss: 5.621246337890625
# Epoch [608/1500], Training Loss: 2.6046016935900607, Validation Loss: 5.580820083618164
# Epoch [609/1500], Training Loss: 2.595861272330295, Validation Loss: 5.542362213134766
# Epoch [610/1500], Training Loss: 2.5872511269702216, Validation Loss: 5.505550861358643
# Epoch [611/1500], Training Loss: 2.5787789123525653, Validation Loss: 5.470489025115967
# Epoch [612/1500], Training Loss: 2.570415611254928, Validation Loss: 5.43696928024292
# Epoch [613/1500], Training Loss: 2.562154056936842, Validation Loss: 5.4051032066345215
# Epoch [614/1500], Training Loss: 2.5539802774727347, Validation Loss: 5.374584197998047
# Epoch [615/1500], Training Loss: 2.545852016352969, Validation Loss: 5.345478057861328
# Epoch [616/1500], Training Loss: 2.5378294690794463, Validation Loss: 5.317828178405762
# Epoch [617/1500], Training Loss: 2.5298892335775283, Validation Loss: 5.291369915008545
# Epoch [618/1500], Training Loss: 2.522054581151173, Validation Loss: 5.266121864318848
# Epoch [619/1500], Training Loss: 2.514290544919777, Validation Loss: 5.241944789886475
# Epoch [620/1500], Training Loss: 2.5066099645213544, Validation Loss: 5.218893051147461
# Epoch [621/1500], Training Loss: 2.4990079941365297, Validation Loss: 5.1968278884887695
# Epoch [622/1500], Training Loss: 2.4914991288148163, Validation Loss: 5.175693035125732
# Epoch [623/1500], Training Loss: 2.484099955873246, Validation Loss: 5.155431747436523
# Epoch [624/1500], Training Loss: 2.476767485618001, Validation Loss: 5.135951042175293
# Epoch [625/1500], Training Loss: 2.4695518661952685, Validation Loss: 5.117324352264404
# Epoch [626/1500], Training Loss: 2.462423864486219, Validation Loss: 5.09941291809082
# Epoch [627/1500], Training Loss: 2.4554075116011576, Validation Loss: 5.0820841789245605
# Epoch [628/1500], Training Loss: 2.448476386726106, Validation Loss: 5.0654377937316895
# Epoch [629/1500], Training Loss: 2.44160979383404, Validation Loss: 5.049357891082764
# Epoch [630/1500], Training Loss: 2.4348170001524077, Validation Loss: 5.033710479736328
# Epoch [631/1500], Training Loss: 2.4280659399581603, Validation Loss: 5.018565654754639
# Epoch [632/1500], Training Loss: 2.4213711178986337, Validation Loss: 5.0039448738098145
# Epoch [633/1500], Training Loss: 2.4147289521966013, Validation Loss: 4.989741802215576
# Epoch [634/1500], Training Loss: 2.408128072413264, Validation Loss: 4.975868225097656
# Epoch [635/1500], Training Loss: 2.4016036043888054, Validation Loss: 4.962388038635254
# Epoch [636/1500], Training Loss: 2.3951259684978776, Validation Loss: 4.9492082595825195
# Epoch [637/1500], Training Loss: 2.388690352731555, Validation Loss: 4.936434268951416
# Epoch [638/1500], Training Loss: 2.382310356207001, Validation Loss: 4.92384147644043
# Epoch [639/1500], Training Loss: 2.3760010546912262, Validation Loss: 4.911606311798096
# Epoch [640/1500], Training Loss: 2.369720342555902, Validation Loss: 4.899378776550293
# Epoch [641/1500], Training Loss: 2.3635019679207074, Validation Loss: 4.887796401977539
# Epoch [642/1500], Training Loss: 2.3573414360402514, Validation Loss: 4.875439643859863
# Epoch [643/1500], Training Loss: 2.3512738794983443, Validation Loss: 4.866054058074951
# Epoch [644/1500], Training Loss: 2.3451936010187673, Validation Loss: 4.848300933837891
# Epoch [645/1500], Training Loss: 2.339418001108652, Validation Loss: 4.853768825531006
# Epoch [646/1500], Training Loss: 2.333043855736372, Validation Loss: 4.800581932067871
# Epoch [647/1500], Training Loss: 2.3323804441503952, Validation Loss: 4.813673496246338
# Epoch [648/1500], Training Loss: 2.3214713023283937, Validation Loss: 4.8201584815979
# Epoch [649/1500], Training Loss: 2.315756211925082, Validation Loss: 4.777400493621826
# Epoch [650/1500], Training Loss: 2.31494394999067, Validation Loss: 4.78840970993042
# Epoch [651/1500], Training Loss: 2.304298842327913, Validation Loss: 4.789182662963867
# Epoch [652/1500], Training Loss: 2.2987801371924794, Validation Loss: 4.752484321594238
# Epoch [653/1500], Training Loss: 2.2973189113640964, Validation Loss: 4.766423225402832
# Epoch [654/1500], Training Loss: 2.287403681506059, Validation Loss: 4.746416091918945
# Epoch [655/1500], Training Loss: 2.2827703544505824, Validation Loss: 4.767605781555176
# Epoch [656/1500], Training Loss: 2.2771313312430186, Validation Loss: 4.720732688903809
# Epoch [657/1500], Training Loss: 2.2740281186253166, Validation Loss: 4.747533321380615
# Epoch [658/1500], Training Loss: 2.2657880646380444, Validation Loss: 4.700199127197266
# Epoch [659/1500], Training Loss: 2.2640428173838796, Validation Loss: 4.727470874786377
# Epoch [660/1500], Training Loss: 2.2551710237767435, Validation Loss: 4.685100555419922
# Epoch [661/1500], Training Loss: 2.253389700384496, Validation Loss: 4.712741851806641
# Epoch [662/1500], Training Loss: 2.2448996211274634, Validation Loss: 4.669720649719238
# Epoch [663/1500], Training Loss: 2.2430887206390864, Validation Loss: 4.699873447418213
# Epoch [664/1500], Training Loss: 2.2347887812164315, Validation Loss: 4.654858589172363
# Epoch [665/1500], Training Loss: 2.232890722258599, Validation Loss: 4.688673973083496
# Epoch [666/1500], Training Loss: 2.2248956215471267, Validation Loss: 4.640786647796631
# Epoch [667/1500], Training Loss: 2.2228523421880766, Validation Loss: 4.679145812988281
# Epoch [668/1500], Training Loss: 2.215246320296497, Validation Loss: 4.627316474914551
# Epoch [669/1500], Training Loss: 2.2129524368865217, Validation Loss: 4.6709208488464355
# Epoch [670/1500], Training Loss: 2.205810684636835, Validation Loss: 4.61386251449585
# Epoch [671/1500], Training Loss: 2.2032311424882822, Validation Loss: 4.663834095001221
# Epoch [672/1500], Training Loss: 2.1965899970253915, Validation Loss: 4.601084232330322
# Epoch [673/1500], Training Loss: 2.1937036351815293, Validation Loss: 4.658126354217529
# Epoch [674/1500], Training Loss: 2.1876357517704617, Validation Loss: 4.588797092437744
# Epoch [675/1500], Training Loss: 2.1843787330330997, Validation Loss: 4.653809547424316
# Epoch [676/1500], Training Loss: 2.1789497448204433, Validation Loss: 4.576878070831299
# Epoch [677/1500], Training Loss: 2.175214771520109, Validation Loss: 4.650688171386719
# Epoch [678/1500], Training Loss: 2.170507340366513, Validation Loss: 4.565209865570068
# Epoch [679/1500], Training Loss: 2.166217614991357, Validation Loss: 4.648828029632568
# Epoch [680/1500], Training Loss: 2.1623081105788526, Validation Loss: 4.5536675453186035
# Epoch [681/1500], Training Loss: 2.157395333330502, Validation Loss: 4.648466110229492
# Epoch [682/1500], Training Loss: 2.1543498378851074, Validation Loss: 4.542614936828613
# Epoch [683/1500], Training Loss: 2.148744845082885, Validation Loss: 4.648870468139648
# Epoch [684/1500], Training Loss: 2.1465449319101264, Validation Loss: 4.532285690307617
# Epoch [685/1500], Training Loss: 2.1403000431115977, Validation Loss: 4.648741245269775
# Epoch [686/1500], Training Loss: 2.1384353483713276, Validation Loss: 4.526737689971924
# Epoch [687/1500], Training Loss: 2.1320310759802683, Validation Loss: 4.6501784324646
# Epoch [688/1500], Training Loss: 2.1302716038539398, Validation Loss: 4.522166728973389
# Epoch [689/1500], Training Loss: 2.123923688162301, Validation Loss: 4.652158737182617
# Epoch [690/1500], Training Loss: 2.1223731050616497, Validation Loss: 4.516252040863037
# Epoch [691/1500], Training Loss: 2.115989058294699, Validation Loss: 4.653401851654053
# Epoch [692/1500], Training Loss: 2.1143451659012005, Validation Loss: 4.514631271362305
# Epoch [693/1500], Training Loss: 2.1082315772772113, Validation Loss: 4.657715797424316
# Epoch [694/1500], Training Loss: 2.107137063089798, Validation Loss: 4.503313064575195
# Epoch [695/1500], Training Loss: 2.100725035079775, Validation Loss: 4.654580593109131
# Epoch [696/1500], Training Loss: 2.097849071501026, Validation Loss: 4.532561779022217
# Epoch [697/1500], Training Loss: 2.093250961183455, Validation Loss: 4.672178745269775
# Epoch [698/1500], Training Loss: 2.09291859794815, Validation Loss: 4.479890823364258
# Epoch [699/1500], Training Loss: 2.0859024272731093, Validation Loss: 4.650299549102783
# Epoch [700/1500], Training Loss: 2.0817595473563033, Validation Loss: 4.58610200881958
# Epoch [701/1500], Training Loss: 2.0787398571291056, Validation Loss: 4.675652027130127
# Epoch [702/1500], Training Loss: 2.07722155684536, Validation Loss: 4.4838972091674805
# Epoch [703/1500], Training Loss: 2.0712603035137795, Validation Loss: 4.662775993347168
# Epoch [704/1500], Training Loss: 2.069652635653714, Validation Loss: 4.506190776824951
# Epoch [705/1500], Training Loss: 2.064291290516715, Validation Loss: 4.683769226074219
# Epoch [706/1500], Training Loss: 2.064829258370139, Validation Loss: 4.4666852951049805
# Epoch [707/1500], Training Loss: 2.0575491272452777, Validation Loss: 4.6718268394470215
# Epoch [708/1500], Training Loss: 2.053552684047258, Validation Loss: 4.629980087280273
# Epoch [709/1500], Training Loss: 2.0500084862393635, Validation Loss: 4.679211616516113
# Epoch [710/1500], Training Loss: 2.051220293418788, Validation Loss: 4.455163478851318
# Epoch [711/1500], Training Loss: 2.0439242859602467, Validation Loss: 4.67702054977417
# Epoch [712/1500], Training Loss: 2.0401333002479363, Validation Loss: 4.651354789733887
# Epoch [713/1500], Training Loss: 2.0364790884774946, Validation Loss: 4.64579963684082
# Epoch [714/1500], Training Loss: 2.03310522213894, Validation Loss: 4.6399736404418945
# Epoch [715/1500], Training Loss: 2.029821299671357, Validation Loss: 4.6393585205078125
# Epoch [716/1500], Training Loss: 2.0265025237782828, Validation Loss: 4.624240398406982
# Epoch [717/1500], Training Loss: 2.0233789191172464, Validation Loss: 4.675123691558838
# Epoch [718/1500], Training Loss: 2.0249493026985057, Validation Loss: 4.440403938293457
# Epoch [719/1500], Training Loss: 2.017875631558909, Validation Loss: 4.694000720977783
# Epoch [720/1500], Training Loss: 2.0143691128293337, Validation Loss: 4.66558837890625
# Epoch [721/1500], Training Loss: 2.0110216526343603, Validation Loss: 4.683964729309082
# Epoch [722/1500], Training Loss: 2.008291347697479, Validation Loss: 4.582209587097168
# Epoch [723/1500], Training Loss: 2.005613869095113, Validation Loss: 4.758283615112305
# Epoch [724/1500], Training Loss: 2.005594679856606, Validation Loss: 4.464714527130127
# Epoch [725/1500], Training Loss: 1.9993994340249728, Validation Loss: 4.735139846801758
# Epoch [726/1500], Training Loss: 1.9964876209375741, Validation Loss: 4.618210792541504
# Epoch [727/1500], Training Loss: 1.9937921962897174, Validation Loss: 4.7914042472839355
# Early stopping at epoch 727
# Final Test Loss: 5.590009689331055

# %%
# Assuming you have a trained model and scaler from previous steps


# Define the window size (from your hyperparameter)
window_size = window_sizes[0]

# Extract the last `window_size` entries
last_window = data.tail(window_size)

# Prepare the input data
x_last_window = last_window[['open', 'high', 'low', 'volume', 'adjusted_close', 'change_percent', 'avg_vol_20d']]

# Normalize the input data using the same scaler
x_last_window_normalized = scaler.transform(x_last_window)

# Convert to PyTorch tensor
x_last_window_tensor = torch.tensor(x_last_window_normalized, dtype=torch.float32).unsqueeze(0)  # Add batch dimension

# Make prediction
model.eval()
with torch.no_grad():
    predicted_close = model(x_last_window_tensor)

print(f"Predicted Next Day's Close Value: {predicted_close.item()}")
# Out:
# Predicted Next Day's Close Value: 196.0170135498047

# %%
# Define the window size
window_size = window_sizes[0]

# Extract the last `window_size` entries
last_window = data.tail(window_size)

print("Last window for prediction:")
print(last_window)
# Out:
# Last window for prediction:
#              open        high         low       close      volume  \
# 10742  193.330002  194.440002  192.919998  193.619995  37283200.0
# 10743  193.669998  195.639999  193.320007  194.500000  47471900.0
# 10744  196.020004  197.199997  192.550003  193.220001  47460200.0
# 10745  194.669998  196.630005  194.139999  195.830002  48291400.0
# 10746  196.059998  196.490005  195.259995  196.449997  38824100.0
#
#        adjusted_close  change_percent  avg_vol_20d
# 10742      193.358902            0.45   52369164.0
# 10743      194.237701            0.45   52206220.0
# 10744      192.959396           -0.66   52018392.0
# 10745      195.565903            1.35   52115596.0
# 10746      196.185104            0.32   49803320.0

# %%
o
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 o
#
# NameError: name 'o' is not defined

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from sklearn import metrics
import numpy as npw
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler


def split_data_with_window(x_in, y_in, split_window_size):
    # Initialize lists to store training and temporary sets
    x_out1_list, y_out1_list, x_out2_list, y_out2_list = [], [], [], []

    # Iterate through the data with the specified window size
    for i in range(0, len(x_in) - split_window_size, split_window_size + 1):
        x_out1_out2 = x_in.iloc[i:i+split_window_size+1]
        y_out1_out2 = y_in.iloc[i:i+split_window_size+1]

        # Separate the last row for the temporary set
        # [ :-1]: all elements except the last one
        # [-1:]:  selects only the last element
        # (:) is used to indicate slicing of a sequence
        # sequence[start : end : step]

        x_out1 = x_out1_out2.iloc[:-1]
        y_out1 = y_out1_out2.iloc[:-1]

        x_out2 = x_out1_out2.iloc[-1:]
        y_out2 = y_out1_out2.iloc[-1:]

        x_out1_list.append(x_out1)
        y_out1_list.append(y_out1)
        x_out2_list.append(x_out2)
        y_out2_list.append(y_out2)

    # Concatenate the lists into pandas DataFrames
    x_out1 = pd.concat(x_out1_list)
    y_out1 = pd.concat(y_out1_list)
    x_out2 = pd.concat(x_out2_list)
    y_out2 = pd.concat(y_out2_list)

    return x_out1, y_out1, x_out2, y_out2










# Read the CSV file
data = pd.read_csv("../data/data/aapl_raw_data.csv")

data = data.drop("date", axis=1)

data.isnull().sum()
data=data.fillna(0)  # Filling null values with zero
data.isnull().sum()

data = data.astype('float32')


# Keep data until 31.08.2023
data = data.iloc[:10731]

#print(data['open'].dtype)
#print(data.shape)

# Assuming 'data' is a pandas DataFrame
x_data = data[['open', 'high', 'low', 'volume', 'adjusted_close', 'change_percent', 'avg_vol_20d']]
y_data = data["close"]

# Now x_data and y_data are pandas DataFrames/Series, respectively

x_data.tail(1)



# Split Data to train and temp

# Define your split_window_size
split_window_size = 3

# Call the split_data_with_window function
x_train, y_train, x_temp, y_temp = split_data_with_window(x_data, y_data, split_window_size)


"""

# Print the last 5 rows of x_data
print("Last 5 rows of x_data:")
print(x_data.tail(5))

# Print the last 5 rows of x_train
print("\nLast 25 rows of x_train:")
print(x_train.tail(25))

print("\nLast 3 rows of y_train:")
print(y_temp.tail(3))

"""

# Split temp into val and test

# Define your split_window_size
split_window_size = 1

# Call the split_data_with_window function
x_val, y_val, x_test, y_test = split_data_with_window(x_temp, y_temp, split_window_size)




scaler = MinMaxScaler()

x_train_normalized = scaler.fit_transform(x_train)
x_val_normalized = scaler.transform(x_val)
x_test_normalized = scaler.transform(x_test)

# Convert the data to PyTorch tensors
x_train_tensor = torch.tensor(x_train_normalized, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).view(-1, 1)

x_val_tensor = torch.tensor(x_val_normalized, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val.values, dtype=torch.float32).view(-1, 1)

x_test_tensor = torch.tensor(x_test_normalized, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).view(-1, 1)


"""
# x_train_tensor inverse

x_test_original = scaler.inverse_transform(x_train_tensor.numpy())
print("\nFirst row of x_test_original:")
print(x_test_original[0])

print("\nFirst row of x_train:")
print(x_train.head(1))



print("\nLast row of x_test_original:")
print(x_test_original[-1])

print("\nLast row of x_train:")
print(x_train.tail(1))
"""









class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, learning_rate, window_size):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.window_size = window_size
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)
        self.learning_rate = learning_rate

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        out, _ = self.lstm(x, (h0, c0))

        out = self.fc(out[:, -1, :])
        return out




    import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]
hidden_sizes = [4]
num_layers_list = [1]
learning_rates = [0.0003]
window_sizes = [5]

num_epochs = 1500
patience = 10  # Number of epochs to wait for improvement



# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')





    #------------------------------------------------------------------------------

    import pandas as pd

# Load the dataset
data = pd.read_csv("../data/data/aapl_raw_data.csv")

# Drop any non-numeric columns that are not needed for prediction
data = data.drop("date", axis=1)

# Define the window size
window_size = window_sizes[0]

# Extract the last `window_size` entries
last_window = data.tail(window_size)

#print("Last window for prediction:")
#print(last_window)
