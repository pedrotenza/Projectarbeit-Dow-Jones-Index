# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from sklearn import metrics
import numpy as npw
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler


# Read the CSV file
data = pd.read_csv("../data/data/aapl_raw_data.csv")

data = data.drop("date", axis=1)

data.isnull().sum()
data=data.fillna(0)  # Filling null values with zero
data.isnull().sum()

data = data.astype('float32')


# Keep data until 31.08.2023
data = data.iloc[:10731]

#print(data['open'].dtype)
#print(data.shape)

# Assuming 'data' is a pandas DataFrame
x_data = data[['open', 'high', 'low', 'volume', 'adjusted_close', 'change_percent', 'avg_vol_20d']]
y_data = data["close"]

# Now x_data and y_data are pandas DataFrames/Series, respectively

x_data.tail(1)




# size of the window for data preparation
split_window_size = 20

# Initialize lists to store training and temporary sets
x_train_list, y_train_list, x_temp_list, y_temp_list = [], [], [], []

# Iterate through the data with the specified window size
for i in range(0, len(x_data) - split_window_size, split_window_size + 1):
    x_train_temp = x_data.iloc[i:i+split_window_size+1]
    y_train_temp = y_data.iloc[i:i+split_window_size+1]

    # Separate the last row for the temporary set
    x_train = x_train_temp.iloc[:-1]
    y_train = y_train_temp.iloc[:-1]

    x_temp = x_train_temp.iloc[-1:]
    y_temp = y_train_temp.iloc[-1:]

    x_train_list.append(x_train)
    y_train_list.append(y_train)
    x_temp_list.append(x_temp)
    y_temp_list.append(y_temp)

# Concatenate the lists into pandas DataFrames
x_train = pd.concat(x_train_list)
y_train = pd.concat(y_train_list)
x_temp = pd.concat(x_temp_list)
y_temp = pd.concat(y_temp_list)

# print(y_train.head(50))
x_temp_train, x_temp_val, y_temp_train, y_temp_val = train_test_split(x_temp, y_temp, test_size=0.2, random_state=42)


# Split x_temp and y_temp into validation and test sets
x_val, x_test, y_val, y_test = train_test_split(
    x_temp, y_temp, test_size=0.5, random_state=42)


"""
# Print the last 5 rows of x_data
print("Last 5 rows of x_data:")
print(x_data.tail(5))

# Print the last 5 rows of x_train
print("\nLast 25 rows of x_train:")
print(x_train.tail(25))

print("\nLast 3 rows of y_train:")
print(y_temp.tail(3))
"""




scaler = MinMaxScaler()

x_train_normalized = scaler.fit_transform(x_train)
x_val_normalized = scaler.transform(x_val)
x_test_normalized = scaler.transform(x_test)

# Convert the data to PyTorch tensors
x_train_tensor = torch.tensor(x_train_normalized, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).view(-1, 1)

x_val_tensor = torch.tensor(x_val_normalized, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val.values, dtype=torch.float32).view(-1, 1)

x_test_tensor = torch.tensor(x_test_normalized, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).view(-1, 1)




"""
# x_train_tensor inverse

x_test_original = scaler.inverse_transform(x_train_tensor.numpy())
print("\nFirst row of x_test_original:")
print(x_test_original[0])

print("\nFirst row of x_train:")
print(x_train.head(1))



print("\nLast row of x_test_original:")
print(x_test_original[-1])

print("\nLast row of x_train:")
print(x_train.tail(1))
"""
# Out:
# '\n# x_train_tensor inverse\n\nx_test_original = scaler.inverse_transform(x_train_tensor.numpy())\nprint("\nFirst row of x_test_original:")\nprint(x_test_original[0])\n\nprint("\nFirst row of x_train:")\nprint(x_train.head(1))\n\n\n\nprint("\nLast row of x_test_original:")\nprint(x_test_original[-1])\n\nprint("\nLast row of x_train:")\nprint(x_train.tail(1))\n'

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, learning_rate, window_size):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.window_size = window_size
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)
        self.learning_rate = learning_rate

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        out, _ = self.lstm(x, (h0, c0))

        out = self.fc(out[:, -1, :])
        return out

# %%
import torch
import torch.nn as nn

window_size = 1

input_size = 7
hidden_size = 16
num_layers = 4

learning_rate = 0.001



num_epochs = 300


model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

# Define the loss function and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Define the size of the sliding window
# sliding_window_size = 1

# Walk-forward validation training with sliding window
for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    running_loss = 0.0

    # Train the model using sliding window approach
    for i in range(len(x_train_tensor)):
        # Determine the end index of the current window
        window_end = min(i + window_size, len(x_train_tensor))

        # Extract the current window of data
        inputs = x_train_tensor[i:window_end].unsqueeze(0)  # Add extra dimensions for batch and sequence length
        labels = y_train_tensor[window_end - 1]  # Label is the last value in the window

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    # Validate the model after each epoch using x_val_tensor and y_val_tensor
    model.eval()  # Set the model to evaluation mode
    val_loss = 0.0

    with torch.no_grad():
        for i in range(len(x_val_tensor)):
            # Determine the end index of the current window
            window_end = min(i + window_size, len(x_val_tensor))

            inputs = x_val_tensor[i:window_end].unsqueeze(0)
            labels = y_val_tensor[window_end - 1]

            outputs = model(inputs)
            val_loss += criterion(outputs, labels)

    print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')
# Out:
# c:\Projectarbeit-Dow-Jones-Index\.venv\lib\site-packages\torch\nn\modules\loss.py:536: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/300], Training Loss: 17726.996224456307, Validation Loss: 18998.43359375
# Epoch [2/300], Training Loss: 14284.579095399544, Validation Loss: 18811.296875
# Epoch [3/300], Training Loss: 10768.255800372946, Validation Loss: 21414.986328125
# Epoch [4/300], Training Loss: 8097.40742481122, Validation Loss: 14617.8974609375
# Epoch [5/300], Training Loss: 6205.981303983779, Validation Loss: 11536.42578125
# Epoch [6/300], Training Loss: 4731.369281281198, Validation Loss: 9215.7255859375
# Epoch [7/300], Training Loss: 3631.127809656652, Validation Loss: 6568.2275390625
# Epoch [8/300], Training Loss: 2767.7662652004547, Validation Loss: 4199.408203125
# Epoch [9/300], Training Loss: 2140.6312790858997, Validation Loss: 3179.010009765625
# Epoch [10/300], Training Loss: 1679.440478884109, Validation Loss: 2725.8974609375
# Epoch [11/300], Training Loss: 1338.2858870762457, Validation Loss: 2168.396240234375
# Epoch [12/300], Training Loss: 1085.3877932939624, Validation Loss: 1652.029052734375
# Epoch [13/300], Training Loss: 885.3661412942433, Validation Loss: 1259.1351318359375
# Epoch [14/300], Training Loss: 720.0225806667103, Validation Loss: 1006.4287719726562
# Epoch [15/300], Training Loss: 582.774471488573, Validation Loss: 836.1212158203125
# Epoch [16/300], Training Loss: 472.9925334312955, Validation Loss: 741.1150512695312
# Epoch [17/300], Training Loss: 382.89450493289155, Validation Loss: 658.7872924804688
# Epoch [18/300], Training Loss: 306.7574066209173, Validation Loss: 573.6724243164062
# Epoch [19/300], Training Loss: 247.90729095564933, Validation Loss: 562.513427734375
# Epoch [20/300], Training Loss: 202.55598491525578, Validation Loss: 577.9987182617188
# Epoch [21/300], Training Loss: 168.12926222760706, Validation Loss: 531.911376953125
# Epoch [22/300], Training Loss: 134.56978948886882, Validation Loss: 455.3643798828125
# Epoch [23/300], Training Loss: 104.90311938432424, Validation Loss: 235.82156372070312
# Epoch [24/300], Training Loss: 86.3849727649868, Validation Loss: 181.00489807128906
# Epoch [25/300], Training Loss: 68.80147892097227, Validation Loss: 140.18800354003906
# Epoch [26/300], Training Loss: 57.24140204914436, Validation Loss: 131.61712646484375
# Epoch [27/300], Training Loss: 48.34494129387487, Validation Loss: 120.7506103515625
# Epoch [28/300], Training Loss: 40.97826137635273, Validation Loss: 103.3545150756836
# Epoch [29/300], Training Loss: 35.301792647966124, Validation Loss: 95.95370483398438
# Epoch [30/300], Training Loss: 30.826184521481167, Validation Loss: 87.29216766357422
# Epoch [31/300], Training Loss: 27.18672868077344, Validation Loss: 100.02886199951172
# Epoch [32/300], Training Loss: 23.73121680808933, Validation Loss: 112.88491821289062
# Epoch [33/300], Training Loss: 21.71260558360347, Validation Loss: 113.87604522705078
# Epoch [34/300], Training Loss: 20.225408868777297, Validation Loss: 111.42012023925781
# Epoch [35/300], Training Loss: 18.899376388244853, Validation Loss: 103.341552734375
# Epoch [36/300], Training Loss: 17.615370254996275, Validation Loss: 94.77589416503906
# Epoch [37/300], Training Loss: 16.39210517186082, Validation Loss: 87.1406021118164
# Epoch [38/300], Training Loss: 15.246651421000553, Validation Loss: 79.26667785644531
# Epoch [39/300], Training Loss: 14.133815291280278, Validation Loss: 69.59046173095703
# Epoch [40/300], Training Loss: 12.992938533563985, Validation Loss: 60.501399993896484
# Epoch [41/300], Training Loss: 11.71378963228585, Validation Loss: 55.81086349487305
# Epoch [42/300], Training Loss: 10.736033074540758, Validation Loss: 54.77452087402344
# Epoch [43/300], Training Loss: 9.903340795038012, Validation Loss: 57.41130065917969
# Epoch [44/300], Training Loss: 9.224448053356761, Validation Loss: 61.294281005859375
# Epoch [45/300], Training Loss: 8.678516077178198, Validation Loss: 66.86637878417969
# Epoch [46/300], Training Loss: 8.310147885066437, Validation Loss: 70.49980163574219
# Epoch [47/300], Training Loss: 8.034664660491742, Validation Loss: 71.99992370605469
# Epoch [48/300], Training Loss: 7.775498584516032, Validation Loss: 73.7420883178711
# Epoch [49/300], Training Loss: 7.576773075578847, Validation Loss: 73.52741241455078
# Epoch [50/300], Training Loss: 7.392083535383009, Validation Loss: 73.3123779296875
# Epoch [51/300], Training Loss: 7.279861495759243, Validation Loss: 72.49335479736328
# Epoch [52/300], Training Loss: 7.309298122963199, Validation Loss: 68.88111114501953
# Epoch [53/300], Training Loss: 7.5133292346939955, Validation Loss: 64.75709533691406
# Epoch [54/300], Training Loss: 7.815953614930515, Validation Loss: 60.95391845703125
# Epoch [55/300], Training Loss: 8.003509358954492, Validation Loss: 54.28936767578125
# Epoch [56/300], Training Loss: 7.949903615103501, Validation Loss: 47.34518051147461
# Epoch [57/300], Training Loss: 7.8242478477446475, Validation Loss: 42.450416564941406
# Epoch [58/300], Training Loss: 7.713950508032781, Validation Loss: 39.089717864990234
# Epoch [59/300], Training Loss: 7.635995645374721, Validation Loss: 36.9188346862793
# Epoch [60/300], Training Loss: 7.593248376496351, Validation Loss: 35.65701675415039
# Epoch [61/300], Training Loss: 7.580814708296125, Validation Loss: 35.0524787902832
# Epoch [62/300], Training Loss: 7.587833012094984, Validation Loss: 35.00495529174805
# Epoch [63/300], Training Loss: 7.599549947672689, Validation Loss: 35.68613052368164
# Epoch [64/300], Training Loss: 7.601343725129018, Validation Loss: 37.37089157104492
# Epoch [65/300], Training Loss: 7.586236258255076, Validation Loss: 40.219703674316406
# Epoch [66/300], Training Loss: 7.55681250829427, Validation Loss: 44.16185760498047
# Epoch [67/300], Training Loss: 7.52270807039265, Validation Loss: 48.819374084472656
# Epoch [68/300], Training Loss: 7.493917949913414, Validation Loss: 53.554405212402344
# Epoch [69/300], Training Loss: 7.473585843464917, Validation Loss: 57.69166564941406
# Epoch [70/300], Training Loss: 7.460103816723977, Validation Loss: 60.72941970825195
# Epoch [71/300], Training Loss: 7.456099540817174, Validation Loss: 62.42242431640625
# Epoch [72/300], Training Loss: 7.471641822970365, Validation Loss: 62.71488571166992
# Epoch [73/300], Training Loss: 7.514226522092268, Validation Loss: 61.831295013427734
# Epoch [74/300], Training Loss: 7.581088610049259, Validation Loss: 60.30722427368164
# Epoch [75/300], Training Loss: 7.665356035591326, Validation Loss: 58.65562438964844
# Epoch [76/300], Training Loss: 7.759497136216173, Validation Loss: 57.180091857910156
# Epoch [77/300], Training Loss: 7.85875527440689, Validation Loss: 55.9825553894043
# Epoch [78/300], Training Loss: 7.961402873309177, Validation Loss: 55.04877853393555
# Epoch [79/300], Training Loss: 8.063764011996579, Validation Loss: 54.335723876953125
# Epoch [80/300], Training Loss: 8.153915692117799, Validation Loss: 53.854652404785156
# Epoch [81/300], Training Loss: 8.209745491200046, Validation Loss: 53.68417739868164
# Epoch [82/300], Training Loss: 8.208451655875606, Validation Loss: 53.96168518066406
# Epoch [83/300], Training Loss: 8.138977603567842, Validation Loss: 54.948272705078125
# Epoch [84/300], Training Loss: 8.000829136498258, Validation Loss: 57.26142883300781
# Epoch [85/300], Training Loss: 7.810013484300556, Validation Loss: 62.192787170410156
# Epoch [86/300], Training Loss: 7.62966416859778, Validation Loss: 70.9100570678711
# Epoch [87/300], Training Loss: 7.52419398428009, Validation Loss: 80.54177856445312
# Epoch [88/300], Training Loss: 7.519046546441868, Validation Loss: 83.36626434326172
# Epoch [89/300], Training Loss: 7.6063799788136555, Validation Loss: 77.20236206054688
# Epoch [90/300], Training Loss: 7.713190476601742, Validation Loss: 67.66475677490234
# Epoch [91/300], Training Loss: 7.774543266096818, Validation Loss: 60.4918212890625
# Epoch [92/300], Training Loss: 7.785000678367334, Validation Loss: 56.994056701660156
# Epoch [93/300], Training Loss: 7.76201144165329, Validation Loss: 56.33283996582031
# Epoch [94/300], Training Loss: 7.722598136742146, Validation Loss: 57.45314025878906
# Epoch [95/300], Training Loss: 7.675433132310534, Validation Loss: 59.55573654174805
# Epoch [96/300], Training Loss: 7.623428331819353, Validation Loss: 62.08656311035156
# Epoch [97/300], Training Loss: 7.568164176290137, Validation Loss: 64.60345458984375
# Epoch [98/300], Training Loss: 7.510351691563563, Validation Loss: 66.6880874633789
# Epoch [99/300], Training Loss: 7.4503705532449915, Validation Loss: 68.02024841308594
# Epoch [100/300], Training Loss: 7.389449119162741, Validation Loss: 68.48124694824219
# Epoch [101/300], Training Loss: 7.329538485843578, Validation Loss: 68.17572021484375
# Epoch [102/300], Training Loss: 7.27269847861386, Validation Loss: 67.32344055175781
# Epoch [103/300], Training Loss: 7.220278495945053, Validation Loss: 66.17623901367188
# Epoch [104/300], Training Loss: 7.173121604338557, Validation Loss: 64.93502044677734
# Epoch [105/300], Training Loss: 7.131315304314567, Validation Loss: 63.716312408447266
# Epoch [106/300], Training Loss: 7.094654119389727, Validation Loss: 62.566444396972656
# Epoch [107/300], Training Loss: 7.062794732479363, Validation Loss: 61.48422622680664
# Epoch [108/300], Training Loss: 7.035351563313146, Validation Loss: 60.43873596191406
# Epoch [109/300], Training Loss: 7.012050262061207, Validation Loss: 59.38774490356445
# Epoch [110/300], Training Loss: 6.992636518101677, Validation Loss: 58.28840255737305
# Epoch [111/300], Training Loss: 6.97707349296968, Validation Loss: 57.103111267089844
# Epoch [112/300], Training Loss: 6.965264808296553, Validation Loss: 55.79781723022461
# Epoch [113/300], Training Loss: 6.957135479063774, Validation Loss: 54.35426330566406
# Epoch [114/300], Training Loss: 6.952570785748332, Validation Loss: 52.748329162597656
# Epoch [115/300], Training Loss: 6.95144319514185, Validation Loss: 50.98946762084961
# Epoch [116/300], Training Loss: 6.953390896367179, Validation Loss: 49.09012222290039
# Epoch [117/300], Training Loss: 6.957899548170232, Validation Loss: 47.085453033447266
# Epoch [118/300], Training Loss: 6.963967943648336, Validation Loss: 45.036773681640625
# Epoch [119/300], Training Loss: 6.969834296887196, Validation Loss: 43.022422790527344
# Epoch [120/300], Training Loss: 6.972960918200964, Validation Loss: 41.13056182861328
# Epoch [121/300], Training Loss: 6.970032347535547, Validation Loss: 39.44068908691406
# Epoch [122/300], Training Loss: 6.95772768908267, Validation Loss: 38.0164794921875
# Epoch [123/300], Training Loss: 6.933905687852046, Validation Loss: 36.890716552734375
# Epoch [124/300], Training Loss: 6.898962828297494, Validation Loss: 36.056217193603516
# Epoch [125/300], Training Loss: 6.855520781291962, Validation Loss: 35.439048767089844
# Epoch [126/300], Training Loss: 6.808557940658428, Validation Loss: 34.88730239868164
# Epoch [127/300], Training Loss: 6.761946601563429, Validation Loss: 34.153228759765625
# Epoch [128/300], Training Loss: 6.721658473871878, Validation Loss: 32.968936920166016
# Epoch [129/300], Training Loss: 6.695626357105545, Validation Loss: 31.267576217651367
# Epoch [130/300], Training Loss: 6.694627466965244, Validation Loss: 29.31449317932129
# Epoch [131/300], Training Loss: 6.735470183652966, Validation Loss: 27.60413932800293
# Epoch [132/300], Training Loss: 6.848153668266477, Validation Loss: 26.63154411315918
# Epoch [133/300], Training Loss: 7.080984556512078, Validation Loss: 26.548242568969727
# Epoch [134/300], Training Loss: 7.476314025299308, Validation Loss: 27.029706954956055
# Epoch [135/300], Training Loss: 7.9859389068211675, Validation Loss: 27.547687530517578
# Epoch [136/300], Training Loss: 8.47828732931274, Validation Loss: 28.358394622802734
# Epoch [137/300], Training Loss: 8.870689112803017, Validation Loss: 30.412534713745117
# Epoch [138/300], Training Loss: 9.172535193558858, Validation Loss: 33.52775192260742
# Epoch [139/300], Training Loss: 9.419110107581892, Validation Loss: 36.31397247314453
# Epoch [140/300], Training Loss: 9.622119110829763, Validation Loss: 37.78645706176758
# Epoch [141/300], Training Loss: 9.769298066774802, Validation Loss: 37.81949234008789
# Epoch [142/300], Training Loss: 9.842961447471941, Validation Loss: 36.76414108276367
# Epoch [143/300], Training Loss: 9.838014974278789, Validation Loss: 35.181400299072266
# Epoch [144/300], Training Loss: 9.765839529449005, Validation Loss: 33.68841552734375
# Epoch [145/300], Training Loss: 9.645410951725285, Validation Loss: 32.685970306396484
# Epoch [146/300], Training Loss: 9.49592205104871, Validation Loss: 32.237003326416016
# Epoch [147/300], Training Loss: 9.336988528464923, Validation Loss: 32.19743347167969
# Epoch [148/300], Training Loss: 9.184823533102485, Validation Loss: 32.36285400390625
# Epoch [149/300], Training Loss: 9.04549701016242, Validation Loss: 32.55645751953125
# Epoch [150/300], Training Loss: 8.914399133314593, Validation Loss: 32.58964920043945
# Epoch [151/300], Training Loss: 8.75447250952424, Validation Loss: 32.495548248291016
# Epoch [152/300], Training Loss: 8.515409678905316, Validation Loss: 32.72284698486328
# Epoch [153/300], Training Loss: 8.214039987688352, Validation Loss: 33.24274826049805
# Epoch [154/300], Training Loss: 7.893874005543828, Validation Loss: 33.62236785888672
# Epoch [155/300], Training Loss: 7.589706594228726, Validation Loss: 33.67854690551758
# Epoch [156/300], Training Loss: 7.3143536818857235, Validation Loss: 33.48749923706055
# Epoch [157/300], Training Loss: 7.0659927736728125, Validation Loss: 33.165653228759766
# Epoch [158/300], Training Loss: 6.8405920285685236, Validation Loss: 32.86968231201172
# Epoch [159/300], Training Loss: 6.6336269056081205, Validation Loss: 32.893680572509766
# Epoch [160/300], Training Loss: 6.443475214701155, Validation Loss: 33.42002487182617
# Epoch [161/300], Training Loss: 6.277734117794069, Validation Loss: 34.23307418823242
# Epoch [162/300], Training Loss: 6.146164825411194, Validation Loss: 35.10091781616211
# Epoch [163/300], Training Loss: 6.053384103717566, Validation Loss: 35.88391876220703
# Epoch [164/300], Training Loss: 5.998846770628033, Validation Loss: 36.34983444213867
# Epoch [165/300], Training Loss: 5.981306481033037, Validation Loss: 36.41782760620117
# Epoch [166/300], Training Loss: 6.001394529615395, Validation Loss: 36.17119598388672
# Epoch [167/300], Training Loss: 6.062274180598387, Validation Loss: 35.81146240234375
# Epoch [168/300], Training Loss: 6.168122161963385, Validation Loss: 35.53580856323242
# Epoch [169/300], Training Loss: 6.318173175840865, Validation Loss: 35.514305114746094
# Epoch [170/300], Training Loss: 6.506372193734042, Validation Loss: 35.81004333496094
# Epoch [171/300], Training Loss: 6.701659480728574, Validation Loss: 36.319847106933594
# Epoch [172/300], Training Loss: 6.868832328336817, Validation Loss: 36.90980911254883
# Epoch [173/300], Training Loss: 6.997625049062731, Validation Loss: 37.5543212890625
# Epoch [174/300], Training Loss: 7.094795944139735, Validation Loss: 38.24928665161133
# Epoch [175/300], Training Loss: 7.170289801943794, Validation Loss: 38.99296188354492
# Epoch [176/300], Training Loss: 7.230923597672456, Validation Loss: 39.7654914855957
# Epoch [177/300], Training Loss: 7.279714806881384, Validation Loss: 40.54432678222656
# Epoch [178/300], Training Loss: 7.3171411056459155, Validation Loss: 41.305694580078125
# Epoch [179/300], Training Loss: 7.342951615734439, Validation Loss: 42.02754211425781
# Epoch [180/300], Training Loss: 7.357167015830875, Validation Loss: 42.70033645629883
# Epoch [181/300], Training Loss: 7.360800667773218, Validation Loss: 43.330299377441406
# Epoch [182/300], Training Loss: 7.355919691878704, Validation Loss: 43.931854248046875
# Epoch [183/300], Training Loss: 7.345226137964728, Validation Loss: 44.527828216552734
# Epoch [184/300], Training Loss: 7.331838486577754, Validation Loss: 45.1274528503418
# Epoch [185/300], Training Loss: 7.318415365342997, Validation Loss: 45.69814682006836
# Epoch [186/300], Training Loss: 7.306888088068902, Validation Loss: 46.19641876220703
# Epoch [187/300], Training Loss: 7.298692755685822, Validation Loss: 46.61858367919922
# Epoch [188/300], Training Loss: 7.295129191899533, Validation Loss: 47.00434112548828
# Epoch [189/300], Training Loss: 7.295856519360261, Validation Loss: 47.406982421875
# Epoch [190/300], Training Loss: 7.299248282676883, Validation Loss: 47.88716506958008
# Epoch [191/300], Training Loss: 7.304226991145435, Validation Loss: 48.488258361816406
# Epoch [192/300], Training Loss: 7.310150089546175, Validation Loss: 49.245460510253906
# Epoch [193/300], Training Loss: 7.316498569930077, Validation Loss: 50.19856643676758
# Epoch [194/300], Training Loss: 7.321868679669533, Validation Loss: 51.372737884521484
# Epoch [195/300], Training Loss: 7.3221229431267725, Validation Loss: 52.6711540222168
# Epoch [196/300], Training Loss: 7.314685684716538, Validation Loss: 54.05575180053711
# Epoch [197/300], Training Loss: 7.300174795947801, Validation Loss: 55.540687561035156
# Epoch [198/300], Training Loss: 7.2754940696507635, Validation Loss: 57.09565734863281
# Epoch [199/300], Training Loss: 7.237278650907655, Validation Loss: 58.6442756652832
# Epoch [200/300], Training Loss: 7.187131235303059, Validation Loss: 60.13032531738281
# Epoch [201/300], Training Loss: 7.122760175487931, Validation Loss: 61.50645446777344
# Epoch [202/300], Training Loss: 7.052294177572425, Validation Loss: 62.76441192626953
# Epoch [203/300], Training Loss: 6.981619750121221, Validation Loss: 63.89388656616211
# Epoch [204/300], Training Loss: 6.9037650554527445, Validation Loss: 64.78033447265625
# Epoch [205/300], Training Loss: 6.8171217288873365, Validation Loss: 65.34535217285156
# Epoch [206/300], Training Loss: 6.722690323475661, Validation Loss: 65.52777862548828
# Epoch [207/300], Training Loss: 6.62362184680136, Validation Loss: 65.2492446899414
# Epoch [208/300], Training Loss: 6.52686213256833, Validation Loss: 64.44355010986328
# Epoch [209/300], Training Loss: 6.439119270028996, Validation Loss: 63.06429672241211
# Epoch [210/300], Training Loss: 6.361076886908788, Validation Loss: 61.17448043823242
# Epoch [211/300], Training Loss: 6.2944342385307905, Validation Loss: 59.08712387084961
# Epoch [212/300], Training Loss: 6.254495881252309, Validation Loss: 57.33253860473633
# Epoch [213/300], Training Loss: 6.270714481317151, Validation Loss: 56.440242767333984
# Epoch [214/300], Training Loss: 6.227873006995567, Validation Loss: 56.62430953979492
# Epoch [215/300], Training Loss: 6.216562807133728, Validation Loss: 57.2169075012207
# Epoch [216/300], Training Loss: 6.219281422574001, Validation Loss: 58.51585388183594
# Epoch [217/300], Training Loss: 6.2272440443156265, Validation Loss: 59.9636116027832
# Epoch [218/300], Training Loss: 6.232629170464074, Validation Loss: 61.064781188964844
# Epoch [219/300], Training Loss: 6.23310560437231, Validation Loss: 61.64542007446289
# Epoch [220/300], Training Loss: 6.226517774411936, Validation Loss: 61.71343231201172
# Epoch [221/300], Training Loss: 6.212803701736891, Validation Loss: 61.38167953491211
# Epoch [222/300], Training Loss: 6.193474227678889, Validation Loss: 60.75602340698242
# Epoch [223/300], Training Loss: 6.170084951654235, Validation Loss: 59.865379333496094
# Epoch [224/300], Training Loss: 6.143945252191104, Validation Loss: 58.676692962646484
# Epoch [225/300], Training Loss: 6.115113668802046, Validation Loss: 57.17810821533203
# Epoch [226/300], Training Loss: 6.082725387886122, Validation Loss: 55.394752502441406
# Epoch [227/300], Training Loss: 6.0459328844738085, Validation Loss: 53.45250701904297
# Epoch [228/300], Training Loss: 6.005122486873587, Validation Loss: 51.47377014160156
# Epoch [229/300], Training Loss: 5.961163729858134, Validation Loss: 49.56955337524414
# Epoch [230/300], Training Loss: 5.91492558713983, Validation Loss: 47.85576248168945
# Epoch [231/300], Training Loss: 5.8677605961334764, Validation Loss: 46.42717361450195
# Epoch [232/300], Training Loss: 5.821099384823345, Validation Loss: 45.32367706298828
# Epoch [233/300], Training Loss: 5.7760260309502875, Validation Loss: 44.535057067871094
# Epoch [234/300], Training Loss: 5.733093553608508, Validation Loss: 44.019142150878906
# Epoch [235/300], Training Loss: 5.692207283438428, Validation Loss: 43.73714065551758
# Epoch [236/300], Training Loss: 5.653115792680494, Validation Loss: 43.64934539794922
# Epoch [237/300], Training Loss: 5.614955080867861, Validation Loss: 43.70040512084961
# Epoch [238/300], Training Loss: 5.577347425013926, Validation Loss: 43.84645080566406
# Epoch [239/300], Training Loss: 5.540041936094412, Validation Loss: 44.08021545410156
# Epoch [240/300], Training Loss: 5.5028439510524585, Validation Loss: 44.401126861572266
# Epoch [241/300], Training Loss: 5.466155996594493, Validation Loss: 44.78593444824219
# Epoch [242/300], Training Loss: 5.4304519081856375, Validation Loss: 45.19203186035156
# Epoch [243/300], Training Loss: 5.396317112544705, Validation Loss: 45.559715270996094
# Epoch [244/300], Training Loss: 5.3641061182593734, Validation Loss: 45.84954833984375
# Epoch [245/300], Training Loss: 5.3342904759761245, Validation Loss: 46.04143142700195
# Epoch [246/300], Training Loss: 5.3083614768999094, Validation Loss: 46.16942596435547
# Epoch [247/300], Training Loss: 5.287154887383623, Validation Loss: 46.35959243774414
# Epoch [248/300], Training Loss: 5.272591776238357, Validation Loss: 46.68872833251953
# Epoch [249/300], Training Loss: 5.266691339917972, Validation Loss: 47.094879150390625
# Epoch [250/300], Training Loss: 5.265221027755125, Validation Loss: 47.52235412597656
# Epoch [251/300], Training Loss: 5.26112065137221, Validation Loss: 47.95658874511719
# Epoch [252/300], Training Loss: 5.252782601731548, Validation Loss: 48.44010543823242
# Epoch [253/300], Training Loss: 5.242359722304609, Validation Loss: 48.978294372558594
# Epoch [254/300], Training Loss: 5.2315229486325565, Validation Loss: 49.507179260253906
# Epoch [255/300], Training Loss: 5.220786103473449, Validation Loss: 49.967445373535156
# Epoch [256/300], Training Loss: 5.210160439408468, Validation Loss: 50.347469329833984
# Epoch [257/300], Training Loss: 5.199828990924007, Validation Loss: 50.66429901123047
# Epoch [258/300], Training Loss: 5.190375777176736, Validation Loss: 50.951866149902344
# Epoch [259/300], Training Loss: 5.182402852880112, Validation Loss: 51.25426483154297
# Epoch [260/300], Training Loss: 5.176575626221472, Validation Loss: 51.633399963378906
# Epoch [261/300], Training Loss: 5.173398759440048, Validation Loss: 52.15100860595703
# Epoch [262/300], Training Loss: 5.173334659142074, Validation Loss: 52.8770751953125
# Epoch [263/300], Training Loss: 5.176347405667792, Validation Loss: 53.853477478027344
# Epoch [264/300], Training Loss: 5.182055499914205, Validation Loss: 55.076107025146484
# Epoch [265/300], Training Loss: 5.189414129609462, Validation Loss: 56.48362731933594
# Epoch [266/300], Training Loss: 5.196472816936403, Validation Loss: 58.03205871582031
# Epoch [267/300], Training Loss: 5.200288026655823, Validation Loss: 59.75619888305664
# Epoch [268/300], Training Loss: 5.196922928535734, Validation Loss: 61.737152099609375
# Epoch [269/300], Training Loss: 5.182490147427934, Validation Loss: 64.02090454101562
# Epoch [270/300], Training Loss: 5.154622679438644, Validation Loss: 66.55823516845703
# Epoch [271/300], Training Loss: 5.115079516871364, Validation Loss: 69.12348937988281
# Epoch [272/300], Training Loss: 5.071189960755106, Validation Loss: 71.53409576416016
# Epoch [273/300], Training Loss: 5.031056065318817, Validation Loss: 72.99571228027344
# Epoch [274/300], Training Loss: 5.002860042249467, Validation Loss: 75.7254867553711
# Epoch [275/300], Training Loss: 4.980062300183805, Validation Loss: 73.07164001464844
# Epoch [276/300], Training Loss: 4.9654213434536985, Validation Loss: 74.92396545410156
# Epoch [277/300], Training Loss: 4.953255187980167, Validation Loss: 69.0151596069336
# Epoch [278/300], Training Loss: 4.961643316066311, Validation Loss: 68.9586181640625
# Epoch [279/300], Training Loss: 4.95805141799411, Validation Loss: 60.51488494873047
# Epoch [280/300], Training Loss: 4.976854540929499, Validation Loss: 60.10679244995117
# Epoch [281/300], Training Loss: 4.957469222127142, Validation Loss: 51.30772399902344
# Epoch [282/300], Training Loss: 4.966413188385152, Validation Loss: 52.28307342529297
# Epoch [283/300], Training Loss: 4.918691815133793, Validation Loss: 44.45609664916992
# Epoch [284/300], Training Loss: 4.922896651789492, Validation Loss: 47.376243591308594
# Epoch [285/300], Training Loss: 4.852803442844245, Validation Loss: 40.81264877319336
# Epoch [286/300], Training Loss: 4.861599180931994, Validation Loss: 45.54769515991211
# Epoch [287/300], Training Loss: 4.7767579081009295, Validation Loss: 39.82718276977539
# Epoch [288/300], Training Loss: 4.795248959247489, Validation Loss: 45.807865142822266
# Epoch [289/300], Training Loss: 4.7070819020573245, Validation Loss: 40.66045379638672
# Epoch [290/300], Training Loss: 4.73207005014024, Validation Loss: 47.51778030395508
# Epoch [291/300], Training Loss: 4.648934649809998, Validation Loss: 43.062252044677734
# Epoch [292/300], Training Loss: 4.674229003048924, Validation Loss: 50.4453010559082
# Epoch [293/300], Training Loss: 4.602663405851016, Validation Loss: 46.82172775268555
# Epoch [294/300], Training Loss: 4.627481303486773, Validation Loss: 54.44330596923828
# Epoch [295/300], Training Loss: 4.571892553378522, Validation Loss: 51.6727294921875
# Epoch [296/300], Training Loss: 4.598820068319393, Validation Loss: 59.210018157958984
# Epoch [297/300], Training Loss: 4.560882012190493, Validation Loss: 57.056663513183594
# Epoch [298/300], Training Loss: 4.591911997983462, Validation Loss: 63.988502502441406
# Epoch [299/300], Training Loss: 4.570427293670411, Validation Loss: 61.95768356323242
# Epoch [300/300], Training Loss: 4.6053224259450545, Validation Loss: 67.38250732421875

# %%
import itertools

# Define the hyperparameters to search over
input_sizes = [7]
hidden_sizes = [16]
num_layers_list = [ 4]
learning_rates = [ 0.001]
window_sizes = [1, 2, 5, 10, 15, 20, 25, 30]
num_epochs = 80

# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

best_validation_loss = float('inf')
best_test_loss = float('inf')
best_hyperparameters = None

# Iterate over each hyperparameter combination
for hyperparameters in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparameters

    print()
    print("Hyperparameters:", hyperparameters)

    # Initialize the model with current hyperparameters
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        # Validate the model
        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)

            avg_train_loss = running_loss / len(x_train_tensor)
            avg_val_loss = val_loss / len(x_val_tensor)

            print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {avg_train_loss}, Validation Loss: {avg_val_loss}')

    # Evaluate the model on test data
    model.eval()  # Set the model to evaluation mode
    test_loss = 0.0

    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    avg_test_loss = test_loss / len(x_test_tensor)
    print(f'Test Loss: {avg_test_loss}')

    # Update best hyperparameters if test loss is lower
    if avg_test_loss < best_test_loss:
        best_test_loss = avg_test_loss
        best_hyperparameters = hyperparameters

print()
print("Best Hyperparameters:", best_hyperparameters)
print("Best Test Loss:", best_test_loss)
# Out:
# Hyperparameters: (7, 16, 4, 0.001, 1)
# Epoch [1/80], Training Loss: 17726.68072065603, Validation Loss: 18998.291015625
# Epoch [2/80], Training Loss: 14268.656376043677, Validation Loss: 18815.806640625
# Epoch [3/80], Training Loss: 10665.354157519032, Validation Loss: 21263.16015625
# Epoch [4/80], Training Loss: 8875.495716726904, Validation Loss: 15064.1650390625
# Epoch [5/80], Training Loss: 7058.00363547739, Validation Loss: 14003.8388671875
# Epoch [6/80], Training Loss: 4901.483497820451, Validation Loss: 9878.9482421875
# Epoch [7/80], Training Loss: 3714.9472711282474, Validation Loss: 6492.92578125
# Epoch [8/80], Training Loss: 2806.323359056444, Validation Loss: 5080.19970703125
# Epoch [9/80], Training Loss: 2170.3582344762513, Validation Loss: 3919.066650390625
# Epoch [10/80], Training Loss: 1708.2795731893757, Validation Loss: 2608.429931640625
# Epoch [11/80], Training Loss: 1364.3270508295295, Validation Loss: 2179.731201171875
# Epoch [12/80], Training Loss: 1118.659401967779, Validation Loss: 1770.2135009765625
# Epoch [13/80], Training Loss: 916.7711885372406, Validation Loss: 1416.93115234375
# Epoch [14/80], Training Loss: 746.84667193973, Validation Loss: 1179.624267578125
# Epoch [15/80], Training Loss: 605.9818928354407, Validation Loss: 1028.6661376953125
# Epoch [16/80], Training Loss: 494.8801738004297, Validation Loss: 887.4906005859375
# Epoch [17/80], Training Loss: 393.80636446051875, Validation Loss: 707.1549072265625
# Epoch [18/80], Training Loss: 311.7255040987254, Validation Loss: 572.0298461914062
# Epoch [19/80], Training Loss: 247.66534060844933, Validation Loss: 475.3876037597656
# Epoch [20/80], Training Loss: 198.55637993251517, Validation Loss: 454.1515808105469
# Epoch [21/80], Training Loss: 161.60166181719578, Validation Loss: 426.0106506347656
# Epoch [22/80], Training Loss: 133.7279781300547, Validation Loss: 357.3583984375
# Epoch [23/80], Training Loss: 106.7843077077079, Validation Loss: 373.3702697753906
# Epoch [24/80], Training Loss: 116.34757139477718, Validation Loss: 410.6856689453125
# Epoch [25/80], Training Loss: 238.58959145783265, Validation Loss: 732.7545166015625
# Epoch [26/80], Training Loss: 130.73716672327953, Validation Loss: 719.5403442382812
# Epoch [27/80], Training Loss: 120.59367308819192, Validation Loss: 564.6758422851562
# Epoch [28/80], Training Loss: 122.51969317344563, Validation Loss: 570.6082153320312
# Epoch [29/80], Training Loss: 94.31288026184323, Validation Loss: 686.2846069335938
# Epoch [30/80], Training Loss: 86.27722521080649, Validation Loss: 610.6939697265625
# Epoch [31/80], Training Loss: 102.6565643630643, Validation Loss: 534.5862426757812
# Epoch [32/80], Training Loss: 90.39536659810243, Validation Loss: 543.2673950195312
# Epoch [33/80], Training Loss: 87.08491996617204, Validation Loss: 519.7882080078125
# Epoch [34/80], Training Loss: 77.91904627510156, Validation Loss: 521.8658447265625
# Epoch [35/80], Training Loss: 52.897171240794876, Validation Loss: 542.6475219726562
# Epoch [36/80], Training Loss: 26.896964321235185, Validation Loss: 579.3643798828125
# Epoch [37/80], Training Loss: 27.58962124305185, Validation Loss: 461.9617614746094
# Epoch [38/80], Training Loss: 23.369590251505635, Validation Loss: 348.87811279296875
# Epoch [39/80], Training Loss: 19.806037749448876, Validation Loss: 335.0329284667969
# Epoch [40/80], Training Loss: 17.51359402153815, Validation Loss: 358.7069396972656
# Epoch [41/80], Training Loss: 19.169988631645513, Validation Loss: 425.3040466308594
# Epoch [42/80], Training Loss: 16.268674578646593, Validation Loss: 385.5722961425781
# Epoch [43/80], Training Loss: 18.060533876230068, Validation Loss: 495.9671325683594
# Epoch [44/80], Training Loss: 15.928380219537264, Validation Loss: 357.6675720214844
# Epoch [45/80], Training Loss: 14.62423633071915, Validation Loss: 415.8411865234375
# Epoch [46/80], Training Loss: 15.93146748560521, Validation Loss: 367.7919006347656
# Epoch [47/80], Training Loss: 13.376564453737924, Validation Loss: 309.9330749511719
# Epoch [48/80], Training Loss: 12.973617299995874, Validation Loss: 272.9365539550781
# Epoch [49/80], Training Loss: 12.278890490641762, Validation Loss: 248.36904907226562
# Epoch [50/80], Training Loss: 12.23449369362062, Validation Loss: 188.63198852539062
# Epoch [51/80], Training Loss: 11.910817335952068, Validation Loss: 172.09219360351562
# Epoch [52/80], Training Loss: 11.396976446256595, Validation Loss: 174.9630584716797
# Epoch [53/80], Training Loss: 11.387971938800899, Validation Loss: 159.48809814453125
# Epoch [54/80], Training Loss: 11.100617617701095, Validation Loss: 163.81484985351562
# Epoch [55/80], Training Loss: 11.105674604793967, Validation Loss: 170.989013671875
# Epoch [56/80], Training Loss: 10.78795997251747, Validation Loss: 173.60000610351562
# Epoch [57/80], Training Loss: 10.657404771009938, Validation Loss: 180.4514923095703
# Epoch [58/80], Training Loss: 10.496887009423283, Validation Loss: 189.86338806152344
# Epoch [59/80], Training Loss: 10.393785474350937, Validation Loss: 197.51315307617188
# Epoch [60/80], Training Loss: 10.19002650897006, Validation Loss: 199.27867126464844
# Epoch [61/80], Training Loss: 10.046147375523192, Validation Loss: 199.6082000732422
# Epoch [62/80], Training Loss: 10.044760139672457, Validation Loss: 187.05325317382812
# Epoch [63/80], Training Loss: 10.140244313166988, Validation Loss: 166.0403594970703
# Epoch [64/80], Training Loss: 10.174679057299175, Validation Loss: 152.93484497070312
# Epoch [65/80], Training Loss: 10.216096070465824, Validation Loss: 147.1656494140625
# Epoch [66/80], Training Loss: 10.229848519837876, Validation Loss: 144.64022827148438
# Epoch [67/80], Training Loss: 10.22121479424317, Validation Loss: 147.46728515625
# Epoch [68/80], Training Loss: 10.207799853883301, Validation Loss: 150.00579833984375
# Epoch [69/80], Training Loss: 10.176893294873679, Validation Loss: 151.06549072265625
# Epoch [70/80], Training Loss: 10.146112943807426, Validation Loss: 149.2287139892578
# Epoch [71/80], Training Loss: 10.13167925908214, Validation Loss: 143.97621154785156
# Epoch [72/80], Training Loss: 10.126648850115878, Validation Loss: 137.654052734375
# Epoch [73/80], Training Loss: 10.158324031908894, Validation Loss: 135.2350311279297
# Epoch [74/80], Training Loss: 10.233114256693895, Validation Loss: 132.94949340820312
# Epoch [75/80], Training Loss: 10.364680409988802, Validation Loss: 129.7905731201172
# Epoch [76/80], Training Loss: 10.374358804269631, Validation Loss: 122.76054382324219
# Epoch [77/80], Training Loss: 10.36701804272887, Validation Loss: 112.93811798095703
# Epoch [78/80], Training Loss: 10.467391268961544, Validation Loss: 102.15042114257812
# Epoch [79/80], Training Loss: 10.668774905268041, Validation Loss: 91.901611328125
# Epoch [80/80], Training Loss: 10.936569571286052, Validation Loss: 83.51456451416016
# Test Loss: 85.81156921386719
#
# Hyperparameters: (7, 16, 4, 0.001, 2)
# Epoch [1/80], Training Loss: 16438.03366016883, Validation Loss: 18639.94921875
# Epoch [2/80], Training Loss: 12360.246068154089, Validation Loss: 20082.4765625
# Epoch [3/80], Training Loss: 8565.904425079212, Validation Loss: 23483.16796875
# Epoch [4/80], Training Loss: 6233.567589508503, Validation Loss: 20685.20703125
# Epoch [5/80], Training Loss: 4472.666216360588, Validation Loss: 21353.015625
# Epoch [6/80], Training Loss: 3203.6182189080837, Validation Loss: 23064.5625
# Epoch [7/80], Training Loss: 2300.353156806728, Validation Loss: 24442.5390625
# Epoch [8/80], Training Loss: 1940.5555153710677, Validation Loss: 25142.048828125
# Epoch [9/80], Training Loss: 1298.1662997227033, Validation Loss: 21157.4765625
# Epoch [10/80], Training Loss: 1025.3368130132653, Validation Loss: 19370.984375
# Epoch [11/80], Training Loss: 930.1315322934507, Validation Loss: 16880.326171875
# Epoch [12/80], Training Loss: 599.2339961017577, Validation Loss: 17592.09765625
# Epoch [13/80], Training Loss: 619.0067849317838, Validation Loss: 15771.9873046875
# Epoch [14/80], Training Loss: 438.0339079511453, Validation Loss: 19684.0703125
# Epoch [15/80], Training Loss: 287.33946550135255, Validation Loss: 16603.89453125
# Epoch [16/80], Training Loss: 220.9006500996262, Validation Loss: 16853.36328125
# Epoch [17/80], Training Loss: 164.51329917538698, Validation Loss: 15554.3408203125
# Epoch [18/80], Training Loss: 129.8695378384574, Validation Loss: 14929.42578125
# Epoch [19/80], Training Loss: 108.2757943095052, Validation Loss: 13464.0439453125
# Epoch [20/80], Training Loss: 94.46016483823335, Validation Loss: 11168.2509765625
# Epoch [21/80], Training Loss: 83.51798644916929, Validation Loss: 11517.208984375
# Epoch [22/80], Training Loss: 71.06267786940987, Validation Loss: 9951.576171875
# Epoch [23/80], Training Loss: 70.31416157523846, Validation Loss: 10587.517578125
# Epoch [24/80], Training Loss: 56.660064504986174, Validation Loss: 10010.349609375
# Epoch [25/80], Training Loss: 51.736821799422344, Validation Loss: 9263.40625
# Epoch [26/80], Training Loss: 49.27245421683708, Validation Loss: 8921.4404296875
# Epoch [27/80], Training Loss: 45.87853483054558, Validation Loss: 8819.001953125
# Epoch [28/80], Training Loss: 44.2388946850339, Validation Loss: 9072.7509765625
# Epoch [29/80], Training Loss: 34.128944273091385, Validation Loss: 9318.75
# Epoch [30/80], Training Loss: 26.303393154126674, Validation Loss: 9680.7978515625
# Epoch [31/80], Training Loss: 24.47780448297469, Validation Loss: 9781.2666015625
# Epoch [32/80], Training Loss: 22.070458603076563, Validation Loss: 9954.1435546875
# Epoch [33/80], Training Loss: 21.22740950519646, Validation Loss: 9998.7958984375
# Epoch [34/80], Training Loss: 20.243819535790248, Validation Loss: 9911.5703125
# Epoch [35/80], Training Loss: 18.481603734901853, Validation Loss: 10430.48046875
# Epoch [36/80], Training Loss: 20.03997849529192, Validation Loss: 11235.962890625
# Epoch [37/80], Training Loss: 18.36226377716941, Validation Loss: 11754.525390625
# Epoch [38/80], Training Loss: 21.419370758852704, Validation Loss: 11979.837890625
# Epoch [39/80], Training Loss: 22.314841899569046, Validation Loss: 11090.70703125
# Epoch [40/80], Training Loss: 19.053174897859645, Validation Loss: 11624.4189453125
# Epoch [41/80], Training Loss: 19.671085162008044, Validation Loss: 10871.689453125
# Epoch [42/80], Training Loss: 15.47960827175575, Validation Loss: 12516.951171875
# Epoch [43/80], Training Loss: 18.179220350883437, Validation Loss: 11854.87109375
# Epoch [44/80], Training Loss: 17.32478518759873, Validation Loss: 11770.76171875
# Epoch [45/80], Training Loss: 18.380856315640287, Validation Loss: 11338.6259765625
# Epoch [46/80], Training Loss: 16.06850161313767, Validation Loss: 12533.962890625
# Epoch [47/80], Training Loss: 18.235897755529184, Validation Loss: 10750.044921875
# Epoch [48/80], Training Loss: 15.24131260109121, Validation Loss: 11146.1591796875
# Epoch [49/80], Training Loss: 14.296108518072744, Validation Loss: 10123.3466796875
# Epoch [50/80], Training Loss: 11.012916600464653, Validation Loss: 10709.662109375
# Epoch [51/80], Training Loss: 11.742999997024059, Validation Loss: 10560.521484375
# Epoch [52/80], Training Loss: 8.6944113776832, Validation Loss: 10520.861328125
# Epoch [53/80], Training Loss: 11.489648750064152, Validation Loss: 10695.0302734375
# Epoch [54/80], Training Loss: 13.0728508357798, Validation Loss: 10143.6396484375
# Epoch [55/80], Training Loss: 11.73078640125492, Validation Loss: 10792.671875
# Epoch [56/80], Training Loss: 12.08546910652194, Validation Loss: 10125.0966796875
# Epoch [57/80], Training Loss: 12.40871842331224, Validation Loss: 9908.7587890625
# Epoch [58/80], Training Loss: 13.771287609084942, Validation Loss: 10500.052734375
# Epoch [59/80], Training Loss: 14.877092191603442, Validation Loss: 10545.37109375
# Epoch [60/80], Training Loss: 9.910615727194338, Validation Loss: 10275.0810546875
# Epoch [61/80], Training Loss: 11.972275423734299, Validation Loss: 9662.5859375
# Epoch [62/80], Training Loss: 11.902535512894048, Validation Loss: 9564.2822265625
# Epoch [63/80], Training Loss: 13.104608667108828, Validation Loss: 9781.986328125
# Epoch [64/80], Training Loss: 13.837346852777706, Validation Loss: 9568.39453125
# Epoch [65/80], Training Loss: 11.17829289768994, Validation Loss: 9012.1708984375
# Epoch [66/80], Training Loss: 9.207070545635032, Validation Loss: 10184.12890625
# Epoch [67/80], Training Loss: 10.848720042794298, Validation Loss: 9492.9013671875
# Epoch [68/80], Training Loss: 10.604246012863234, Validation Loss: 9785.3486328125
# Epoch [69/80], Training Loss: 8.695902125199346, Validation Loss: 9700.2958984375
# Epoch [70/80], Training Loss: 10.832018747785666, Validation Loss: 9653.982421875
# Epoch [71/80], Training Loss: 10.276246553071806, Validation Loss: 9164.0078125
# Epoch [72/80], Training Loss: 12.39273186747119, Validation Loss: 9362.576171875
# Epoch [73/80], Training Loss: 11.69531740303061, Validation Loss: 8982.15625
# Epoch [74/80], Training Loss: 8.64278635100787, Validation Loss: 9268.291015625
