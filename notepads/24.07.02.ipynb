# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from sklearn import metrics
import numpy as npw
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler


def split_data_with_window(x_in, y_in, split_window_size):
    # Initialize lists to store training and temporary sets
    x_out1_list, y_out1_list, x_out2_list, y_out2_list = [], [], [], []

    # Iterate through the data with the specified window size
    for i in range(0, len(x_in) - split_window_size, split_window_size + 1):
        x_out1_out2 = x_in.iloc[i:i+split_window_size+1]
        y_out1_out2 = y_in.iloc[i:i+split_window_size+1]

        # Separate the last row for the temporary set
        # [ :-1]: all elements except the last one
        # [-1:]:  selects only the last element
        # (:) is used to indicate slicing of a sequence
        # sequence[start : end : step]

        x_out1 = x_out1_out2.iloc[:-1]
        y_out1 = y_out1_out2.iloc[:-1]

        x_out2 = x_out1_out2.iloc[-1:]
        y_out2 = y_out1_out2.iloc[-1:]

        x_out1_list.append(x_out1)
        y_out1_list.append(y_out1)
        x_out2_list.append(x_out2)
        y_out2_list.append(y_out2)

    # Concatenate the lists into pandas DataFrames
    x_out1 = pd.concat(x_out1_list)
    y_out1 = pd.concat(y_out1_list)
    x_out2 = pd.concat(x_out2_list)
    y_out2 = pd.concat(y_out2_list)

    return x_out1, y_out1, x_out2, y_out2










# Read the CSV file
data = pd.read_csv("../data/data/aapl_raw_data.csv")

data = data.drop("date", axis=1)

data.isnull().sum()
data=data.fillna(0)  # Filling null values with zero
data.isnull().sum()

data = data.astype('float32')


# Keep data until 31.08.2023
data = data.iloc[:10731]

#print(data['open'].dtype)
#print(data.shape)

# Assuming 'data' is a pandas DataFrame
x_data = data[['open', 'high', 'low', 'volume', 'adjusted_close', 'change_percent', 'avg_vol_20d']]
y_data = data["close"]

# Now x_data and y_data are pandas DataFrames/Series, respectively

x_data.tail(1)



# Split Data to train and temp

# Define your split_window_size
split_window_size = 3

# Call the split_data_with_window function
x_train, y_train, x_temp, y_temp = split_data_with_window(x_data, y_data, split_window_size)


"""

# Print the last 5 rows of x_data
print("Last 5 rows of x_data:")
print(x_data.tail(5))

# Print the last 5 rows of x_train
print("\nLast 25 rows of x_train:")
print(x_train.tail(25))

print("\nLast 3 rows of y_train:")
print(y_temp.tail(3))

"""

# Split temp into val and test

# Define your split_window_size
split_window_size = 1

# Call the split_data_with_window function
x_val, y_val, x_test, y_test = split_data_with_window(x_temp, y_temp, split_window_size)




scaler = MinMaxScaler()

x_train_normalized = scaler.fit_transform(x_train)
x_val_normalized = scaler.transform(x_val)
x_test_normalized = scaler.transform(x_test)

# Convert the data to PyTorch tensors
x_train_tensor = torch.tensor(x_train_normalized, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).view(-1, 1)

x_val_tensor = torch.tensor(x_val_normalized, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val.values, dtype=torch.float32).view(-1, 1)

x_test_tensor = torch.tensor(x_test_normalized, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).view(-1, 1)


"""
# x_train_tensor inverse

x_test_original = scaler.inverse_transform(x_train_tensor.numpy())
print("\nFirst row of x_test_original:")
print(x_test_original[0])

print("\nFirst row of x_train:")
print(x_train.head(1))



print("\nLast row of x_test_original:")
print(x_test_original[-1])

print("\nLast row of x_train:")
print(x_train.tail(1))
"""









class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, learning_rate, window_size):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.window_size = window_size
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)
        self.learning_rate = learning_rate

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        out, _ = self.lstm(x, (h0, c0))

        out = self.fc(out[:, -1, :])
        return out

# %%
import torch
import torch.nn as nn
import itertools
import random

# Define the hyperparameters to search over
input_sizes = [7]
hidden_sizes = [4]
num_layers_list = [2]
learning_rates = [0.0002]
window_sizes = [5]

num_epochs = 1200
patience = 10  # Number of epochs to wait for improvement



# Set random seeds for reproducibility to achieve reproducibility in your PyTorch script
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed) if torch.cuda.is_available() else None
np.random.seed(seed)
random.seed(seed)

# Additional steps to ensure determinism if needed !!!!!!!!!!!!!!

# ensures that cuDNN (CUDA Deep Neural Network library) will always produce the same results given the same input
torch.backends.cudnn.deterministic = True

# select the best algorithm for your input data. which can lead to faster execution times.
# different algorithms may be chosen even with the same input
torch.backends.cudnn.benchmark = False





# Combine hyperparameters into a list of tuples
hyperparameter_combinations = list(itertools.product(input_sizes, hidden_sizes, num_layers_list, learning_rates, window_sizes))

# Walk-forward validation training with sliding window for each hyperparameter combination
for hyperparams in hyperparameter_combinations:
    input_size, hidden_size, num_layers, learning_rate, window_size = hyperparams

    # Print hyperparameters
    print(f"Hyperparameters: input_size={input_size}, hidden_size={hidden_size}, num_layers={num_layers}, learning_rate={learning_rate}, window_size={window_size}")

    # Initialize the model
    model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    best_val_loss = float('inf')
    counter = 0

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i in range(len(x_train_tensor)):
            window_end = min(i + window_size, len(x_train_tensor))
            inputs = x_train_tensor[i:window_end].unsqueeze(0)
            labels = y_train_tensor[window_end - 1]

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        model.eval()
        val_loss = 0.0

        with torch.no_grad():
            for i in range(len(x_val_tensor)):
                window_end = min(i + window_size, len(x_val_tensor))
                inputs = x_val_tensor[i:window_end].unsqueeze(0)
                labels = y_val_tensor[window_end - 1]

                outputs = model(inputs)
                val_loss += criterion(outputs, labels)


        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f'Early stopping at epoch {epoch}')
                break

        print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {running_loss / len(x_train_tensor)}, Validation Loss: {val_loss / len(x_val_tensor)}')

       # Calculate test loss after training is complete
    test_loss = 0.0
    with torch.no_grad():
        for i in range(len(x_test_tensor)):
            window_end = min(i + window_size, len(x_test_tensor))
            inputs = x_test_tensor[i:window_end].unsqueeze(0)
            labels = y_test_tensor[window_end - 1]

            outputs = model(inputs)
            test_loss += criterion(outputs, labels)

    print(f'Final Test Loss: {test_loss / len(x_test_tensor)}')
# Out:
# Hyperparameters: input_size=7, hidden_size=4, num_layers=2, learning_rate=0.0002, window_size=5
# c:\VisualStudioCode\Repositories\Projectarbeit-Dow-Jones-Index\Projectarbeit-Dow-Jones-Index\.venv\Lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/1200], Training Loss: 28388.47489208361, Validation Loss: 28115.943359375
# Epoch [2/1200], Training Loss: 27150.39558028046, Validation Loss: 26965.1640625
# Epoch [3/1200], Training Loss: 26077.423699468287, Validation Loss: 25931.212890625
# Epoch [4/1200], Training Loss: 25121.48970722734, Validation Loss: 25010.828125
# Epoch [5/1200], Training Loss: 24278.404660282653, Validation Loss: 24199.33203125
# Epoch [6/1200], Training Loss: 23541.802013532822, Validation Loss: 23489.986328125
# Epoch [7/1200], Training Loss: 22903.069461783372, Validation Loss: 22874.099609375
# Epoch [8/1200], Training Loss: 22351.941646400464, Validation Loss: 22341.681640625
# Epoch [9/1200], Training Loss: 21877.441564977253, Validation Loss: 21882.197265625
# Epoch [10/1200], Training Loss: 21468.771943953478, Validation Loss: 21485.3984375
# Epoch [11/1200], Training Loss: 21116.033277628892, Validation Loss: 21142.080078125
# Epoch [12/1200], Training Loss: 20810.623113635855, Validation Loss: 20844.056640625
# Epoch [13/1200], Training Loss: 20545.141570184536, Validation Loss: 20584.439453125
# Epoch [14/1200], Training Loss: 20313.39385757408, Validation Loss: 20357.33203125
# Epoch [15/1200], Training Loss: 20110.215056578327, Validation Loss: 20157.85546875
# Epoch [16/1200], Training Loss: 19931.375374339044, Validation Loss: 19981.96484375
# Epoch [17/1200], Training Loss: 19773.30742616866, Validation Loss: 19826.25
# Epoch [18/1200], Training Loss: 19633.11486683594, Validation Loss: 19687.962890625
# Epoch [19/1200], Training Loss: 19508.31702009976, Validation Loss: 19564.689453125
# Epoch [20/1200], Training Loss: 19396.899722743055, Validation Loss: 19454.50390625
# Epoch [21/1200], Training Loss: 19297.10605851679, Validation Loss: 19355.689453125
# Epoch [22/1200], Training Loss: 19207.447439868298, Validation Loss: 19266.830078125
# Epoch [23/1200], Training Loss: 19126.71590372672, Validation Loss: 19186.705078125
# Epoch [24/1200], Training Loss: 19053.833228405387, Validation Loss: 19114.322265625
# Epoch [25/1200], Training Loss: 18987.859434990798, Validation Loss: 19048.755859375
# Epoch [26/1200], Training Loss: 18928.064864176176, Validation Loss: 18989.27734375
# Epoch [27/1200], Training Loss: 17963.940668189338, Validation Loss: 17797.640625
# Epoch [28/1200], Training Loss: 17180.836104642487, Validation Loss: 17243.888671875
# Epoch [29/1200], Training Loss: 16750.068003321827, Validation Loss: 16797.279296875
# Epoch [30/1200], Training Loss: 16336.354250492719, Validation Loss: 16382.4716796875
# Epoch [31/1200], Training Loss: 15938.821112525651, Validation Loss: 15984.701171875
# Epoch [32/1200], Training Loss: 15556.962901169329, Validation Loss: 15600.1904296875
# Epoch [33/1200], Training Loss: 15189.955678349243, Validation Loss: 15227.4404296875
# Epoch [34/1200], Training Loss: 14836.701402862915, Validation Loss: 14867.9580078125
# Epoch [35/1200], Training Loss: 14496.621580454079, Validation Loss: 14524.8720703125
# Epoch [36/1200], Training Loss: 14169.40462972995, Validation Loss: 14192.8544921875
# Epoch [37/1200], Training Loss: 13854.062821881265, Validation Loss: 13883.74609375
# Epoch [38/1200], Training Loss: 13548.545579131884, Validation Loss: 13579.4599609375
# Epoch [39/1200], Training Loss: 13252.877527021337, Validation Loss: 13286.0400390625
# Epoch [40/1200], Training Loss: 12967.700296853027, Validation Loss: 13002.75
# Epoch [41/1200], Training Loss: 12692.621097751757, Validation Loss: 12732.8349609375
# Epoch [42/1200], Training Loss: 12427.430176837393, Validation Loss: 12472.484375
# Epoch [43/1200], Training Loss: 12171.605452294256, Validation Loss: 12223.3779296875
# Epoch [44/1200], Training Loss: 11924.509144533034, Validation Loss: 11983.998046875
# Epoch [45/1200], Training Loss: 11685.52879417853, Validation Loss: 11753.3505859375
# Epoch [46/1200], Training Loss: 11454.329583877034, Validation Loss: 11532.4443359375
# Epoch [47/1200], Training Loss: 11230.673943684313, Validation Loss: 11320.6806640625
# Epoch [48/1200], Training Loss: 11014.40965582574, Validation Loss: 11115.77734375
# Epoch [49/1200], Training Loss: 10805.416120598951, Validation Loss: 10922.9833984375
# Epoch [50/1200], Training Loss: 10603.685471524788, Validation Loss: 10737.0224609375
# Epoch [51/1200], Training Loss: 10408.9639817623, Validation Loss: 10548.62109375
# Epoch [52/1200], Training Loss: 10221.12026236849, Validation Loss: 10361.8837890625
# Epoch [53/1200], Training Loss: 10040.045177205606, Validation Loss: 10179.8603515625
# Epoch [54/1200], Training Loss: 9865.418939857822, Validation Loss: 9992.654296875
# Epoch [55/1200], Training Loss: 9696.738181336286, Validation Loss: 9801.0537109375
# Epoch [56/1200], Training Loss: 9534.371264479134, Validation Loss: 9676.88671875
# Epoch [57/1200], Training Loss: 9378.318979827869, Validation Loss: 9519.779296875
# Epoch [58/1200], Training Loss: 9227.893180990692, Validation Loss: 9340.048828125
# Epoch [59/1200], Training Loss: 9082.710738985435, Validation Loss: 9172.0712890625
# Epoch [60/1200], Training Loss: 8942.717716145775, Validation Loss: 9022.95703125
# Epoch [61/1200], Training Loss: 8807.702751192388, Validation Loss: 8887.4013671875
# Epoch [62/1200], Training Loss: 8677.40614395293, Validation Loss: 8758.3349609375
# Epoch [63/1200], Training Loss: 8551.527976600719, Validation Loss: 8634.3818359375
# Epoch [64/1200], Training Loss: 8429.819725725896, Validation Loss: 8513.15625
# Epoch [65/1200], Training Loss: 8312.108575845527, Validation Loss: 8393.158203125
# Epoch [66/1200], Training Loss: 8198.229009288008, Validation Loss: 8278.40234375
# Epoch [67/1200], Training Loss: 8088.097096705215, Validation Loss: 8169.359375
# Epoch [68/1200], Training Loss: 7981.582315939356, Validation Loss: 8061.45263671875
# Epoch [69/1200], Training Loss: 7878.452808144551, Validation Loss: 7956.8134765625
# Epoch [70/1200], Training Loss: 7778.631166981718, Validation Loss: 7855.87158203125
# Epoch [71/1200], Training Loss: 7636.344118319387, Validation Loss: 7956.97607421875
# Epoch [72/1200], Training Loss: 7370.332752243296, Validation Loss: 7872.35205078125
# Epoch [73/1200], Training Loss: 7223.732174979777, Validation Loss: 7599.05126953125
# Epoch [74/1200], Training Loss: 7098.639487256174, Validation Loss: 7332.0439453125
# Epoch [75/1200], Training Loss: 6978.77023247491, Validation Loss: 7136.76416015625
# Epoch [76/1200], Training Loss: 6861.687809439454, Validation Loss: 6981.45166015625
# Epoch [77/1200], Training Loss: 6746.832400113718, Validation Loss: 6852.38720703125
# Epoch [78/1200], Training Loss: 6633.931629319478, Validation Loss: 6732.6376953125
# Epoch [79/1200], Training Loss: 6522.89966197212, Validation Loss: 6620.0576171875
# Epoch [80/1200], Training Loss: 6413.661175623926, Validation Loss: 6511.4697265625
# Epoch [81/1200], Training Loss: 6306.154474060955, Validation Loss: 6405.30810546875
# Epoch [82/1200], Training Loss: 6200.315674257203, Validation Loss: 6300.958984375
# Epoch [83/1200], Training Loss: 6096.1518491524985, Validation Loss: 6198.24560546875
# Epoch [84/1200], Training Loss: 5993.701700016354, Validation Loss: 6097.236328125
# Epoch [85/1200], Training Loss: 5892.9995680770235, Validation Loss: 5997.99365234375
# Epoch [86/1200], Training Loss: 5794.085874966663, Validation Loss: 5900.51953125
# Epoch [87/1200], Training Loss: 5696.998288142534, Validation Loss: 5804.81005859375
# Epoch [88/1200], Training Loss: 5601.744612883793, Validation Loss: 5710.876953125
# Epoch [89/1200], Training Loss: 5508.344531543773, Validation Loss: 5618.73828125
# Epoch [90/1200], Training Loss: 5416.827877775981, Validation Loss: 5528.4150390625
# Epoch [91/1200], Training Loss: 5327.167074113379, Validation Loss: 5439.896484375
# Epoch [92/1200], Training Loss: 5239.366633852384, Validation Loss: 5353.13037109375
# Epoch [93/1200], Training Loss: 5153.348029704743, Validation Loss: 5268.0625
# Epoch [94/1200], Training Loss: 5069.058464983943, Validation Loss: 5184.78466796875
# Epoch [95/1200], Training Loss: 4986.424123218677, Validation Loss: 5103.57568359375
# Epoch [96/1200], Training Loss: 4905.312252633908, Validation Loss: 5024.6455078125
# Epoch [97/1200], Training Loss: 4825.488373275214, Validation Loss: 4947.0673828125
# Epoch [98/1200], Training Loss: 4746.800092159296, Validation Loss: 4867.6474609375
# Epoch [99/1200], Training Loss: 4669.473457221789, Validation Loss: 4791.3037109375
# Epoch [100/1200], Training Loss: 4593.295280192894, Validation Loss: 4719.703125
# Epoch [101/1200], Training Loss: 4518.133085276046, Validation Loss: 4649.4296875
# Epoch [102/1200], Training Loss: 4443.987400992464, Validation Loss: 4579.55810546875
# Epoch [103/1200], Training Loss: 4370.822230071473, Validation Loss: 4510.0615234375
# Epoch [104/1200], Training Loss: 4298.627248721285, Validation Loss: 4440.91015625
# Epoch [105/1200], Training Loss: 4227.397825072867, Validation Loss: 4372.1640625
# Epoch [106/1200], Training Loss: 4157.105472355508, Validation Loss: 4304.13916015625
# Epoch [107/1200], Training Loss: 4087.73488371108, Validation Loss: 4237.5615234375
# Epoch [108/1200], Training Loss: 4019.34168833596, Validation Loss: 4172.7587890625
# Epoch [109/1200], Training Loss: 3952.0063337447236, Validation Loss: 4107.8740234375
# Epoch [110/1200], Training Loss: 3885.6958808455856, Validation Loss: 4041.83642578125
# Epoch [111/1200], Training Loss: 3820.373634129591, Validation Loss: 3975.129638671875
# Epoch [112/1200], Training Loss: 3755.9812996828423, Validation Loss: 3908.125
# Epoch [113/1200], Training Loss: 3692.4464333780875, Validation Loss: 3841.03466796875
# Epoch [114/1200], Training Loss: 3629.6022881733884, Validation Loss: 3774.524169921875
# Epoch [115/1200], Training Loss: 3567.255308485789, Validation Loss: 3709.834716796875
# Epoch [116/1200], Training Loss: 3505.3887762609224, Validation Loss: 3650.316650390625
# Epoch [117/1200], Training Loss: 3443.6983477956037, Validation Loss: 3593.54736328125
# Epoch [118/1200], Training Loss: 3384.590918062349, Validation Loss: 3537.775146484375
# Epoch [119/1200], Training Loss: 3326.927365845066, Validation Loss: 3481.541748046875
# Epoch [120/1200], Training Loss: 3270.342300362712, Validation Loss: 3425.911376953125
# Epoch [121/1200], Training Loss: 3214.782633099127, Validation Loss: 3371.56591796875
# Epoch [122/1200], Training Loss: 3160.311020836286, Validation Loss: 3317.995849609375
# Epoch [123/1200], Training Loss: 3106.981994519237, Validation Loss: 3265.60302734375
# Epoch [124/1200], Training Loss: 3054.758368268851, Validation Loss: 3214.74267578125
# Epoch [125/1200], Training Loss: 3003.603554620068, Validation Loss: 3165.276611328125
# Epoch [126/1200], Training Loss: 2953.486319971323, Validation Loss: 3117.186279296875
# Epoch [127/1200], Training Loss: 2904.3233654529167, Validation Loss: 3070.218994140625
# Epoch [128/1200], Training Loss: 2856.065137442507, Validation Loss: 3024.0595703125
# Epoch [129/1200], Training Loss: 2808.660105977178, Validation Loss: 2978.471435546875
# Epoch [130/1200], Training Loss: 2762.075485073867, Validation Loss: 2933.04345703125
# Epoch [131/1200], Training Loss: 2716.2000506498143, Validation Loss: 2885.226806640625
# Epoch [132/1200], Training Loss: 2671.059554406029, Validation Loss: 2827.52490234375
# Epoch [133/1200], Training Loss: 2626.6940024051764, Validation Loss: 2775.019775390625
# Epoch [134/1200], Training Loss: 2583.0936285241705, Validation Loss: 2730.945068359375
# Epoch [135/1200], Training Loss: 2540.1858228595624, Validation Loss: 2679.289794921875
# Epoch [136/1200], Training Loss: 2497.771560892143, Validation Loss: 2621.654296875
# Epoch [137/1200], Training Loss: 2451.326598198369, Validation Loss: 2580.50537109375
# Epoch [138/1200], Training Loss: 2410.5030908875356, Validation Loss: 2537.333984375
# Epoch [139/1200], Training Loss: 2372.0477285282527, Validation Loss: 2497.286865234375
# Epoch [140/1200], Training Loss: 2334.8606008097277, Validation Loss: 2458.376708984375
# Epoch [141/1200], Training Loss: 2298.7610673402505, Validation Loss: 2421.7392578125
# Epoch [142/1200], Training Loss: 2263.512441104741, Validation Loss: 2386.70458984375
# Epoch [143/1200], Training Loss: 2228.8823481653762, Validation Loss: 2352.607666015625
# Epoch [144/1200], Training Loss: 2194.7762631349447, Validation Loss: 2319.336181640625
# Epoch [145/1200], Training Loss: 2161.1656446897177, Validation Loss: 2286.724365234375
# Epoch [146/1200], Training Loss: 2128.041544966916, Validation Loss: 2254.749267578125
# Epoch [147/1200], Training Loss: 2095.411007026669, Validation Loss: 2223.19140625
# Epoch [148/1200], Training Loss: 2063.3020375189803, Validation Loss: 2191.953857421875
# Epoch [149/1200], Training Loss: 2031.7468292773146, Validation Loss: 2161.169921875
# Epoch [150/1200], Training Loss: 2000.715970587096, Validation Loss: 2131.0244140625
# Epoch [151/1200], Training Loss: 1970.1707254640148, Validation Loss: 2101.4853515625
# Epoch [152/1200], Training Loss: 1940.0693095181034, Validation Loss: 2072.297607421875
# Epoch [153/1200], Training Loss: 1910.367924875691, Validation Loss: 2042.7471923828125
# Epoch [154/1200], Training Loss: 1881.0556178496277, Validation Loss: 2009.8663330078125
# Epoch [155/1200], Training Loss: 1852.1471127417938, Validation Loss: 1970.3514404296875
# Epoch [156/1200], Training Loss: 1823.6670458672959, Validation Loss: 1932.82421875
# Epoch [157/1200], Training Loss: 1795.6561224035802, Validation Loss: 1900.039306640625
# Epoch [158/1200], Training Loss: 1768.1080720707375, Validation Loss: 1870.7913818359375
# Epoch [159/1200], Training Loss: 1741.0018316889668, Validation Loss: 1843.6654052734375
# Epoch [160/1200], Training Loss: 1714.3808273857928, Validation Loss: 1817.051513671875
# Epoch [161/1200], Training Loss: 1688.0914492768632, Validation Loss: 1790.8641357421875
# Epoch [162/1200], Training Loss: 1661.8689472443984, Validation Loss: 1764.82177734375
# Epoch [163/1200], Training Loss: 1635.570922999975, Validation Loss: 1739.17919921875
# Epoch [164/1200], Training Loss: 1609.8664278753506, Validation Loss: 1713.849365234375
# Epoch [165/1200], Training Loss: 1585.1856536262374, Validation Loss: 1687.685302734375
# Epoch [166/1200], Training Loss: 1561.3091960747347, Validation Loss: 1661.093994140625
# Epoch [167/1200], Training Loss: 1538.005872239574, Validation Loss: 1634.9146728515625
# Epoch [168/1200], Training Loss: 1515.1515776762733, Validation Loss: 1609.663818359375
# Epoch [169/1200], Training Loss: 1492.7310396854164, Validation Loss: 1585.6690673828125
# Epoch [170/1200], Training Loss: 1470.8102142418752, Validation Loss: 1562.87646484375
# Epoch [171/1200], Training Loss: 1449.5078163559604, Validation Loss: 1541.298095703125
# Epoch [172/1200], Training Loss: 1428.7195830959351, Validation Loss: 1519.9156494140625
# Epoch [173/1200], Training Loss: 1408.3134058437233, Validation Loss: 1495.632568359375
# Epoch [174/1200], Training Loss: 1388.3042428313347, Validation Loss: 1476.28564453125
# Epoch [175/1200], Training Loss: 1368.7737301797254, Validation Loss: 1456.1171875
# Epoch [176/1200], Training Loss: 1349.5663935713735, Validation Loss: 1433.5902099609375
# Epoch [177/1200], Training Loss: 1330.428323302018, Validation Loss: 1408.348876953125
# Epoch [178/1200], Training Loss: 1310.8939733902432, Validation Loss: 1378.95849609375
# Epoch [179/1200], Training Loss: 1290.8648553935766, Validation Loss: 1347.5006103515625
# Epoch [180/1200], Training Loss: 1271.36422157427, Validation Loss: 1319.400634765625
# Epoch [181/1200], Training Loss: 1252.9527963201458, Validation Loss: 1295.90869140625
# Epoch [182/1200], Training Loss: 1235.3447930067439, Validation Loss: 1275.21240234375
# Epoch [183/1200], Training Loss: 1218.2636433504283, Validation Loss: 1256.0335693359375
# Epoch [184/1200], Training Loss: 1201.5736440076469, Validation Loss: 1237.85009765625
# Epoch [185/1200], Training Loss: 1185.2020666248516, Validation Loss: 1220.42724609375
# Epoch [186/1200], Training Loss: 1169.0914535308345, Validation Loss: 1203.5821533203125
# Epoch [187/1200], Training Loss: 1153.210828550778, Validation Loss: 1187.151611328125
# Epoch [188/1200], Training Loss: 1137.5385646606765, Validation Loss: 1171.026611328125
# Epoch [189/1200], Training Loss: 1122.0540440739987, Validation Loss: 1155.12060546875
# Epoch [190/1200], Training Loss: 1106.7528205960123, Validation Loss: 1139.409912109375
# Epoch [191/1200], Training Loss: 1091.6292705401786, Validation Loss: 1123.8731689453125
# Epoch [192/1200], Training Loss: 1076.6834209519043, Validation Loss: 1108.52197265625
# Epoch [193/1200], Training Loss: 1061.9168325711298, Validation Loss: 1093.356689453125
# Epoch [194/1200], Training Loss: 1047.3244789385487, Validation Loss: 1078.3753662109375
# Epoch [195/1200], Training Loss: 1032.907800931203, Validation Loss: 1063.5855712890625
# Epoch [196/1200], Training Loss: 1018.669437913352, Validation Loss: 1048.993896484375
# Epoch [197/1200], Training Loss: 1004.6123204910107, Validation Loss: 1034.6090087890625
# Epoch [198/1200], Training Loss: 990.7364138121869, Validation Loss: 1020.4281616210938
# Epoch [199/1200], Training Loss: 977.048908533334, Validation Loss: 1006.45947265625
# Epoch [200/1200], Training Loss: 963.5485239264425, Validation Loss: 992.7059936523438
# Epoch [201/1200], Training Loss: 950.2289940229247, Validation Loss: 979.1520385742188
# Epoch [202/1200], Training Loss: 937.0889353388563, Validation Loss: 965.8073120117188
# Epoch [203/1200], Training Loss: 924.1283952473962, Validation Loss: 952.6697387695312
# Epoch [204/1200], Training Loss: 911.347042693996, Validation Loss: 939.737060546875
# Epoch [205/1200], Training Loss: 898.7458521573892, Validation Loss: 927.0062255859375
# Epoch [206/1200], Training Loss: 886.31603086382, Validation Loss: 914.4725952148438
# Epoch [207/1200], Training Loss: 874.0601149038894, Validation Loss: 902.1288452148438
# Epoch [208/1200], Training Loss: 861.971622225627, Validation Loss: 889.9744873046875
# Epoch [209/1200], Training Loss: 850.0545475386508, Validation Loss: 878.0099487304688
# Epoch [210/1200], Training Loss: 838.303431520501, Validation Loss: 866.22607421875
# Epoch [211/1200], Training Loss: 826.7173021209319, Validation Loss: 854.6246337890625
# Epoch [212/1200], Training Loss: 815.2908585534598, Validation Loss: 843.1969604492188
# Epoch [213/1200], Training Loss: 804.0173978014909, Validation Loss: 831.9368286132812
# Epoch [214/1200], Training Loss: 792.8929283631389, Validation Loss: 820.8382568359375
# Epoch [215/1200], Training Loss: 781.9133511845245, Validation Loss: 809.9071655273438
# Epoch [216/1200], Training Loss: 771.0809481835148, Validation Loss: 799.1373901367188
# Epoch [217/1200], Training Loss: 760.3897151108649, Validation Loss: 788.525146484375
# Epoch [218/1200], Training Loss: 749.8215742792174, Validation Loss: 778.0575561523438
# Epoch [219/1200], Training Loss: 739.3798418429894, Validation Loss: 767.7377319335938
# Epoch [220/1200], Training Loss: 729.058292835366, Validation Loss: 757.567138671875
# Epoch [221/1200], Training Loss: 718.86058487245, Validation Loss: 747.5474243164062
# Epoch [222/1200], Training Loss: 708.7905576395192, Validation Loss: 737.6765747070312
# Epoch [223/1200], Training Loss: 698.8460568617537, Validation Loss: 727.9511108398438
# Epoch [224/1200], Training Loss: 689.0318852082921, Validation Loss: 718.3618774414062
# Epoch [225/1200], Training Loss: 679.3410768282549, Validation Loss: 708.9006958007812
# Epoch [226/1200], Training Loss: 669.7743652115737, Validation Loss: 699.56787109375
# Epoch [227/1200], Training Loss: 660.3335431080143, Validation Loss: 690.3645629882812
# Epoch [228/1200], Training Loss: 651.0217014447429, Validation Loss: 681.2869873046875
# Epoch [229/1200], Training Loss: 641.8359643207717, Validation Loss: 672.3407592773438
# Epoch [230/1200], Training Loss: 632.7789167208963, Validation Loss: 663.5244140625
# Epoch [231/1200], Training Loss: 623.8447533538176, Validation Loss: 654.8381958007812
# Epoch [232/1200], Training Loss: 615.0337023839987, Validation Loss: 646.2811889648438
# Epoch [233/1200], Training Loss: 606.3455207956616, Validation Loss: 637.8499145507812
# Epoch [234/1200], Training Loss: 597.7729233656443, Validation Loss: 629.535888671875
# Epoch [235/1200], Training Loss: 589.3220303582464, Validation Loss: 621.3435668945312
# Epoch [236/1200], Training Loss: 580.9862085380107, Validation Loss: 613.2503662109375
# Epoch [237/1200], Training Loss: 572.762727943916, Validation Loss: 605.2520141601562
# Epoch [238/1200], Training Loss: 564.6559290817545, Validation Loss: 597.3401489257812
# Epoch [239/1200], Training Loss: 556.6620935153961, Validation Loss: 589.4986572265625
# Epoch [240/1200], Training Loss: 548.7784532381116, Validation Loss: 581.7144165039062
# Epoch [241/1200], Training Loss: 541.0008863831926, Validation Loss: 573.9749755859375
# Epoch [242/1200], Training Loss: 533.329969507672, Validation Loss: 566.2717895507812
# Epoch [243/1200], Training Loss: 525.755923008546, Validation Loss: 558.5968627929688
# Epoch [244/1200], Training Loss: 518.281137295516, Validation Loss: 550.9454956054688
# Epoch [245/1200], Training Loss: 510.8977026228944, Validation Loss: 543.28955078125
# Epoch [246/1200], Training Loss: 503.5938439230723, Validation Loss: 535.8491821289062
# Epoch [247/1200], Training Loss: 496.31481672642, Validation Loss: 527.19482421875
# Epoch [248/1200], Training Loss: 488.7828367435881, Validation Loss: 517.9581298828125
# Epoch [249/1200], Training Loss: 481.4754480537276, Validation Loss: 510.1694641113281
# Epoch [250/1200], Training Loss: 474.31894586204146, Validation Loss: 503.36962890625
# Epoch [251/1200], Training Loss: 467.2620942506759, Validation Loss: 496.99072265625
# Epoch [252/1200], Training Loss: 460.2922195405889, Validation Loss: 490.7579345703125
# Epoch [253/1200], Training Loss: 453.40522150474, Validation Loss: 484.5129089355469
# Epoch [254/1200], Training Loss: 446.6047556370006, Validation Loss: 478.19891357421875
# Epoch [255/1200], Training Loss: 439.8842734626955, Validation Loss: 471.8031311035156
# Epoch [256/1200], Training Loss: 433.2404839947597, Validation Loss: 465.35009765625
# Epoch [257/1200], Training Loss: 426.6813067848796, Validation Loss: 458.8612060546875
# Epoch [258/1200], Training Loss: 420.203874726977, Validation Loss: 452.3546447753906
# Epoch [259/1200], Training Loss: 413.8106027097385, Validation Loss: 445.8466491699219
# Epoch [260/1200], Training Loss: 407.5025849412908, Validation Loss: 439.35394287109375
# Epoch [261/1200], Training Loss: 401.2795154774708, Validation Loss: 432.8893127441406
# Epoch [262/1200], Training Loss: 395.1416937358573, Validation Loss: 426.468505859375
# Epoch [263/1200], Training Loss: 389.0897415004699, Validation Loss: 420.1049499511719
# Epoch [264/1200], Training Loss: 383.1232064835509, Validation Loss: 413.81256103515625
# Epoch [265/1200], Training Loss: 377.2416754690871, Validation Loss: 407.607421875
# Epoch [266/1200], Training Loss: 371.44741551858493, Validation Loss: 401.5012512207031
# Epoch [267/1200], Training Loss: 365.7359629254683, Validation Loss: 395.5014953613281
# Epoch [268/1200], Training Loss: 360.1095311661314, Validation Loss: 389.6188049316406
# Epoch [269/1200], Training Loss: 354.5701446018169, Validation Loss: 383.8553466796875
# Epoch [270/1200], Training Loss: 349.11345340226256, Validation Loss: 378.2088317871094
# Epoch [271/1200], Training Loss: 343.73937645738386, Validation Loss: 372.6776123046875
# Epoch [272/1200], Training Loss: 338.4459353450061, Validation Loss: 367.2531433105469
# Epoch [273/1200], Training Loss: 333.23425022874704, Validation Loss: 361.928466796875
# Epoch [274/1200], Training Loss: 328.1039082135702, Validation Loss: 356.6979064941406
# Epoch [275/1200], Training Loss: 323.0511810338441, Validation Loss: 351.5548400878906
# Epoch [276/1200], Training Loss: 318.07800282925825, Validation Loss: 346.4967346191406
# Epoch [277/1200], Training Loss: 313.18009990646965, Validation Loss: 341.52532958984375
# Epoch [278/1200], Training Loss: 308.35817706370074, Validation Loss: 336.6384582519531
# Epoch [279/1200], Training Loss: 303.6094622995113, Validation Loss: 331.84124755859375
# Epoch [280/1200], Training Loss: 298.9371862163921, Validation Loss: 327.1340637207031
# Epoch [281/1200], Training Loss: 294.34072293710426, Validation Loss: 322.51483154296875
# Epoch [282/1200], Training Loss: 289.8170888593309, Validation Loss: 317.9839782714844
# Epoch [283/1200], Training Loss: 285.36692643839285, Validation Loss: 313.5393981933594
# Epoch [284/1200], Training Loss: 280.9885934438779, Validation Loss: 309.17950439453125
# Epoch [285/1200], Training Loss: 276.68163279237365, Validation Loss: 304.9001770019531
# Epoch [286/1200], Training Loss: 272.4432713108757, Validation Loss: 300.69915771484375
# Epoch [287/1200], Training Loss: 268.2760181288539, Validation Loss: 296.57647705078125
# Epoch [288/1200], Training Loss: 264.176799077431, Validation Loss: 292.52294921875
# Epoch [289/1200], Training Loss: 260.1426059712191, Validation Loss: 288.5401306152344
# Epoch [290/1200], Training Loss: 256.176146745308, Validation Loss: 284.6257629394531
# Epoch [291/1200], Training Loss: 252.2759738180899, Validation Loss: 280.7755432128906
# Epoch [292/1200], Training Loss: 248.43921835638776, Validation Loss: 276.98907470703125
# Epoch [293/1200], Training Loss: 244.6651539722856, Validation Loss: 273.2619934082031
# Epoch [294/1200], Training Loss: 240.95125974136985, Validation Loss: 269.5945739746094
# Epoch [295/1200], Training Loss: 237.29857031569378, Validation Loss: 265.9862365722656
# Epoch [296/1200], Training Loss: 233.70585813510596, Validation Loss: 262.43450927734375
# Epoch [297/1200], Training Loss: 230.17141319873934, Validation Loss: 258.93927001953125
# Epoch [298/1200], Training Loss: 226.69548327562995, Validation Loss: 255.4989013671875
# Epoch [299/1200], Training Loss: 223.2776632500439, Validation Loss: 252.11248779296875
# Epoch [300/1200], Training Loss: 219.91429894078013, Validation Loss: 248.7736053466797
# Epoch [301/1200], Training Loss: 216.6065435952424, Validation Loss: 245.4818878173828
# Epoch [302/1200], Training Loss: 213.35202481024808, Validation Loss: 242.2301025390625
# Epoch [303/1200], Training Loss: 210.15009727454367, Validation Loss: 239.017822265625
# Epoch [304/1200], Training Loss: 206.9992650984153, Validation Loss: 235.83924865722656
# Epoch [305/1200], Training Loss: 203.90138225662224, Validation Loss: 232.695556640625
# Epoch [306/1200], Training Loss: 200.85378625705746, Validation Loss: 229.58489990234375
# Epoch [307/1200], Training Loss: 197.85428445401428, Validation Loss: 226.50967407226562
# Epoch [308/1200], Training Loss: 194.90261463476995, Validation Loss: 223.4723358154297
# Epoch [309/1200], Training Loss: 191.99943821529786, Validation Loss: 220.4806365966797
# Epoch [310/1200], Training Loss: 189.1434430449433, Validation Loss: 217.53289794921875
# Epoch [311/1200], Training Loss: 186.3313382254088, Validation Loss: 214.6337890625
# Epoch [312/1200], Training Loss: 183.56417157668614, Validation Loss: 211.7804412841797
# Epoch [313/1200], Training Loss: 180.84008412209636, Validation Loss: 208.96949768066406
# Epoch [314/1200], Training Loss: 178.15842456497123, Validation Loss: 206.19566345214844
# Epoch [315/1200], Training Loss: 175.51784376306486, Validation Loss: 203.45474243164062
# Epoch [316/1200], Training Loss: 172.91716956519568, Validation Loss: 200.74093627929688
# Epoch [317/1200], Training Loss: 170.35499887232177, Validation Loss: 198.05441284179688
# Epoch [318/1200], Training Loss: 167.83141926297773, Validation Loss: 195.3954620361328
# Epoch [319/1200], Training Loss: 165.34565440346313, Validation Loss: 192.76687622070312
# Epoch [320/1200], Training Loss: 162.8948221979945, Validation Loss: 190.17221069335938
# Epoch [321/1200], Training Loss: 160.4784965270399, Validation Loss: 187.6099090576172
# Epoch [322/1200], Training Loss: 158.0957496158701, Validation Loss: 185.08477783203125
# Epoch [323/1200], Training Loss: 155.74720156149723, Validation Loss: 182.59962463378906
# Epoch [324/1200], Training Loss: 153.42958441643418, Validation Loss: 180.15188598632812
# Epoch [325/1200], Training Loss: 151.14338704464058, Validation Loss: 177.74221801757812
# Epoch [326/1200], Training Loss: 148.88833992032926, Validation Loss: 175.36875915527344
# Epoch [327/1200], Training Loss: 146.66166240867227, Validation Loss: 173.02609252929688
# Epoch [328/1200], Training Loss: 144.4632038953288, Validation Loss: 170.71109008789062
# Epoch [329/1200], Training Loss: 142.29493957806596, Validation Loss: 168.4239044189453
# Epoch [330/1200], Training Loss: 140.15441906759597, Validation Loss: 166.15997314453125
# Epoch [331/1200], Training Loss: 138.04188098344056, Validation Loss: 163.9185333251953
# Epoch [332/1200], Training Loss: 135.95761162859247, Validation Loss: 161.70022583007812
# Epoch [333/1200], Training Loss: 133.90116373777408, Validation Loss: 159.5040740966797
# Epoch [334/1200], Training Loss: 131.87262120918015, Validation Loss: 157.3335418701172
# Epoch [335/1200], Training Loss: 129.87239396427458, Validation Loss: 155.19017028808594
# Epoch [336/1200], Training Loss: 127.89815570245165, Validation Loss: 153.0748291015625
# Epoch [337/1200], Training Loss: 125.95080630965352, Validation Loss: 150.99246215820312
# Epoch [338/1200], Training Loss: 124.03084156866498, Validation Loss: 148.9426727294922
# Epoch [339/1200], Training Loss: 122.13670239065455, Validation Loss: 146.92703247070312
# Epoch [340/1200], Training Loss: 120.26892096131428, Validation Loss: 144.9447479248047
# Epoch [341/1200], Training Loss: 118.4263555008553, Validation Loss: 142.99618530273438
# Epoch [342/1200], Training Loss: 116.60915335525169, Validation Loss: 141.0816650390625
# Epoch [343/1200], Training Loss: 114.81780151833084, Validation Loss: 139.1988983154297
# Epoch [344/1200], Training Loss: 113.05072327328764, Validation Loss: 137.34715270996094
# Epoch [345/1200], Training Loss: 111.30883734035889, Validation Loss: 135.5241241455078
# Epoch [346/1200], Training Loss: 109.59130171629815, Validation Loss: 133.72865295410156
# Epoch [347/1200], Training Loss: 107.89798347423277, Validation Loss: 131.95729064941406
# Epoch [348/1200], Training Loss: 106.22801578867126, Validation Loss: 130.20736694335938
# Epoch [349/1200], Training Loss: 104.581760523559, Validation Loss: 128.47715759277344
# Epoch [350/1200], Training Loss: 102.95952045038571, Validation Loss: 126.76422882080078
# Epoch [351/1200], Training Loss: 101.36020996119831, Validation Loss: 125.0662841796875
# Epoch [352/1200], Training Loss: 99.78488741395705, Validation Loss: 123.38301849365234
# Epoch [353/1200], Training Loss: 98.23398341230269, Validation Loss: 121.71263122558594
# Epoch [354/1200], Training Loss: 96.70550709415589, Validation Loss: 120.05266571044922
# Epoch [355/1200], Training Loss: 95.19978331066915, Validation Loss: 118.40355682373047
# Epoch [356/1200], Training Loss: 93.71712841877265, Validation Loss: 116.76512145996094
# Epoch [357/1200], Training Loss: 92.2581512532229, Validation Loss: 115.13824462890625
# Epoch [358/1200], Training Loss: 90.82192312189147, Validation Loss: 113.52177429199219
# Epoch [359/1200], Training Loss: 89.40900758533627, Validation Loss: 111.9172134399414
# Epoch [360/1200], Training Loss: 88.01880516338194, Validation Loss: 110.32559967041016
# Epoch [361/1200], Training Loss: 86.65107188096647, Validation Loss: 108.74677276611328
# Epoch [362/1200], Training Loss: 85.30515579825857, Validation Loss: 107.18133544921875
# Epoch [363/1200], Training Loss: 83.98120839944748, Validation Loss: 105.63048553466797
# Epoch [364/1200], Training Loss: 82.67979593358879, Validation Loss: 104.09554290771484
# Epoch [365/1200], Training Loss: 81.40020041701513, Validation Loss: 102.57691192626953
# Epoch [366/1200], Training Loss: 80.14199626930917, Validation Loss: 101.07511901855469
# Epoch [367/1200], Training Loss: 78.90508000763015, Validation Loss: 99.59089660644531
# Epoch [368/1200], Training Loss: 77.68889759239508, Validation Loss: 98.12435913085938
# Epoch [369/1200], Training Loss: 76.49402487512086, Validation Loss: 96.67765808105469
# Epoch [370/1200], Training Loss: 75.31975402764544, Validation Loss: 95.25048828125
# Epoch [371/1200], Training Loss: 74.16591139576364, Validation Loss: 93.84403228759766
# Epoch [372/1200], Training Loss: 73.03216917171301, Validation Loss: 92.45829010009766
# Epoch [373/1200], Training Loss: 71.91758823502325, Validation Loss: 91.09371948242188
# Epoch [374/1200], Training Loss: 70.82313982331581, Validation Loss: 89.7515869140625
# Epoch [375/1200], Training Loss: 69.74799297552127, Validation Loss: 88.43159484863281
# Epoch [376/1200], Training Loss: 68.69164665286009, Validation Loss: 87.13516998291016
# Epoch [377/1200], Training Loss: 67.65379345819082, Validation Loss: 85.86236572265625
# Epoch [378/1200], Training Loss: 66.63439350592826, Validation Loss: 84.61280059814453
# Epoch [379/1200], Training Loss: 65.63346810245609, Validation Loss: 83.38743591308594
# Epoch [380/1200], Training Loss: 64.65033401603398, Validation Loss: 82.18623352050781
# Epoch [381/1200], Training Loss: 63.68521484265419, Validation Loss: 81.00884246826172
# Epoch [382/1200], Training Loss: 62.7384572293221, Validation Loss: 79.85661315917969
# Epoch [383/1200], Training Loss: 61.808652931479706, Validation Loss: 78.72774505615234
# Epoch [384/1200], Training Loss: 60.89576462389405, Validation Loss: 77.62303924560547
# Epoch [385/1200], Training Loss: 60.000368080222316, Validation Loss: 76.54200744628906
# Epoch [386/1200], Training Loss: 59.121889786853096, Validation Loss: 75.48519134521484
# Epoch [387/1200], Training Loss: 58.25988378500777, Validation Loss: 74.45158386230469
# Epoch [388/1200], Training Loss: 57.41380681706977, Validation Loss: 73.44123077392578
# Epoch [389/1200], Training Loss: 56.58334803878553, Validation Loss: 72.45360565185547
# Epoch [390/1200], Training Loss: 55.768808413089566, Validation Loss: 71.48937225341797
# Epoch [391/1200], Training Loss: 54.969807421715196, Validation Loss: 70.54841613769531
# Epoch [392/1200], Training Loss: 54.18574161185843, Validation Loss: 69.62994384765625
# Epoch [393/1200], Training Loss: 53.416233656007975, Validation Loss: 68.73409271240234
# Epoch [394/1200], Training Loss: 52.66134656259199, Validation Loss: 67.8611831665039
# Epoch [395/1200], Training Loss: 51.921212441781535, Validation Loss: 67.01110076904297
# Epoch [396/1200], Training Loss: 51.19510348298619, Validation Loss: 66.18347930908203
# Epoch [397/1200], Training Loss: 50.48288365271634, Validation Loss: 65.37860870361328
# Epoch [398/1200], Training Loss: 49.784137744276705, Validation Loss: 64.59583282470703
# Epoch [399/1200], Training Loss: 49.09845964271216, Validation Loss: 63.835628509521484
# Epoch [400/1200], Training Loss: 48.42623727478938, Validation Loss: 63.09785079956055
# Epoch [401/1200], Training Loss: 47.76643685531366, Validation Loss: 62.3819694519043
# Epoch [402/1200], Training Loss: 47.118801356087516, Validation Loss: 61.68804931640625
# Epoch [403/1200], Training Loss: 46.48310542880338, Validation Loss: 61.01500701904297
# Epoch [404/1200], Training Loss: 45.85923933614561, Validation Loss: 60.362823486328125
# Epoch [405/1200], Training Loss: 45.24644635275441, Validation Loss: 59.730377197265625
# Epoch [406/1200], Training Loss: 44.64459993518524, Validation Loss: 59.11752700805664
# Epoch [407/1200], Training Loss: 44.053113674027145, Validation Loss: 58.522953033447266
# Epoch [408/1200], Training Loss: 43.472369617510886, Validation Loss: 57.94637680053711
# Epoch [409/1200], Training Loss: 42.90174366294091, Validation Loss: 57.38715744018555
# Epoch [410/1200], Training Loss: 42.34140675972195, Validation Loss: 56.84394836425781
# Epoch [411/1200], Training Loss: 41.790737389041745, Validation Loss: 56.31631088256836
# Epoch [412/1200], Training Loss: 41.249514330672426, Validation Loss: 55.80332565307617
# Epoch [413/1200], Training Loss: 40.71769944133357, Validation Loss: 55.30341339111328
# Epoch [414/1200], Training Loss: 40.19461113417145, Validation Loss: 54.81562423706055
# Epoch [415/1200], Training Loss: 39.68108681697056, Validation Loss: 54.33995819091797
# Epoch [416/1200], Training Loss: 39.17642292687102, Validation Loss: 53.874698638916016
# Epoch [417/1200], Training Loss: 38.680071768279824, Validation Loss: 53.418827056884766
# Epoch [418/1200], Training Loss: 38.192125106621525, Validation Loss: 52.97186279296875
# Epoch [419/1200], Training Loss: 37.71234233659648, Validation Loss: 52.532718658447266
# Epoch [420/1200], Training Loss: 37.24086628251789, Validation Loss: 52.10112380981445
# Epoch [421/1200], Training Loss: 36.77736268429324, Validation Loss: 51.675498962402344
# Epoch [422/1200], Training Loss: 36.32157761163564, Validation Loss: 51.25559997558594
# Epoch [423/1200], Training Loss: 35.87360866511712, Validation Loss: 50.840965270996094
# Epoch [424/1200], Training Loss: 35.432995332813086, Validation Loss: 50.431278228759766
# Epoch [425/1200], Training Loss: 34.99999733959193, Validation Loss: 50.025489807128906
# Epoch [426/1200], Training Loss: 34.574162536975585, Validation Loss: 49.623626708984375
# Epoch [427/1200], Training Loss: 34.155666159482514, Validation Loss: 49.22553253173828
# Epoch [428/1200], Training Loss: 33.74435620006877, Validation Loss: 48.831581115722656
# Epoch [429/1200], Training Loss: 33.339888589563586, Validation Loss: 48.43975067138672
# Epoch [430/1200], Training Loss: 32.9420383669304, Validation Loss: 48.05179214477539
# Epoch [431/1200], Training Loss: 32.55094107302196, Validation Loss: 47.66748809814453
# Epoch [432/1200], Training Loss: 32.16645319487422, Validation Loss: 47.28636932373047
# Epoch [433/1200], Training Loss: 31.788567121823885, Validation Loss: 46.90884780883789
# Epoch [434/1200], Training Loss: 31.417140079372004, Validation Loss: 46.53487777709961
# Epoch [435/1200], Training Loss: 31.05193292850752, Validation Loss: 46.164955139160156
# Epoch [436/1200], Training Loss: 30.692985023891517, Validation Loss: 45.79816818237305
# Epoch [437/1200], Training Loss: 30.340316884221377, Validation Loss: 45.43486022949219
# Epoch [438/1200], Training Loss: 29.993615924785868, Validation Loss: 45.075565338134766
# Epoch [439/1200], Training Loss: 29.65285854933568, Validation Loss: 44.71953582763672
# Epoch [440/1200], Training Loss: 29.317743844938082, Validation Loss: 44.36647033691406
# Epoch [441/1200], Training Loss: 28.988535891663105, Validation Loss: 44.017147064208984
# Epoch [442/1200], Training Loss: 28.665089597007967, Validation Loss: 43.671573638916016
# Epoch [443/1200], Training Loss: 28.347286491955526, Validation Loss: 43.330101013183594
# Epoch [444/1200], Training Loss: 28.034780246701906, Validation Loss: 42.99197006225586
# Epoch [445/1200], Training Loss: 27.7277625679608, Validation Loss: 42.658912658691406
# Epoch [446/1200], Training Loss: 27.426067941005133, Validation Loss: 42.329166412353516
# Epoch [447/1200], Training Loss: 27.12952829910774, Validation Loss: 42.00358581542969
# Epoch [448/1200], Training Loss: 26.83816499497423, Validation Loss: 41.68230438232422
# Epoch [449/1200], Training Loss: 26.55188669139783, Validation Loss: 41.36566162109375
# Epoch [450/1200], Training Loss: 26.27068265777879, Validation Loss: 41.053707122802734
# Epoch [451/1200], Training Loss: 25.994369811680155, Validation Loss: 40.74613571166992
# Epoch [452/1200], Training Loss: 25.722695944483462, Validation Loss: 40.44320297241211
# Epoch [453/1200], Training Loss: 25.45552806726586, Validation Loss: 40.14541244506836
# Epoch [454/1200], Training Loss: 25.192923297363098, Validation Loss: 39.853355407714844
# Epoch [455/1200], Training Loss: 24.9348655824295, Validation Loss: 39.56571578979492
# Epoch [456/1200], Training Loss: 24.680809189748015, Validation Loss: 39.282901763916016
# Epoch [457/1200], Training Loss: 24.4309404712326, Validation Loss: 39.00490951538086
# Epoch [458/1200], Training Loss: 24.18509433872139, Validation Loss: 38.7325553894043
# Epoch [459/1200], Training Loss: 23.94351547949895, Validation Loss: 38.465911865234375
# Epoch [460/1200], Training Loss: 23.706198723917897, Validation Loss: 38.2052116394043
# Epoch [461/1200], Training Loss: 23.47284050051091, Validation Loss: 37.94890594482422
# Epoch [462/1200], Training Loss: 23.243385881610916, Validation Loss: 37.69988250732422
# Epoch [463/1200], Training Loss: 23.018006242028576, Validation Loss: 37.4560661315918
# Epoch [464/1200], Training Loss: 22.796111710764567, Validation Loss: 37.21774673461914
# Epoch [465/1200], Training Loss: 22.57787553486341, Validation Loss: 36.985816955566406
# Epoch [466/1200], Training Loss: 22.363103364682935, Validation Loss: 36.75910186767578
# Epoch [467/1200], Training Loss: 22.15175770019682, Validation Loss: 36.539031982421875
# Epoch [468/1200], Training Loss: 21.943942499598403, Validation Loss: 36.324684143066406
# Epoch [469/1200], Training Loss: 21.739417133942702, Validation Loss: 36.11800765991211
# Epoch [470/1200], Training Loss: 21.538333182884493, Validation Loss: 35.9199333190918
# Epoch [471/1200], Training Loss: 21.340600041331708, Validation Loss: 35.7284049987793
# Epoch [472/1200], Training Loss: 21.146074947376487, Validation Loss: 35.54386520385742
# Epoch [473/1200], Training Loss: 20.954442689618674, Validation Loss: 35.36529541015625
# Epoch [474/1200], Training Loss: 20.766075422914724, Validation Loss: 35.19329833984375
# Epoch [475/1200], Training Loss: 20.58091037860555, Validation Loss: 35.02726364135742
# Epoch [476/1200], Training Loss: 20.398425900812068, Validation Loss: 34.866188049316406
# Epoch [477/1200], Training Loss: 20.21889093140437, Validation Loss: 34.711326599121094
# Epoch [478/1200], Training Loss: 20.042136740703103, Validation Loss: 34.561519622802734
# Epoch [479/1200], Training Loss: 19.868091820986304, Validation Loss: 34.41663360595703
# Epoch [480/1200], Training Loss: 19.696880178599237, Validation Loss: 34.277042388916016
# Epoch [481/1200], Training Loss: 19.528378104516378, Validation Loss: 34.14194869995117
# Epoch [482/1200], Training Loss: 19.362550665775686, Validation Loss: 34.010498046875
# Epoch [483/1200], Training Loss: 19.199177315739256, Validation Loss: 33.882911682128906
# Epoch [484/1200], Training Loss: 19.038373542361295, Validation Loss: 33.75937271118164
# Epoch [485/1200], Training Loss: 18.879946672460875, Validation Loss: 33.638404846191406
# Epoch [486/1200], Training Loss: 18.723846857773932, Validation Loss: 33.519813537597656
# Epoch [487/1200], Training Loss: 18.569911185018192, Validation Loss: 33.40418243408203
# Epoch [488/1200], Training Loss: 18.41825218290617, Validation Loss: 33.291385650634766
# Epoch [489/1200], Training Loss: 18.26878726522486, Validation Loss: 33.18098831176758
# Epoch [490/1200], Training Loss: 18.121327618597988, Validation Loss: 33.07205581665039
# Epoch [491/1200], Training Loss: 17.975955853845814, Validation Loss: 32.96476364135742
# Epoch [492/1200], Training Loss: 17.83248150739712, Validation Loss: 32.860328674316406
# Epoch [493/1200], Training Loss: 17.690937781686127, Validation Loss: 32.75652313232422
# Epoch [494/1200], Training Loss: 17.551324117562544, Validation Loss: 32.65410614013672
# Epoch [495/1200], Training Loss: 17.413601131649965, Validation Loss: 32.553436279296875
# Epoch [496/1200], Training Loss: 17.277662064610414, Validation Loss: 32.45420455932617
# Epoch [497/1200], Training Loss: 17.143608394207995, Validation Loss: 32.35736083984375
# Epoch [498/1200], Training Loss: 17.011155477440667, Validation Loss: 32.26105499267578
# Epoch [499/1200], Training Loss: 16.88041957755534, Validation Loss: 32.16532516479492
# Epoch [500/1200], Training Loss: 16.751403016024135, Validation Loss: 32.07232666015625
# Epoch [501/1200], Training Loss: 16.624109251472106, Validation Loss: 31.979230880737305
# Epoch [502/1200], Training Loss: 16.498280245099163, Validation Loss: 31.887680053710938
# Epoch [503/1200], Training Loss: 16.374032573892556, Validation Loss: 31.79840087890625
# Epoch [504/1200], Training Loss: 16.251357876425423, Validation Loss: 31.709440231323242
# Epoch [505/1200], Training Loss: 16.130093829855745, Validation Loss: 31.621061325073242
# Epoch [506/1200], Training Loss: 16.01039094486747, Validation Loss: 31.534259796142578
# Epoch [507/1200], Training Loss: 15.892064281012077, Validation Loss: 31.447725296020508
# Epoch [508/1200], Training Loss: 15.775204968798166, Validation Loss: 31.3624210357666
# Epoch [509/1200], Training Loss: 15.659710321970431, Validation Loss: 31.27743148803711
# Epoch [510/1200], Training Loss: 15.54572990229236, Validation Loss: 31.192739486694336
# Epoch [511/1200], Training Loss: 15.433245879616127, Validation Loss: 31.10906410217285
# Epoch [512/1200], Training Loss: 15.32207879780485, Validation Loss: 31.02387237548828
# Epoch [513/1200], Training Loss: 15.212214291768435, Validation Loss: 30.939760208129883
# Epoch [514/1200], Training Loss: 15.103760887810349, Validation Loss: 30.856243133544922
# Epoch [515/1200], Training Loss: 14.996666521624288, Validation Loss: 30.773120880126953
# Epoch [516/1200], Training Loss: 14.890900996720191, Validation Loss: 30.689647674560547
# Epoch [517/1200], Training Loss: 14.786301972910227, Validation Loss: 30.605989456176758
# Epoch [518/1200], Training Loss: 14.682920045568823, Validation Loss: 30.522966384887695
# Epoch [519/1200], Training Loss: 14.580598150153367, Validation Loss: 30.440473556518555
# Epoch [520/1200], Training Loss: 14.479519593075095, Validation Loss: 30.35759162902832
# Epoch [521/1200], Training Loss: 14.379517347502267, Validation Loss: 30.27562141418457
# Epoch [522/1200], Training Loss: 14.28071604835428, Validation Loss: 30.193716049194336
# Epoch [523/1200], Training Loss: 14.183067914125967, Validation Loss: 30.11146354675293
# Epoch [524/1200], Training Loss: 14.086530690964368, Validation Loss: 30.02982521057129
# Epoch [525/1200], Training Loss: 13.991056695435137, Validation Loss: 29.948455810546875
# Epoch [526/1200], Training Loss: 13.89667264922752, Validation Loss: 29.867578506469727
# Epoch [527/1200], Training Loss: 13.803321958051336, Validation Loss: 29.786819458007812
# Epoch [528/1200], Training Loss: 13.711073741985903, Validation Loss: 29.70633888244629
# Epoch [529/1200], Training Loss: 13.619910072418648, Validation Loss: 29.625507354736328
# Epoch [530/1200], Training Loss: 13.529748001736195, Validation Loss: 29.54460334777832
# Epoch [531/1200], Training Loss: 13.440562066917654, Validation Loss: 29.464115142822266
# Epoch [532/1200], Training Loss: 13.352485308318148, Validation Loss: 29.383581161499023
# Epoch [533/1200], Training Loss: 13.265366593590386, Validation Loss: 29.303600311279297
# Epoch [534/1200], Training Loss: 13.179111702483572, Validation Loss: 29.222522735595703
# Epoch [535/1200], Training Loss: 13.093730009982032, Validation Loss: 29.141685485839844
# Epoch [536/1200], Training Loss: 13.009213260759617, Validation Loss: 29.060897827148438
# Epoch [537/1200], Training Loss: 12.925456721786766, Validation Loss: 28.979589462280273
# Epoch [538/1200], Training Loss: 12.842656328397906, Validation Loss: 28.898658752441406
# Epoch [539/1200], Training Loss: 12.760677452152182, Validation Loss: 28.81657600402832
# Epoch [540/1200], Training Loss: 12.679523604211942, Validation Loss: 28.734901428222656
# Epoch [541/1200], Training Loss: 12.599191260007496, Validation Loss: 28.652687072753906
# Epoch [542/1200], Training Loss: 12.519724298297614, Validation Loss: 28.57099151611328
# Epoch [543/1200], Training Loss: 12.441103096863678, Validation Loss: 28.488386154174805
# Epoch [544/1200], Training Loss: 12.363162486407061, Validation Loss: 28.405895233154297
# Epoch [545/1200], Training Loss: 12.285940122517772, Validation Loss: 28.322826385498047
# Epoch [546/1200], Training Loss: 12.20952956195603, Validation Loss: 28.239961624145508
# ...
# Epoch [770/1200], Training Loss: 3.574555863417878, Validation Loss: 9.172343254089355
# Epoch [771/1200], Training Loss: 3.5592198379137843, Validation Loss: 9.124690055847168
# Epoch [772/1200], Training Loss: 3.5439715072043856, Validation Loss: 9.077796936035156
# Epoch [773/1200], Training Loss: 3.528830132702405, Validation Loss: 9.031575202941895
# Epoch [774/1200], Training Loss: 3.5137606229991896, Validation Loss: 8.98622989654541
# Epoch [775/1200], Training Loss: 3.498774370019581, Validation Loss: 8.941600799560547
# Epoch [776/1200], Training Loss: 3.483925000335093, Validation Loss: 8.897706031799316
# Epoch [777/1200], Training Loss: 3.469145212047966, Validation Loss: 8.854902267456055
# Epoch [778/1200], Training Loss: 3.4544547596242725, Validation Loss: 8.812899589538574
# Epoch [779/1200], Training Loss: 3.4398746774103626, Validation Loss: 8.771632194519043
# Epoch [780/1200], Training Loss: 3.4254502585885453, Validation Loss: 8.73132610321045
# Epoch [781/1200], Training Loss: 3.4111212514841647, Validation Loss: 8.691853523254395
# Epoch [782/1200], Training Loss: 3.3969347614749674, Validation Loss: 8.6532621383667
# Epoch [783/1200], Training Loss: 3.3828295020851638, Validation Loss: 8.615286827087402
# Epoch [784/1200], Training Loss: 3.368920184745586, Validation Loss: 8.578644752502441
# Epoch [785/1200], Training Loss: 3.355113160035734, Validation Loss: 8.5425386428833
# Epoch [786/1200], Training Loss: 3.341393951068755, Validation Loss: 8.507631301879883
# Epoch [787/1200], Training Loss: 3.32780121051122, Validation Loss: 8.473179817199707
# Epoch [788/1200], Training Loss: 3.3143424509812105, Validation Loss: 8.440296173095703
# Epoch [789/1200], Training Loss: 3.300989626688156, Validation Loss: 8.408024787902832
# Epoch [790/1200], Training Loss: 3.287696886914052, Validation Loss: 8.376507759094238
# Epoch [791/1200], Training Loss: 3.2745829788898457, Validation Loss: 8.346190452575684
# Epoch [792/1200], Training Loss: 3.2616760652415264, Validation Loss: 8.316097259521484
# Epoch [793/1200], Training Loss: 3.2488532967729347, Validation Loss: 8.287219047546387
# Epoch [794/1200], Training Loss: 3.2361777898393314, Validation Loss: 8.25906753540039
# Epoch [795/1200], Training Loss: 3.223647392002446, Validation Loss: 8.231668472290039
# Epoch [796/1200], Training Loss: 3.211200028158148, Validation Loss: 8.205387115478516
# Epoch [797/1200], Training Loss: 3.198885734080568, Validation Loss: 8.179502487182617
# Epoch [798/1200], Training Loss: 3.186729360139366, Validation Loss: 8.154402732849121
# Epoch [799/1200], Training Loss: 3.1747091743825226, Validation Loss: 8.129895210266113
# Epoch [800/1200], Training Loss: 3.162799227792333, Validation Loss: 8.106267929077148
# Epoch [801/1200], Training Loss: 3.1509992602971106, Validation Loss: 8.083232879638672
# Epoch [802/1200], Training Loss: 3.139343693070722, Validation Loss: 8.060755729675293
# Epoch [803/1200], Training Loss: 3.1278041499584845, Validation Loss: 8.038983345031738
# Epoch [804/1200], Training Loss: 3.116375354597917, Validation Loss: 8.017512321472168
# Epoch [805/1200], Training Loss: 3.105098004300507, Validation Loss: 7.9967522621154785
# Epoch [806/1200], Training Loss: 3.093972212754889, Validation Loss: 7.976342678070068
# Epoch [807/1200], Training Loss: 3.0829768573849656, Validation Loss: 7.956633567810059
# Epoch [808/1200], Training Loss: 3.0721184002005777, Validation Loss: 7.937134265899658
# Epoch [809/1200], Training Loss: 3.061382264861381, Validation Loss: 7.918061256408691
# Epoch [810/1200], Training Loss: 3.0507913864729574, Validation Loss: 7.899075508117676
# Epoch [811/1200], Training Loss: 3.040308553541921, Validation Loss: 7.880803108215332
# Epoch [812/1200], Training Loss: 3.0299434536573027, Validation Loss: 7.862742900848389
# Epoch [813/1200], Training Loss: 3.0196872355850095, Validation Loss: 7.844923973083496
# Epoch [814/1200], Training Loss: 3.0095424324611812, Validation Loss: 7.827517032623291
# Epoch [815/1200], Training Loss: 2.999521308703475, Validation Loss: 7.81003475189209
# Epoch [816/1200], Training Loss: 2.989607162189405, Validation Loss: 7.793269634246826
# Epoch [817/1200], Training Loss: 2.979795935250762, Validation Loss: 7.776584148406982
# Epoch [818/1200], Training Loss: 2.9700328267316793, Validation Loss: 7.759687900543213
# Epoch [819/1200], Training Loss: 2.9604286585512702, Validation Loss: 7.743088245391846
# Epoch [820/1200], Training Loss: 2.950925495776912, Validation Loss: 7.726595878601074
# Epoch [821/1200], Training Loss: 2.9415637806877886, Validation Loss: 7.710032939910889
# Epoch [822/1200], Training Loss: 2.9323391843170303, Validation Loss: 7.693352222442627
# Epoch [823/1200], Training Loss: 2.923220089254617, Validation Loss: 7.677035808563232
# Epoch [824/1200], Training Loss: 2.9141910347139386, Validation Loss: 7.66033411026001
# Epoch [825/1200], Training Loss: 2.905242605852627, Validation Loss: 7.644020080566406
# Epoch [826/1200], Training Loss: 2.8964455473395545, Validation Loss: 7.627993583679199
# Epoch [827/1200], Training Loss: 2.8877208122519176, Validation Loss: 7.611590385437012
# Epoch [828/1200], Training Loss: 2.8790772254940835, Validation Loss: 7.59513521194458
# Epoch [829/1200], Training Loss: 2.8705014430200944, Validation Loss: 7.579139232635498
# Epoch [830/1200], Training Loss: 2.861999536698379, Validation Loss: 7.562722206115723
# Epoch [831/1200], Training Loss: 2.8536040607347335, Validation Loss: 7.546644687652588
# Epoch [832/1200], Training Loss: 2.8452762140925345, Validation Loss: 7.530006408691406
# Epoch [833/1200], Training Loss: 2.8370053818335004, Validation Loss: 7.513643264770508
# Epoch [834/1200], Training Loss: 2.8288025520215063, Validation Loss: 7.49704647064209
# Epoch [835/1200], Training Loss: 2.8206967933198595, Validation Loss: 7.4806342124938965
# Epoch [836/1200], Training Loss: 2.8126809571693956, Validation Loss: 7.463939189910889
# Epoch [837/1200], Training Loss: 2.8047362983854653, Validation Loss: 7.447652339935303
# Epoch [838/1200], Training Loss: 2.796864710673458, Validation Loss: 7.430934906005859
# Epoch [839/1200], Training Loss: 2.789048621462211, Validation Loss: 7.413967132568359
# Epoch [840/1200], Training Loss: 2.7813502894820505, Validation Loss: 7.397408485412598
# Epoch [841/1200], Training Loss: 2.7737149139042523, Validation Loss: 7.380651950836182
# Epoch [842/1200], Training Loss: 2.76617839721125, Validation Loss: 7.3638739585876465
# Epoch [843/1200], Training Loss: 2.7587043081975504, Validation Loss: 7.346737861633301
# Epoch [844/1200], Training Loss: 2.7512746993044246, Validation Loss: 7.330036640167236
# Epoch [845/1200], Training Loss: 2.7438792191359513, Validation Loss: 7.313103199005127
# Epoch [846/1200], Training Loss: 2.7365762227492567, Validation Loss: 7.2963361740112305
# Epoch [847/1200], Training Loss: 2.7293496279589, Validation Loss: 7.279519557952881
# Epoch [848/1200], Training Loss: 2.722177736670764, Validation Loss: 7.263009071350098
# Epoch [849/1200], Training Loss: 2.715094075893603, Validation Loss: 7.246215343475342
# Epoch [850/1200], Training Loss: 2.7080460838566696, Validation Loss: 7.229658126831055
# Epoch [851/1200], Training Loss: 2.7010984481812637, Validation Loss: 7.213039875030518
# Epoch [852/1200], Training Loss: 2.6941875811769767, Validation Loss: 7.196352958679199
# Epoch [853/1200], Training Loss: 2.6873665566014275, Validation Loss: 7.1799540519714355
# Epoch [854/1200], Training Loss: 2.68058177379241, Validation Loss: 7.163418769836426
# Epoch [855/1200], Training Loss: 2.673893526631451, Validation Loss: 7.146927833557129
# Epoch [856/1200], Training Loss: 2.667272639451108, Validation Loss: 7.1304216384887695
# Epoch [857/1200], Training Loss: 2.6607072545240302, Validation Loss: 7.113861560821533
# Epoch [858/1200], Training Loss: 2.654179854705894, Validation Loss: 7.097710132598877
# Epoch [859/1200], Training Loss: 2.647725663519838, Validation Loss: 7.081360340118408
# Epoch [860/1200], Training Loss: 2.6413180822623854, Validation Loss: 7.0651397705078125
# Epoch [861/1200], Training Loss: 2.6349823286779026, Validation Loss: 7.04888916015625
# Epoch [862/1200], Training Loss: 2.628702887645153, Validation Loss: 7.0328898429870605
# Epoch [863/1200], Training Loss: 2.622454770912794, Validation Loss: 7.016920566558838
# Epoch [864/1200], Training Loss: 2.6162704240632855, Validation Loss: 7.000868797302246
# Epoch [865/1200], Training Loss: 2.610106675043318, Validation Loss: 6.985121250152588
# Epoch [866/1200], Training Loss: 2.6039889793862376, Validation Loss: 6.969507217407227
# Epoch [867/1200], Training Loss: 2.5979370422395722, Validation Loss: 6.953822135925293
# Epoch [868/1200], Training Loss: 2.5919328274452162, Validation Loss: 6.938472270965576
# Epoch [869/1200], Training Loss: 2.585970136104196, Validation Loss: 6.923246383666992
# Epoch [870/1200], Training Loss: 2.5800475697043272, Validation Loss: 6.908317565917969
# Epoch [871/1200], Training Loss: 2.5741092407065453, Validation Loss: 6.893253326416016
# Epoch [872/1200], Training Loss: 2.5682256310903653, Validation Loss: 6.878526210784912
# Epoch [873/1200], Training Loss: 2.5623567093046162, Validation Loss: 6.863564491271973
# Epoch [874/1200], Training Loss: 2.556522178477811, Validation Loss: 6.848895072937012
# Epoch [875/1200], Training Loss: 2.5506971990175353, Validation Loss: 6.834394931793213
# Epoch [876/1200], Training Loss: 2.54495704589571, Validation Loss: 6.820131301879883
# Epoch [877/1200], Training Loss: 2.5392260256704633, Validation Loss: 6.805938720703125
# Epoch [878/1200], Training Loss: 2.5335674718348398, Validation Loss: 6.791808605194092
# Epoch [879/1200], Training Loss: 2.5279300230858284, Validation Loss: 6.777879238128662
# Epoch [880/1200], Training Loss: 2.5223154511299537, Validation Loss: 6.76420783996582
# Epoch [881/1200], Training Loss: 2.5167607867278274, Validation Loss: 6.750447750091553
# Epoch [882/1200], Training Loss: 2.5112248061207723, Validation Loss: 6.737071514129639
# Epoch [883/1200], Training Loss: 2.50571950590501, Validation Loss: 6.723588466644287
# Epoch [884/1200], Training Loss: 2.5002619832538233, Validation Loss: 6.7104902267456055
# Epoch [885/1200], Training Loss: 2.4948195259622685, Validation Loss: 6.697563648223877
# Epoch [886/1200], Training Loss: 2.489459090933872, Validation Loss: 6.685123920440674
# Epoch [887/1200], Training Loss: 2.484081971818008, Validation Loss: 6.672574996948242
# Epoch [888/1200], Training Loss: 2.4787519691426896, Validation Loss: 6.660166263580322
# Epoch [889/1200], Training Loss: 2.4734821216404863, Validation Loss: 6.647759437561035
# Epoch [890/1200], Training Loss: 2.468202720579166, Validation Loss: 6.635571002960205
# Epoch [891/1200], Training Loss: 2.4629501211014238, Validation Loss: 6.623780250549316
# Epoch [892/1200], Training Loss: 2.4577453419431827, Validation Loss: 6.612009525299072
# Epoch [893/1200], Training Loss: 2.4525759844849375, Validation Loss: 6.6001482009887695
# Epoch [894/1200], Training Loss: 2.4474166406293163, Validation Loss: 6.588709354400635
# Epoch [895/1200], Training Loss: 2.442253959646788, Validation Loss: 6.577528476715088
# Epoch [896/1200], Training Loss: 2.4371412449232452, Validation Loss: 6.566450119018555
# Epoch [897/1200], Training Loss: 2.432031359288902, Validation Loss: 6.555455684661865
# Epoch [898/1200], Training Loss: 2.4269517428863336, Validation Loss: 6.5446038246154785
# Epoch [899/1200], Training Loss: 2.421906229541099, Validation Loss: 6.533997535705566
# Epoch [900/1200], Training Loss: 2.4168745674982914, Validation Loss: 6.5234832763671875
# Epoch [901/1200], Training Loss: 2.4119028070855815, Validation Loss: 6.513315200805664
# Epoch [902/1200], Training Loss: 2.406932236208241, Validation Loss: 6.50307035446167
# Epoch [903/1200], Training Loss: 2.4020135426538967, Validation Loss: 6.4931864738464355
# Epoch [904/1200], Training Loss: 2.397109327592484, Validation Loss: 6.48350191116333
# Epoch [905/1200], Training Loss: 2.3922548032909083, Validation Loss: 6.473951816558838
# Epoch [906/1200], Training Loss: 2.38739370160116, Validation Loss: 6.464505195617676
# Epoch [907/1200], Training Loss: 2.3825837919939907, Validation Loss: 6.455209255218506
# Epoch [908/1200], Training Loss: 2.377770824703147, Validation Loss: 6.44611120223999
# Epoch [909/1200], Training Loss: 2.3729770791539684, Validation Loss: 6.437135219573975
# Epoch [910/1200], Training Loss: 2.3682197527252042, Validation Loss: 6.428318977355957
# Epoch [911/1200], Training Loss: 2.363449717763699, Validation Loss: 6.419581890106201
# Epoch [912/1200], Training Loss: 2.3586948608115437, Validation Loss: 6.411158084869385
# Epoch [913/1200], Training Loss: 2.3539520403763, Validation Loss: 6.402622699737549
# Epoch [914/1200], Training Loss: 2.349209197438631, Validation Loss: 6.394495487213135
# Epoch [915/1200], Training Loss: 2.3444780113348385, Validation Loss: 6.386412143707275
# Epoch [916/1200], Training Loss: 2.339766276034715, Validation Loss: 6.378400802612305
# Epoch [917/1200], Training Loss: 2.33509173555845, Validation Loss: 6.3706159591674805
# Epoch [918/1200], Training Loss: 2.330446688871682, Validation Loss: 6.362850666046143
# Epoch [919/1200], Training Loss: 2.3258050086975337, Validation Loss: 6.354964256286621
# Epoch [920/1200], Training Loss: 2.3211906732606957, Validation Loss: 6.347425937652588
# Epoch [921/1200], Training Loss: 2.316589103904013, Validation Loss: 6.3398261070251465
# Epoch [922/1200], Training Loss: 2.3120016269525747, Validation Loss: 6.332273960113525
# Epoch [923/1200], Training Loss: 2.307445117266336, Validation Loss: 6.324889659881592
# Epoch [924/1200], Training Loss: 2.302914855908413, Validation Loss: 6.317564010620117
# Epoch [925/1200], Training Loss: 2.298388872723411, Validation Loss: 6.310060977935791
# Epoch [926/1200], Training Loss: 2.293887053702186, Validation Loss: 6.302774429321289
# Epoch [927/1200], Training Loss: 2.289395590476413, Validation Loss: 6.295599937438965
# Epoch [928/1200], Training Loss: 2.2849151588652283, Validation Loss: 6.288544178009033
# Epoch [929/1200], Training Loss: 2.280442133092055, Validation Loss: 6.281423091888428
# Epoch [930/1200], Training Loss: 2.275998677108887, Validation Loss: 6.274622440338135
# Epoch [931/1200], Training Loss: 2.2715697821138563, Validation Loss: 6.267734050750732
# Epoch [932/1200], Training Loss: 2.267166056001761, Validation Loss: 6.26123571395874
# Epoch [933/1200], Training Loss: 2.2628198636988786, Validation Loss: 6.254947662353516
# Epoch [934/1200], Training Loss: 2.2584790550069727, Validation Loss: 6.248973369598389
# Epoch [935/1200], Training Loss: 2.2541503117560944, Validation Loss: 6.243465423583984
# Epoch [936/1200], Training Loss: 2.249857526153323, Validation Loss: 6.238616943359375
# Epoch [937/1200], Training Loss: 2.2456119638458465, Validation Loss: 6.234395980834961
# Epoch [938/1200], Training Loss: 2.2414138434136563, Validation Loss: 6.230769634246826
# Epoch [939/1200], Training Loss: 2.2372850405830245, Validation Loss: 6.228127479553223
# Epoch [940/1200], Training Loss: 2.2332249051617685, Validation Loss: 6.2262797355651855
# Epoch [941/1200], Training Loss: 2.229272599764627, Validation Loss: 6.225186347961426
# Epoch [942/1200], Training Loss: 2.2253866025773648, Validation Loss: 6.224490642547607
# Epoch [943/1200], Training Loss: 2.221648028994993, Validation Loss: 6.224888801574707
# Epoch [944/1200], Training Loss: 2.21801107937326, Validation Loss: 6.226059436798096
# Epoch [945/1200], Training Loss: 2.2144767529732365, Validation Loss: 6.228148460388184
# Epoch [946/1200], Training Loss: 2.2110509155071982, Validation Loss: 6.2305707931518555
# Epoch [947/1200], Training Loss: 2.2077502973904055, Validation Loss: 6.233023166656494
# Epoch [948/1200], Training Loss: 2.2045470740668587, Validation Loss: 6.23552131652832
# Epoch [949/1200], Training Loss: 2.20144460353047, Validation Loss: 6.2377214431762695
# Epoch [950/1200], Training Loss: 2.198408404196458, Validation Loss: 6.23942232131958
# Epoch [951/1200], Training Loss: 2.195455492671821, Validation Loss: 6.240558624267578
# Early stopping at epoch 951
# Final Test Loss: 6.530320167541504

# %%
import numpy as np
import torch

def predict_future(model, initial_input, num_future_steps, scaler, device='cpu'):
    model.eval()
    future_predictions = []

    # Convert initial input to tensor and move to device
    # Ensure initial input has the shape (1, window_size, input_size)
    input_seq = torch.tensor(initial_input, dtype=torch.float32).unsqueeze(0).to(device)

    with torch.no_grad():
        for _ in range(num_future_steps):
            output = model(input_seq)
            future_predictions.append(output.item())

            # Update the input sequence by appending the latest prediction
            # Remove the first element and add the new prediction
            next_input = torch.cat((input_seq[:, 1:, :], output.unsqueeze(0).unsqueeze(0).repeat(1, 1, input_seq.size(2))), dim=1)
            input_seq = next_input

    # Inverse transform the predictions to the original scale
    future_predictions = np.array(future_predictions).reshape(-1, 1)
    future_predictions = scaler.inverse_transform(future_predictions)
    return future_predictions

# Parameters
num_future_steps = 10
input_size = len(x_train.columns)
hidden_size = 4
num_layers = 2
learning_rate = 0.0002
window_size = 5
forecast_horizon = 5

# Load your trained model
model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size, forecast_horizon)
# Assuming model is already trained, otherwise load the trained model

# Use the last window_size data points from the training set as the initial input
initial_input = x_train_normalized[-window_size:]

# Predict future steps
future_predictions = predict_future(model, initial_input, num_future_steps, scaler)

print("Future Predictions:", future_predictions)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 37
#      34 forecast_horizon = 5
#      36 # Load your trained model
# ---> 37 model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size, forecast_horizon)
#      38 # Assuming model is already trained, otherwise load the trained model
#      39
#      40 # Use the last window_size data points from the training set as the initial input
#      41 initial_input = x_train_normalized[-window_size:]
#
# TypeError: LSTMModel.__init__() takes 6 positional arguments but 7 were given

# %%
import numpy as np
# Define window size
window_size = 5

# Extract the last window from the training set
last_window = x_train[-window_size:]

model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size)

initial_input = last_window
num_future_steps = 5
forecast_horizon = 5
scaler = MinMaxScaler()



def predict_future(model, initial_input, num_future_steps, scaler, device='cpu'):
    model.eval()
    future_predictions = []

    # Convert initial input to tensor and move to device
    input_seq = torch.tensor(initial_input, dtype=torch.float32).unsqueeze(0).to(device)

    with torch.no_grad():
        for _ in range(num_future_steps):
            output = model(input_seq)
            prediction = output[-1].item()  # Get the prediction for the last time step
            future_predictions.append(prediction)

            # Create the next input sequence by appending the latest prediction
            next_input = torch.cat((input_seq[:, 1:, :], output.unsqueeze(0)), dim=1)
            input_seq = next_input

    # Inverse transform the predictions to the original scale
    future_predictions = np.array(future_predictions).reshape(-1, 1)
    future_predictions = scaler.inverse_transform(future_predictions)
    return future_predictions


# Parameters
num_future_steps = 10
input_size = len(x_train.columns)
hidden_size = 4
num_layers = 2
learning_rate = 0.0002
window_size = 5
forecast_horizon = 5

# Load your trained model
model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size, forecast_horizon)
# Assuming model is already trained, otherwise load the trained model

# Use the last window_size data points from the training set as the initial input
initial_input = x_train_normalized[-window_size:]

# Predict future steps
future_predictions = predict_future(model, initial_input, num_future_steps, scaler)

print("Future Predictions:", future_predictions)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 50
#      47 forecast_horizon = 5
#      49 # Load your trained model
# ---> 50 model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size, forecast_horizon)
#      51 # Assuming model is already trained, otherwise load the trained model
#      52
#      53 # Use the last window_size data points from the training set as the initial input
#      54 initial_input = x_train_normalized[-window_size:]
#
# TypeError: LSTMModel.__init__() takes 6 positional arguments but 7 were given

# %%
import numpy as np
# Define window size
window_size = 5

# Extract the last window from the training set
last_window = x_train[-window_size:]

model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size, forecast_horizon)

initial_input = last_window
num_future_steps = 5
forecast_horizon = 5
scaler = MinMaxScaler()



def predict_future(model, initial_input, num_future_steps, scaler, device='cpu'):
    model.eval()
    future_predictions = []

    # Convert initial input to tensor and move to device
    input_seq = torch.tensor(initial_input, dtype=torch.float32).unsqueeze(0).to(device)

    with torch.no_grad():
        for _ in range(num_future_steps):
            output = model(input_seq)
            prediction = output[-1].item()  # Get the prediction for the last time step
            future_predictions.append(prediction)

            # Create the next input sequence by appending the latest prediction
            next_input = torch.cat((input_seq[:, 1:, :], output.unsqueeze(0)), dim=1)
            input_seq = next_input

    # Inverse transform the predictions to the original scale
    future_predictions = np.array(future_predictions).reshape(-1, 1)
    future_predictions = scaler.inverse_transform(future_predictions)
    return future_predictions


# Parameters
num_future_steps = 10
input_size = len(x_train.columns)
hidden_size = 4
num_layers = 2
learning_rate = 0.0002
window_size = 5
forecast_horizon = 5

# Load your trained model
model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size, forecast_horizon)
# Assuming model is already trained, otherwise load the trained model

# Use the last window_size data points from the training set as the initial input
initial_input = x_train_normalized[-window_size:]

# Predict future steps
future_predictions = predict_future(model, initial_input, num_future_steps, scaler)

print("Future Predictions:", future_predictions)
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[68], line 8
#
#       5 # Extract the last window from the training set
#
#       6 last_window = x_train[-window_size:]
#
# ----> 8 model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size, forecast_horizon)
#
#       9 initial_input = last_window
#
#      10 num_future_steps = 5
#
#
#
# TypeError: LSTMModel.__init__() takes 6 positional arguments but 7 were given

# %%
import numpy as np
# Define window size
window_size = 5

# Extract the last window from the training set
last_window = x_train[-window_size:]

model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size, forecast_horizon)
initial_input = last_window
num_future_steps = 5
forecast_horizon = 5
scaler = MinMaxScaler()



def predict_future(model, initial_input, num_future_steps, scaler, device='cpu'):
    model.eval()
    future_predictions = []

    # Convert initial input to tensor and move to device
    input_seq = torch.tensor(initial_input, dtype=torch.float32).unsqueeze(0).to(device)

    with torch.no_grad():
        for _ in range(num_future_steps):
            output = model(input_seq)
            future_predictions.append(output.item())

            # Create the next input sequence by appending the latest prediction
            next_input = torch.cat((input_seq[:, 1:, :], output.unsqueeze(0).unsqueeze(0)), dim=1)
            input_seq = next_input

    # Inverse transform the predictions to the original scale
    future_predictions = np.array(future_predictions).reshape(-1, 1)
    future_predictions = scaler.inverse_transform(future_predictions)
    return future_predictions

# Parameters
num_future_steps = 10
input_size = len(x_train.columns)
hidden_size = 4
num_layers = 2
learning_rate = 0.0002
window_size = 5
forecast_horizon = 5

# Load your trained model
model = LSTMModel(input_size, hidden_size, num_layers, learning_rate, window_size, forecast_horizon)
# Assuming model is already trained, otherwise load the trained model

# Use the last window_size data points from the training set as the initial input
initial_input = x_train_normalized[-window_size:]

# Predict future steps
future_predictions = predict_future(model, initial_input, num_future_steps, scaler)

print("Future Predictions:", future_predictions)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[50], line 54
#      51 initial_input = x_train_normalized[-window_size:]
#      53 # Predict future steps
# ---> 54 future_predictions = predict_future(model, initial_input, num_future_steps, scaler)
#      56 print("Future Predictions:", future_predictions)
#
# Cell In[50], line 26, in predict_future(model, initial_input, num_future_steps, scaler, device)
#      24 for _ in range(num_future_steps):
#      25     output = model(input_seq)
# ---> 26     future_predictions.append(output.item())
#      28     # Create the next input sequence by appending the latest prediction
#      29     next_input = torch.cat((input_seq[:, 1:, :], output.unsqueeze(0).unsqueeze(0)), dim=1)
#
# RuntimeError: a Tensor with 5 elements cannot be converted to Scalar
